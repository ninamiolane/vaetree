# %%
from itertools import cycle, islice
import glob
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import os
import pickle
from scipy.stats import gaussian_kde
import seaborn as sns
import re

from sklearn.decomposition import PCA

import importlib

import imnn
importlib.reload(imnn)
import toylosses
importlib.reload(toylosses)
import toynn
importlib.reload(toynn)
import toyvis
importlib.reload(toyvis)

import torch
import torch.utils.data
from torchvision import datasets, transforms
#sns.set()

import toypipeline
importlib.reload(toypipeline)

LATENT_DIM = 10
DATA_DIM = 784

CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if CUDA else "cpu")
OUTPUT = '/scratch/users/nmiolane/imoutput_nips_omniglot10'

# %% [markdown]
# # Inspect Functions

# %%
algo_strings = {'vae': 'VAE', 'iwae': 'IWAE', 'vem': 'VIWAE'}
crit_strings = {'neg_elbo': 'Neg ELBO', 'neg_iwelbo': 'Neg IWELBO', 'neg_loglikelihood': 'NLL'}
train_val_strings = {'train': 'Train', 'val': 'Valid'}
crit_color_dict = {'neg_elbo': 'red', 'neg_iwelbo': 'orange'}
algo_color_dict = {'vae': 'red', 'iwae': 'orange', 'vem': 'blue'}

# %%
def plot_kl_posterior(ax, algo_name='vae', mode='train',
                      from_epoch=0, to_epoch=1000, color='blue', dashes=False):

    neg_elbo = get_losses(algo_name=algo_name, crit_name='neg_elbo', mode=mode)
    neg_ll = get_losses(algo_name=algo_name, crit_name='neg_loglikelihood', mode=mode)

    kl = [nelbo - nll for (nelbo, nll) in zip(neg_elbo, neg_ll)]
    
    n_epochs = len(kl)
    epochs = range(n_epochs)
    to_epoch = min(to_epoch, n_epochs)

    label = f'{algo_strings[algo_name]}: {train_val_strings[mode]} KL'
   
    if not dashes:
        ax.plot(epochs[from_epoch:to_epoch], kl[from_epoch:to_epoch], 
                label=label, color=color)
    else:
        ax.plot(epochs[from_epoch:to_epoch], kl[from_epoch:to_epoch], 
                label=label, color=color, dashes=[2, 2, 2, 2])
    ax.set_xlabel('epochs')
    return ax

# %%
def plot_kl_prior(ax, algo_name='vae', mode='train',
                  from_epoch=0, to_epoch=1000, color='blue', dashes=False):

    neg_elbo = get_losses(algo_name=algo_name, crit_name='neg_elbo', mode=mode)
    reconstruction_loss = get_losses(algo_name=algo_name, crit_name='reconstruction', mode=mode)

    kl = [nelbo - recon_loss for (nelbo, recon_loss) in zip(neg_elbo, reconstruction_loss)]
    
    n_epochs = len(kl)
    epochs = range(n_epochs)
    to_epoch = min(to_epoch, n_epochs)

    label = f'{algo_strings[algo_name]}: {train_val_strings[mode]} KL prior'
   
    if not dashes:
        ax.plot(epochs[from_epoch:to_epoch], kl[from_epoch:to_epoch], 
                label=label, color=color)
    else:
        ax.plot(epochs[from_epoch:to_epoch], kl[from_epoch:to_epoch], 
                label=label, color=color, dashes=[2, 2, 2, 2])
    ax.set_xlabel('epochs')
    return ax

# %%
def get_losses(algo_name='vae', crit_name='neg_elbo', mode='train'):
    losses_path = glob.glob(f'{OUTPUT}/train_{algo_name}/{mode}_losses.pkl')
    if len(losses_path) == 0:
        ckpts = glob.glob(f'{OUTPUT}/train_{algo_name}/models/epoch_*_checkpoint.pth')
        if len(ckpts) == 0:
            print(f'{algo_strings[algo_name]}: No {mode}_losses.pkl found. No checkpoints found.')
        else:
            ckpts_ids_and_paths = [(int(f.split('_')[2]), f) for f in ckpts]
            ckpt_id, ckpt_path = max(
                ckpts_ids_and_paths, key=lambda item: item[0])
            print('Found checkpoints. Getting: %s.' % ckpt_path)
            ckpt = torch.load(ckpt_path, map_location=DEVICE)
            
            losses = ckpt[f'{mode}_losses']
            losses = [loss[crit_name] for loss in losses]

    else:
        losses_path = glob.glob(f'{OUTPUT}/train_{algo_name}/{mode}_losses.pkl')[0]
        losses = pickle.load(open(losses_path, 'rb'))
        losses = [loss[crit_name] for loss in losses]
    return losses

# %%
def plot_criterion(ax, algo_name='vae', crit_name='neg_elbo', mode='train', 
                   from_epoch=0, to_epoch=1000, color='blue', dashes=False):
    if crit_name == 'kl_post':
        return plot_kl_posterior(
            ax=ax, algo_name=algo_name, mode=mode, 
            from_epoch=from_epoch, to_epoch=to_epoch, color=color, dashes=dashes)
    if crit_name == 'kl_prior':
        return plot_kl_prior(
            ax=ax, algo_name=algo_name, mode=mode, 
            from_epoch=from_epoch, to_epoch=to_epoch, color=color, dashes=dashes)
    
    losses_total = get_losses(algo_name=algo_name, crit_name=crit_name, mode=mode)
    
    n_epochs = len(losses_total)
    epochs = range(n_epochs)
    to_epoch = min(to_epoch, n_epochs)
    
    label = f'{algo_strings[algo_name]}: {train_val_strings[mode]} {crit_strings[crit_name]}'
   
    if not dashes:
        ax.plot(epochs[from_epoch:to_epoch], losses_total[from_epoch:to_epoch], 
                label=label, color=color)
    else:
        ax.plot(epochs[from_epoch:to_epoch], losses_total[from_epoch:to_epoch], 
                label=label, color=color, dashes=[2, 2, 2, 2])
    ax.set_xlabel('epochs')
    ax.legend()
    return ax

# %% [markdown]
# # Comparison of Convergences

# %%
from_epoch = 0
to_epoch = 20

# %%
def plot_convergence(ax, algo_name, crit_name):
    ax = plot_criterion(ax, algo_name=algo_name, crit_name=crit_name, mode='train', 
                    from_epoch=from_epoch, to_epoch=to_epoch, color=crit_color_dict[crit_name])
    ax = plot_criterion(ax, algo_name=algo_name, crit_name=crit_name, mode='val', 
                    from_epoch=from_epoch, to_epoch=to_epoch, color=crit_color_dict[crit_name], dashes=True)
    ax.set_title(f'Convergence of {algo_strings[algo_name]}.')
    return ax

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(18, 4))

ax = axes[0]
ax = plot_convergence(ax, 'vae', 'neg_elbo')

ax = axes[1]
ax = plot_convergence(ax, 'iwae', 'neg_iwelbo')

ax = axes[2]
ax = plot_convergence(ax, 'vem', 'neg_elbo')
ax = axes[3]
ax = plot_convergence(ax, 'vem', 'neg_iwelbo')

# %%
def plot_nll(ax, algo_name):
    # ax = plot_criterion(ax, algo_name=algo_name, crit_name='neg_loglikelihood', mode='train', 
    #                from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name])
    ax = plot_criterion(ax, algo_name=algo_name, crit_name='neg_loglikelihood', mode='val', 
                    from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name], dashes=True)
    return ax

def plot_kl_prior_all(ax, algo_name):
    # ax = plot_kl_posterior(ax, algo_name=algo_name, mode='train',
    #                   from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name], dashes=False)
    ax = plot_criterion(ax, algo_name=algo_name, crit_name='kl_prior', mode='val',
                      from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name], dashes=True)
    
    return ax

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 4))

ax = axes[0]
ax = plot_nll(ax, 'vae')
ax = plot_nll(ax, 'iwae')
ax = plot_nll(ax, 'vem')
ax.set_title('Valid NLL (estimated)')

ax = axes[1]
ax = plot_kl(ax, 'vae')
ax = plot_kl(ax, 'iwae')
ax = plot_kl(ax, 'vem')
ax.set_title('Valid KL to posterior (estimated)')
ax.legend()

ax = axes[2]
ax = plot_kl_prior_all(ax, 'vae')
ax = plot_kl_prior_all(ax, 'iwae')
ax = plot_kl_prior_all(ax, 'vem')
ax.set_title('Valid KL to prior (estimated)')
ax.legend()

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(18, 4))

ax = axes[0]
ax = plot_convergence(ax, 'vem', 'neg_elbo')
ax = axes[1]
ax = plot_convergence(ax, 'vem', 'neg_iwelbo')

ax = axes[2]
ax = plot_nll(ax, 'vae')
ax = plot_nll(ax, 'iwae')
ax = plot_nll(ax, 'vem')
ax.set_title('Valid NLL (estimated)')

ax = axes[3]
ax = plot_kl(ax, 'vae')
ax = plot_kl(ax, 'iwae')
ax = plot_kl(ax, 'vem')
ax.set_title('Valid KL to posterior (estimated)')
ax.legend()

# %% [markdown]
# # Inspect latent spaces

# %%
def load_module(algo_name='vae', module_name='encoder'):
    module_path = glob.glob(f'{OUTPUT}/train_{algo_name}/models/{module_name}.pth')
    if len(module_path) == 0:
        ckpts = glob.glob(f'{OUTPUT}/train_{algo_name}/models/epoch_*_checkpoint.pth')
        if len(ckpts) == 0:
            print('No module found. No checkpoints found.')
        else:
            ckpts_ids_and_paths = [(int(f.split('_')[2]), f) for f in ckpts]
            ckpt_id, ckpt_path = max(
                ckpts_ids_and_paths, key=lambda item: item[0])
            print('Found checkpoints. Getting: %s.' % ckpt_path)
            ckpt = torch.load(ckpt_path, map_location=DEVICE)
            
            vae = imnn.VAE(
                latent_dim=LATENT_DIM,
                data_dim=DATA_DIM)
            vae.to(DEVICE)

            modules = {}
            modules['encoder'] = vae.encoder
            modules['decoder'] = vae.decoder
            module = modules[module_name]
            module_ckpt = ckpt[module_name]
            module.load_state_dict(module_ckpt['module_state_dict'])   
        
    else:
        module_path = module_path[0]
        print('Loading: %s' % module_path)
        module = torch.load(module_path, map_location=DEVICE)
    return module

# %%
m = load_module()
print(m)
# Out:
# Loading: /scratch/users/nmiolane/imoutput_nips_omniglot20/train_vae/models/encoder.pth
# Encoder(
#   (fc1): Linear(in_features=784, out_features=400, bias=True)
#   (fc21): Linear(in_features=400, out_features=20, bias=True)
#   (fc22): Linear(in_features=400, out_features=20, bias=True)
# )

# %%
def latent_space_pca(val_dataset, n_components, algo_name='vae'):
    encoder = load_module(algo_name, 'encoder')

    mus = []
    
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=BATCH_SIZE, shuffle=False, **KWARGS)
    for i, data in enumerate(val_loader):
        data = data[0].to(DEVICE)
        data = data.view(-1, 784)
        mu, logvar = encoder(data)
        mu = np.array(mu.cpu().detach())
        mus.append(mu)

    mus = np.vstack(mus).squeeze()

    pca = PCA(n_components=n_components)
    pca.fit(mus)
    projected_mus = pca.transform(mus)
    return projected_mus

# %%
def plot_pca(ax, val_dataset, algo_name='vae'):
    projected_mus = latent_space_pca(val_dataset, n_components=2, algo_name=algo_name)
    val_labels = val_dataset.test_labels
    colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                     '#f781bf', '#a65628', '#984ea3',
                                      '#999999', '#e41a1c', '#dede00']),
                                      int(max(val_labels) + 1))))
    # add black color for outliers (if any)
    colors = np.append(colors, ["#000000"])
    sc = ax.scatter(projected_mus[:, 0], projected_mus[:, 1], s=10, color=colors[val_labels])
    #legend = ax.legend(*sc.legend_elements(), title='Labels')
    #ax.add_artist(legend)
    #ax.legend()
    ax.set_title(algo_strings[algo_name])
    return ax

# %%
BATCH_SIZE = 32
KWARGS = {'num_workers': 1, 'pin_memory': True} if CUDA else {}

test_dataset = datasets.Omniglot(
    '../data', download=True, transform=transforms.ToTensor())


fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 4))

ax = axes[0]
ax = plot_pca(ax, val_dataset, 'vae')

ax = axes[1]
ax = plot_pca(ax, val_dataset, 'iwae')

ax = axes[2]
ax = plot_pca(ax, val_dataset, 'vem')
# Out:
# Downloading https://github.com/brendenlake/omniglot/raw/master/python/images_background.zip to ../data/omniglot-py/images_background.zip
# Failed download. Trying https -> http instead. Downloading http://github.com/brendenlake/omniglot/raw/master/python/images_background.zip to ../data/omniglot-py/images_background.zip
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torchvision/datasets/utils.py in download_url(url, root, filename, md5)
#      40             print('Downloading ' + url + ' to ' + fpath)
# ---> 41             urllib.request.urlretrieve(url, fpath)
#      42         except:
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 503: first byte timeout
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-992c98341074> in <module>
#       3
#       4 test_dataset = datasets.Omniglot(
# ----> 5     '../data', download=True, transform=transforms.ToTensor())
#       6
#       7
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torchvision/datasets/omniglot.py in __init__(self, root, background, transform, target_transform, download)
#      38
#      39         if download:
# ---> 40             self.download()
#      41
#      42         if not self._check_integrity():
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torchvision/datasets/omniglot.py in download(self)
#      91         zip_filename = filename + '.zip'
#      92         url = self.download_url_prefix + '/' + zip_filename
# ---> 93         download_url(url, self.root, zip_filename, self.zips_md5[filename])
#      94         print('Extracting downloaded file: ' + join(self.root, zip_filename))
#      95         with zipfile.ZipFile(join(self.root, zip_filename), 'r') as zip_file:
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torchvision/datasets/utils.py in download_url(url, root, filename, md5)
#      45                 print('Failed download. Trying https -> http instead.'
#      46                       ' Downloading ' + url + ' to ' + fpath)
# ---> 47                 urllib.request.urlretrieve(url, fpath)
#      48
#      49
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/miniconda/envs/py36/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: first byte timeout

# %% [markdown]
# # Inspect active units

# %% [markdown]
# # Inspect generated samples

# %%
fig = plt.figure(figsize=(18, 6))
outer = gridspec.GridSpec(1, 3, wspace=0.1, hspace=0.1)

for i, algo_name in enumerate(['vae', 'iwae', 'vem']):
    toyvis.show_samples(OUTPUT, fig, outer, i, algo_name, latent_dim=LATENT_DIM, data_dim=DATA_DIM)
fig.show()
# Out:
# Loading: /scratch/users/nmiolane/imoutput_nips_omniglot10/train_vae/models/decoder.pth
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-5c6acec2616b> in <module>
#       3
#       4 for i, algo_name in enumerate(['vae', 'iwae', 'vem']):
# ----> 5     toyvis.show_samples(OUTPUT, fig, outer, i, algo_name, latent_dim=LATENT_DIM, data_dim=DATA_DIM)
#       6 fig.show()
#
# /home/nina/code/vaetree/toyvis.py in show_samples(output_dir, fig, outer, i, algo_name, latent_dim, data_dim, sqrt_n_samples)
#     513     z_from_prior = imnn.sample_from_prior(
#     514         latent_dim=latent_dim, n_samples=n_samples)
# --> 515     x_recon, _ = decoder(z_from_prior)
#     516     x_recon = x_recon.cpu().detach().numpy()
#     517
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /home/nina/code/vaetree/imnn.py in forward(self, z)
#     108
#     109     def forward(self, z):
# --> 110         h3 = F.relu(self.fc3(z))
#     111         recon_x =  torch.sigmoid(self.fc4(h3))
#     112         #h3 = self.leakyrelu(self.fc3(z))
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      65     @weak_script_method
#      66     def forward(self, input):
# ---> 67         return F.linear(input, self.weight, self.bias)
#      68
#      69     def extra_repr(self):
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1350     if input.dim() == 2 and bias is not None:
#    1351         # fused op is marginally faster
# -> 1352         ret = torch.addmm(torch.jit._unwrap_optional(bias), input, weight.t())
#    1353     else:
#    1354         output = input.matmul(weight.t())
#
# RuntimeError: size mismatch, m1: [100 x 10], m2: [20 x 400] at /opt/conda/conda-bld/pytorch_1544174967633/work/aten/src/THC/generic/THCTensorMathBlas.cu:266

# %% [markdown]
# # Comparison of times

# %%
def print_average_time(algo_name='vae'):
    losses_path = glob.glob(f'{OUTPUT}/train_{algo_name}/train_losses.pkl')[0]
    losses_all_epochs = pickle.load(open(losses_path, 'rb'))
    
    times = [loss['total_time'] for loss in losses_all_epochs]
    print(np.mean(times))
    
print_average_time('vae')
print_average_time('iwae')
print_average_time('vem')
# Out:
# 2.7169014549255373
# 4.04880124092102
# 6.174043731689453

# %% [markdown]
# # Print pipeline logs

# %%
pattern = 'logs'
logs = []
for filename in os.listdir(OUTPUT):
    if re.search(pattern, filename):
        logs.append(filename)

print('Found %d log files.' % len(logs))
        
for filename in logs:
    path = os.path.join(OUTPUT, filename)
    print('\n-- Log file: %s\n' % filename)
    with open(path, 'r') as f:
        message = f.read()
    print(message)
# Out:
# Found 2 log files.
#
# -- Log file: logs2019-05-23 16:39:16.178793.txt
#
# 2019-05-23 16:39:16,178 root         INFO     start
# 2019-05-23 16:39:16,193 luigi        INFO     logging configured by default settings
# 2019-05-23 16:39:16,222 luigi-interface DEBUG    Checking if RunAll() is complete
# 2019-05-23 16:39:16,222 luigi-interface DEBUG    Checking if Report() is complete
# 2019-05-23 16:39:16,223 luigi-interface INFO     Informed scheduler that task   RunAll__99914b932b   has status   PENDING
# 2019-05-23 16:39:16,223 luigi-interface DEBUG    Checking if TrainVAE() is complete
# 2019-05-23 16:39:16,224 luigi-interface DEBUG    Checking if TrainIWAE() is complete
# 2019-05-23 16:39:16,224 luigi-interface DEBUG    Checking if TrainVEM() is complete
# 2019-05-23 16:39:16,224 luigi-interface INFO     Informed scheduler that task   Report__99914b932b   has status   PENDING
# 2019-05-23 16:39:16,225 luigi-interface INFO     Informed scheduler that task   TrainVEM__99914b932b   has status   PENDING
# 2019-05-23 16:39:16,225 luigi-interface INFO     Informed scheduler that task   TrainIWAE__99914b932b   has status   PENDING
# 2019-05-23 16:39:16,225 luigi-interface INFO     Informed scheduler that task   TrainVAE__99914b932b   has status   PENDING
# 2019-05-23 16:39:16,225 luigi-interface INFO     Done scheduling tasks
# 2019-05-23 16:39:16,225 luigi-interface INFO     Running Worker with 1 processes
# 2019-05-23 16:39:16,226 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-23 16:39:16,226 luigi-interface DEBUG    Pending tasks: 5
# 2019-05-23 16:39:16,226 luigi-interface INFO     [pid 4688] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=4688) running   TrainVEM()
# 2019-05-23 16:39:20,456 root         INFO     No checkpoints found. Initializing with Xavier Normal.
# 2019-05-23 16:39:20,598 root         INFO     Train Epoch: 0 [0/15424 (0%)]	Batch Neg ELBO: 816.408264	Batch Neg IWELBO: 811.3829
# 2019-05-23 16:39:21,116 root         INFO     Train Epoch: 0 [1280/15424 (8%)]	Batch Neg ELBO: 769.541687	Batch Neg IWELBO: 767.8358
# 2019-05-23 16:39:21,614 root         INFO     Train Epoch: 0 [2560/15424 (17%)]	Batch Neg ELBO: 753.992737	Batch Neg IWELBO: 750.2846
# 2019-05-23 16:39:22,113 root         INFO     Train Epoch: 0 [3840/15424 (25%)]	Batch Neg ELBO: 750.015686	Batch Neg IWELBO: 744.4003
# 2019-05-23 16:39:22,612 root         INFO     Train Epoch: 0 [5120/15424 (33%)]	Batch Neg ELBO: 745.235718	Batch Neg IWELBO: 744.6359
# 2019-05-23 16:39:23,115 root         INFO     Train Epoch: 0 [6400/15424 (41%)]	Batch Neg ELBO: 741.242249	Batch Neg IWELBO: 741.0952
# 2019-05-23 16:39:23,621 root         INFO     Train Epoch: 0 [7680/15424 (50%)]	Batch Neg ELBO: 740.051453	Batch Neg IWELBO: 738.7336
# 2019-05-23 16:39:24,128 root         INFO     Train Epoch: 0 [8960/15424 (58%)]	Batch Neg ELBO: 743.974426	Batch Neg IWELBO: 739.0514
# 2019-05-23 16:39:24,636 root         INFO     Train Epoch: 0 [10240/15424 (66%)]	Batch Neg ELBO: 741.311829	Batch Neg IWELBO: 738.3821
# 2019-05-23 16:39:25,134 root         INFO     Train Epoch: 0 [11520/15424 (75%)]	Batch Neg ELBO: 740.151672	Batch Neg IWELBO: 737.7671
# 2019-05-23 16:39:25,636 root         INFO     Train Epoch: 0 [12800/15424 (83%)]	Batch Neg ELBO: 735.775879	Batch Neg IWELBO: 735.3501
# 2019-05-23 16:39:26,149 root         INFO     Train Epoch: 0 [14080/15424 (91%)]	Batch Neg ELBO: 740.931702	Batch Neg IWELBO: 737.3121
# 2019-05-23 16:39:26,643 root         INFO     Train Epoch: 0 [15360/15424 (99%)]	Batch Neg ELBO: 735.673340	Batch Neg IWELBO: 737.2302
# 2019-05-23 16:39:26,692 root         INFO     ====> Epoch: 0 Average Neg ELBO: 747.7261Average Neg IWELBO: 745.9010
# 2019-05-23 16:39:26,784 root         INFO     Val Epoch: 0 [0/3856 (0%)]	Batch Neg ELBO: 738.152832	Batch Neg IWELBO: 736.0179
# 2019-05-23 16:39:30,184 root         INFO     Val Epoch: 0 [1280/3856 (33%)]	Batch Neg ELBO: 739.012878	Batch Neg IWELBO: 738.3928
# 2019-05-23 16:39:33,581 root         INFO     Val Epoch: 0 [2560/3856 (66%)]	Batch Neg ELBO: 739.918274	Batch Neg IWELBO: 736.4601
# 2019-05-23 16:39:36,977 root         INFO     Val Epoch: 0 [3072/3856 (99%)]	Batch Neg ELBO: 740.125488	Batch Neg IWELBO: 738.1273
# 2019-05-23 16:39:37,004 root         INFO     ====> Val Epoch: 0 Average Negative ELBO: 739.5511Average IWAE: 737.6783
# 2019-05-23 16:39:37,056 root         INFO     Train Epoch: 1 [0/15424 (0%)]	Batch Neg ELBO: 740.892944	Batch Neg IWELBO: 738.2902
# 2019-05-23 16:39:37,556 root         INFO     Train Epoch: 1 [1280/15424 (8%)]	Batch Neg ELBO: 741.492432	Batch Neg IWELBO: 737.1918
# 2019-05-23 16:39:38,052 root         INFO     Train Epoch: 1 [2560/15424 (17%)]	Batch Neg ELBO: 738.360413	Batch Neg IWELBO: 737.4946
# 2019-05-23 16:39:38,558 root         INFO     Train Epoch: 1 [3840/15424 (25%)]	Batch Neg ELBO: 739.903137	Batch Neg IWELBO: 737.6180
# 2019-05-23 16:39:39,059 root         INFO     Train Epoch: 1 [5120/15424 (33%)]	Batch Neg ELBO: 739.344299	Batch Neg IWELBO: 737.3271
# 2019-05-23 16:39:39,559 root         INFO     Train Epoch: 1 [6400/15424 (41%)]	Batch Neg ELBO: 740.883789	Batch Neg IWELBO: 737.3646
# 2019-05-23 16:39:40,062 root         INFO     Train Epoch: 1 [7680/15424 (50%)]	Batch Neg ELBO: 735.391357	Batch Neg IWELBO: 734.0118
# 2019-05-23 16:39:40,559 root         INFO     Train Epoch: 1 [8960/15424 (58%)]	Batch Neg ELBO: 738.048218	Batch Neg IWELBO: 734.5290
# 2019-05-23 16:39:41,056 root         INFO     Train Epoch: 1 [10240/15424 (66%)]	Batch Neg ELBO: 737.832397	Batch Neg IWELBO: 735.7868
# 2019-05-23 16:39:41,576 root         INFO     Train Epoch: 1 [11520/15424 (75%)]	Batch Neg ELBO: 738.153625	Batch Neg IWELBO: 737.1286
# 2019-05-23 16:39:42,077 root         INFO     Train Epoch: 1 [12800/15424 (83%)]	Batch Neg ELBO: 737.251648	Batch Neg IWELBO: 735.5706
# 2019-05-23 16:39:42,579 root         INFO     Train Epoch: 1 [14080/15424 (91%)]	Batch Neg ELBO: 742.318420	Batch Neg IWELBO: 738.3139
# 2019-05-23 16:39:43,091 root         INFO     Train Epoch: 1 [15360/15424 (99%)]	Batch Neg ELBO: 738.448120	Batch Neg IWELBO: 737.2197
# 2019-05-23 16:39:43,140 root         INFO     ====> Epoch: 1 Average Neg ELBO: 739.1539Average Neg IWELBO: 737.1159
# 2019-05-23 16:39:43,230 root         INFO     Val Epoch: 1 [0/3856 (0%)]	Batch Neg ELBO: 744.746887	Batch Neg IWELBO: 736.8334
# 2019-05-23 16:39:46,642 root         INFO     Val Epoch: 1 [1280/3856 (33%)]	Batch Neg ELBO: 735.932617	Batch Neg IWELBO: 733.5270
# 2019-05-23 16:39:50,076 root         INFO     Val Epoch: 1 [2560/3856 (66%)]	Batch Neg ELBO: 738.058228	Batch Neg IWELBO: 737.7734
# 2019-05-23 16:39:53,477 root         INFO     Val Epoch: 1 [3072/3856 (99%)]	Batch Neg ELBO: 737.230591	Batch Neg IWELBO: 737.7573
# 2019-05-23 16:39:53,504 root         INFO     ====> Val Epoch: 1 Average Negative ELBO: 738.4982Average IWAE: 736.5267
# 2019-05-23 16:39:53,556 root         INFO     Train Epoch: 2 [0/15424 (0%)]	Batch Neg ELBO: 740.149902	Batch Neg IWELBO: 737.2545
# 2019-05-23 16:39:54,063 root         INFO     Train Epoch: 2 [1280/15424 (8%)]	Batch Neg ELBO: 735.960876	Batch Neg IWELBO: 735.9641
# 2019-05-23 16:39:54,562 root         INFO     Train Epoch: 2 [2560/15424 (17%)]	Batch Neg ELBO: 736.857666	Batch Neg IWELBO: 735.9255
# 2019-05-23 16:39:55,063 root         INFO     Train Epoch: 2 [3840/15424 (25%)]	Batch Neg ELBO: 737.616699	Batch Neg IWELBO: 737.3480
# 2019-05-23 16:39:55,566 root         INFO     Train Epoch: 2 [5120/15424 (33%)]	Batch Neg ELBO: 740.215027	Batch Neg IWELBO: 736.6044
# 2019-05-23 16:39:56,073 root         INFO     Train Epoch: 2 [6400/15424 (41%)]	Batch Neg ELBO: 736.682922	Batch Neg IWELBO: 736.7830
# 2019-05-23 16:39:56,579 root         INFO     Train Epoch: 2 [7680/15424 (50%)]	Batch Neg ELBO: 740.049316	Batch Neg IWELBO: 736.6324
# 2019-05-23 16:39:57,083 root         INFO     Train Epoch: 2 [8960/15424 (58%)]	Batch Neg ELBO: 740.904480	Batch Neg IWELBO: 738.2333
# 2019-05-23 16:39:57,591 root         INFO     Train Epoch: 2 [10240/15424 (66%)]	Batch Neg ELBO: 738.292664	Batch Neg IWELBO: 737.2145
# 2019-05-23 16:39:58,095 root         INFO     Train Epoch: 2 [11520/15424 (75%)]	Batch Neg ELBO: 737.497925	Batch Neg IWELBO: 738.0975
# 2019-05-23 16:39:58,604 root         INFO     Train Epoch: 2 [12800/15424 (83%)]	Batch Neg ELBO: 739.281067	Batch Neg IWELBO: 736.9745
# 2019-05-23 16:39:59,112 root         INFO     Train Epoch: 2 [14080/15424 (91%)]	Batch Neg ELBO: 738.083008	Batch Neg IWELBO: 735.6954
# 2019-05-23 16:39:59,617 root         INFO     Train Epoch: 2 [15360/15424 (99%)]	Batch Neg ELBO: 739.258301	Batch Neg IWELBO: 736.7687
# 2019-05-23 16:39:59,666 root         INFO     ====> Epoch: 2 Average Neg ELBO: 738.0267Average Neg IWELBO: 736.4385
# 2019-05-23 16:39:59,756 root         INFO     Val Epoch: 2 [0/3856 (0%)]	Batch Neg ELBO: 739.682861	Batch Neg IWELBO: 735.9301
# 2019-05-23 16:40:03,191 root         INFO     Val Epoch: 2 [1280/3856 (33%)]	Batch Neg ELBO: 736.801880	Batch Neg IWELBO: 734.6481
# 2019-05-23 16:40:06,644 root         INFO     Val Epoch: 2 [2560/3856 (66%)]	Batch Neg ELBO: 735.731262	Batch Neg IWELBO: 736.7424
# 2019-05-23 16:40:10,055 root         INFO     Val Epoch: 2 [3072/3856 (99%)]	Batch Neg ELBO: 737.408447	Batch Neg IWELBO: 735.8938
# 2019-05-23 16:40:10,082 root         INFO     ====> Val Epoch: 2 Average Negative ELBO: 737.0336Average IWAE: 735.9884
# 2019-05-23 16:40:10,134 root         INFO     Train Epoch: 3 [0/15424 (0%)]	Batch Neg ELBO: 736.947144	Batch Neg IWELBO: 737.0815
# 2019-05-23 16:40:10,645 root         INFO     Train Epoch: 3 [1280/15424 (8%)]	Batch Neg ELBO: 738.807190	Batch Neg IWELBO: 736.7745
# 2019-05-23 16:40:11,156 root         INFO     Train Epoch: 3 [2560/15424 (17%)]	Batch Neg ELBO: 737.196960	Batch Neg IWELBO: 735.6902
# 2019-05-23 16:40:11,669 root         INFO     Train Epoch: 3 [3840/15424 (25%)]	Batch Neg ELBO: 740.458191	Batch Neg IWELBO: 737.5349
# 2019-05-23 16:40:12,178 root         INFO     Train Epoch: 3 [5120/15424 (33%)]	Batch Neg ELBO: 738.826965	Batch Neg IWELBO: 736.1285
# 2019-05-23 16:40:12,687 root         INFO     Train Epoch: 3 [6400/15424 (41%)]	Batch Neg ELBO: 736.271973	Batch Neg IWELBO: 736.1016
# 2019-05-23 16:40:13,193 root         INFO     Train Epoch: 3 [7680/15424 (50%)]	Batch Neg ELBO: 735.554382	Batch Neg IWELBO: 734.9265
# 2019-05-23 16:40:13,699 root         INFO     Train Epoch: 3 [8960/15424 (58%)]	Batch Neg ELBO: 735.942749	Batch Neg IWELBO: 735.7579
# 2019-05-23 16:40:14,207 root         INFO     Train Epoch: 3 [10240/15424 (66%)]	Batch Neg ELBO: 736.390625	Batch Neg IWELBO: 737.0854
# 2019-05-23 16:40:14,710 root         INFO     Train Epoch: 3 [11520/15424 (75%)]	Batch Neg ELBO: 737.188110	Batch Neg IWELBO: 738.6061
# 2019-05-23 16:40:15,216 root         INFO     Train Epoch: 3 [12800/15424 (83%)]	Batch Neg ELBO: 735.976318	Batch Neg IWELBO: 736.0630
# 2019-05-23 16:40:15,719 root         INFO     Train Epoch: 3 [14080/15424 (91%)]	Batch Neg ELBO: 733.989075	Batch Neg IWELBO: 735.0750
# 2019-05-23 16:40:16,222 root         INFO     Train Epoch: 3 [15360/15424 (99%)]	Batch Neg ELBO: 735.466431	Batch Neg IWELBO: 735.3066
# 2019-05-23 16:40:16,271 root         INFO     ====> Epoch: 3 Average Neg ELBO: 736.4336Average Neg IWELBO: 735.8952
# 2019-05-23 16:40:16,361 root         INFO     Val Epoch: 3 [0/3856 (0%)]	Batch Neg ELBO: 738.410645	Batch Neg IWELBO: 736.5558
# 2019-05-23 16:40:19,778 root         INFO     Val Epoch: 3 [1280/3856 (33%)]	Batch Neg ELBO: 738.505432	Batch Neg IWELBO: 733.5920
# 2019-05-23 16:40:23,197 root         INFO     Val Epoch: 3 [2560/3856 (66%)]	Batch Neg ELBO: 737.220215	Batch Neg IWELBO: 735.6147
# 2019-05-23 16:40:26,608 root         INFO     Val Epoch: 3 [3072/3856 (99%)]	Batch Neg ELBO: 736.587219	Batch Neg IWELBO: 736.7628
# 2019-05-23 16:40:26,635 root         INFO     ====> Val Epoch: 3 Average Negative ELBO: 735.8855Average IWAE: 735.5179
# 2019-05-23 16:40:26,687 root         INFO     Train Epoch: 4 [0/15424 (0%)]	Batch Neg ELBO: 735.440369	Batch Neg IWELBO: 735.4190
# 2019-05-23 16:40:27,196 root         INFO     Train Epoch: 4 [1280/15424 (8%)]	Batch Neg ELBO: 738.382874	Batch Neg IWELBO: 736.7296
# 2019-05-23 16:40:27,696 root         INFO     Train Epoch: 4 [2560/15424 (17%)]	Batch Neg ELBO: 738.102234	Batch Neg IWELBO: 735.3064
# 2019-05-23 16:40:28,195 root         INFO     Train Epoch: 4 [3840/15424 (25%)]	Batch Neg ELBO: 734.461548	Batch Neg IWELBO: 733.6178
# 2019-05-23 16:40:28,693 root         INFO     Train Epoch: 4 [5120/15424 (33%)]	Batch Neg ELBO: 737.002441	Batch Neg IWELBO: 737.1678
# 2019-05-23 16:40:29,190 root         INFO     Train Epoch: 4 [6400/15424 (41%)]	Batch Neg ELBO: 737.234070	Batch Neg IWELBO: 735.2799
# 2019-05-23 16:40:29,686 root         INFO     Train Epoch: 4 [7680/15424 (50%)]	Batch Neg ELBO: 735.773010	Batch Neg IWELBO: 736.2091
# 2019-05-23 16:40:30,181 root         INFO     Train Epoch: 4 [8960/15424 (58%)]	Batch Neg ELBO: 735.014099	Batch Neg IWELBO: 734.9406
# 2019-05-23 16:40:30,677 root         INFO     Train Epoch: 4 [10240/15424 (66%)]	Batch Neg ELBO: 733.038757	Batch Neg IWELBO: 733.3875
# 2019-05-23 16:40:31,183 root         INFO     Train Epoch: 4 [11520/15424 (75%)]	Batch Neg ELBO: 734.563110	Batch Neg IWELBO: 735.2026
# 2019-05-23 16:40:31,689 root         INFO     Train Epoch: 4 [12800/15424 (83%)]	Batch Neg ELBO: 738.231934	Batch Neg IWELBO: 738.0384
# 2019-05-23 16:40:32,192 root         INFO     Train Epoch: 4 [14080/15424 (91%)]	Batch Neg ELBO: 734.846375	Batch Neg IWELBO: 736.6738
# 2019-05-23 16:40:32,695 root         INFO     Train Epoch: 4 [15360/15424 (99%)]	Batch Neg ELBO: 738.610107	Batch Neg IWELBO: 736.7995
# 2019-05-23 16:40:32,744 root         INFO     ====> Epoch: 4 Average Neg ELBO: 735.9275Average Neg IWELBO: 735.7076
# 2019-05-23 16:40:32,834 root         INFO     Val Epoch: 4 [0/3856 (0%)]	Batch Neg ELBO: 735.519226	Batch Neg IWELBO: 734.6654
# 2019-05-23 16:40:36,266 root         INFO     Val Epoch: 4 [1280/3856 (33%)]	Batch Neg ELBO: 735.026367	Batch Neg IWELBO: 735.0635
# 2019-05-23 16:40:39,738 root         INFO     Val Epoch: 4 [2560/3856 (66%)]	Batch Neg ELBO: 737.191589	Batch Neg IWELBO: 735.5794
# 2019-05-23 16:40:43,237 root         INFO     Val Epoch: 4 [3072/3856 (99%)]	Batch Neg ELBO: 734.289917	Batch Neg IWELBO: 735.2087
# 2019-05-23 16:40:43,264 root         INFO     ====> Val Epoch: 4 Average Negative ELBO: 735.7033Average IWAE: 735.5746
# 2019-05-23 16:40:43,316 root         INFO     Train Epoch: 5 [0/15424 (0%)]	Batch Neg ELBO: 737.302673	Batch Neg IWELBO: 735.4118
# 2019-05-23 16:40:43,826 root         INFO     Train Epoch: 5 [1280/15424 (8%)]	Batch Neg ELBO: 737.072144	Batch Neg IWELBO: 737.2239
# 2019-05-23 16:40:44,332 root         INFO     Train Epoch: 5 [2560/15424 (17%)]	Batch Neg ELBO: 735.615967	Batch Neg IWELBO: 736.7053
# 2019-05-23 16:40:44,839 root         INFO     Train Epoch: 5 [3840/15424 (25%)]	Batch Neg ELBO: 736.846924	Batch Neg IWELBO: 735.8975
# 2019-05-23 16:40:45,346 root         INFO     Train Epoch: 5 [5120/15424 (33%)]	Batch Neg ELBO: 735.344482	Batch Neg IWELBO: 734.7591
# 2019-05-23 16:40:45,851 root         INFO     Train Epoch: 5 [6400/15424 (41%)]	Batch Neg ELBO: 735.111511	Batch Neg IWELBO: 735.5053
# 2019-05-23 16:40:46,355 root         INFO     Train Epoch: 5 [7680/15424 (50%)]	Batch Neg ELBO: 735.993103	Batch Neg IWELBO: 736.2034
# 2019-05-23 16:40:46,862 root         INFO     Train Epoch: 5 [8960/15424 (58%)]	Batch Neg ELBO: 736.010864	Batch Neg IWELBO: 735.1241
# 2019-05-23 16:40:47,363 root         INFO     Train Epoch: 5 [10240/15424 (66%)]	Batch Neg ELBO: 734.828552	Batch Neg IWELBO: 734.8519
# 2019-05-23 16:40:47,860 root         INFO     Train Epoch: 5 [11520/15424 (75%)]	Batch Neg ELBO: 734.750732	Batch Neg IWELBO: 736.1160
# 2019-05-23 16:40:48,358 root         INFO     Train Epoch: 5 [12800/15424 (83%)]	Batch Neg ELBO: 736.617065	Batch Neg IWELBO: 735.3588
# 2019-05-23 16:40:48,858 root         INFO     Train Epoch: 5 [14080/15424 (91%)]	Batch Neg ELBO: 737.176636	Batch Neg IWELBO: 736.0710
# 2019-05-23 16:40:49,357 root         INFO     Train Epoch: 5 [15360/15424 (99%)]	Batch Neg ELBO: 735.366455	Batch Neg IWELBO: 735.6957
# 2019-05-23 16:40:49,405 root         INFO     ====> Epoch: 5 Average Neg ELBO: 735.8291Average Neg IWELBO: 735.6912
# 2019-05-23 16:40:49,497 root         INFO     Val Epoch: 5 [0/3856 (0%)]	Batch Neg ELBO: 738.954346	Batch Neg IWELBO: 734.3395
# 2019-05-23 16:40:53,005 root         INFO     Val Epoch: 5 [1280/3856 (33%)]	Batch Neg ELBO: 736.013123	Batch Neg IWELBO: 735.4710
# 2019-05-23 16:40:56,528 root         INFO     Val Epoch: 5 [2560/3856 (66%)]	Batch Neg ELBO: 735.303284	Batch Neg IWELBO: 736.6286
# 2019-05-23 16:41:00,042 root         INFO     Val Epoch: 5 [3072/3856 (99%)]	Batch Neg ELBO: 735.591797	Batch Neg IWELBO: 733.0297
# 2019-05-23 16:41:00,069 root         INFO     ====> Val Epoch: 5 Average Negative ELBO: 735.4769Average IWAE: 735.7326
# 2019-05-23 16:41:00,121 root         INFO     Train Epoch: 6 [0/15424 (0%)]	Batch Neg ELBO: 734.976868	Batch Neg IWELBO: 735.2158
# 2019-05-23 16:41:00,635 root         INFO     Train Epoch: 6 [1280/15424 (8%)]	Batch Neg ELBO: 734.664368	Batch Neg IWELBO: 736.0874
# 2019-05-23 16:41:01,148 root         INFO     Train Epoch: 6 [2560/15424 (17%)]	Batch Neg ELBO: 735.606201	Batch Neg IWELBO: 735.0185
# 2019-05-23 16:41:01,661 root         INFO     Train Epoch: 6 [3840/15424 (25%)]	Batch Neg ELBO: 734.761292	Batch Neg IWELBO: 736.1293
# 2019-05-23 16:41:02,174 root         INFO     Train Epoch: 6 [5120/15424 (33%)]	Batch Neg ELBO: 733.543518	Batch Neg IWELBO: 735.5891
# 2019-05-23 16:41:02,694 root         INFO     Train Epoch: 6 [6400/15424 (41%)]	Batch Neg ELBO: 736.114685	Batch Neg IWELBO: 734.8555
# 2019-05-23 16:41:03,220 root         INFO     Train Epoch: 6 [7680/15424 (50%)]	Batch Neg ELBO: 737.464905	Batch Neg IWELBO: 736.6937
# 2019-05-23 16:41:03,747 root         INFO     Train Epoch: 6 [8960/15424 (58%)]	Batch Neg ELBO: 735.805298	Batch Neg IWELBO: 734.7708
# 2019-05-23 16:41:04,269 root         INFO     Train Epoch: 6 [10240/15424 (66%)]	Batch Neg ELBO: 733.994873	Batch Neg IWELBO: 736.6662
# 2019-05-23 16:41:04,785 root         INFO     Train Epoch: 6 [11520/15424 (75%)]	Batch Neg ELBO: 737.456055	Batch Neg IWELBO: 735.5325
# 2019-05-23 16:41:05,295 root         INFO     Train Epoch: 6 [12800/15424 (83%)]	Batch Neg ELBO: 738.788635	Batch Neg IWELBO: 737.1323
# 2019-05-23 16:41:05,799 root         INFO     Train Epoch: 6 [14080/15424 (91%)]	Batch Neg ELBO: 735.198914	Batch Neg IWELBO: 734.6810
# 2019-05-23 16:41:06,312 root         INFO     Train Epoch: 6 [15360/15424 (99%)]	Batch Neg ELBO: 738.310852	Batch Neg IWELBO: 736.3643
# 2019-05-23 16:41:06,361 root         INFO     ====> Epoch: 6 Average Neg ELBO: 735.7842Average Neg IWELBO: 735.6834
# 2019-05-23 16:41:06,452 root         INFO     Val Epoch: 6 [0/3856 (0%)]	Batch Neg ELBO: 735.535217	Batch Neg IWELBO: 732.7730
# 2019-05-23 16:41:09,971 root         INFO     Val Epoch: 6 [1280/3856 (33%)]	Batch Neg ELBO: 739.350037	Batch Neg IWELBO: 734.2368
# 2019-05-23 16:41:13,485 root         INFO     Val Epoch: 6 [2560/3856 (66%)]	Batch Neg ELBO: 733.997009	Batch Neg IWELBO: 737.0428
# 2019-05-23 16:41:16,988 root         INFO     Val Epoch: 6 [3072/3856 (99%)]	Batch Neg ELBO: 737.833862	Batch Neg IWELBO: 731.8423
# 2019-05-23 16:41:17,015 root         INFO     ====> Val Epoch: 6 Average Negative ELBO: 735.5670Average IWAE: 735.6025
# 2019-05-23 16:41:17,067 root         INFO     Train Epoch: 7 [0/15424 (0%)]	Batch Neg ELBO: 735.917053	Batch Neg IWELBO: 735.3812
# 2019-05-23 16:41:17,585 root         INFO     Train Epoch: 7 [1280/15424 (8%)]	Batch Neg ELBO: 735.316101	Batch Neg IWELBO: 735.6994
# 2019-05-23 16:41:18,097 root         INFO     Train Epoch: 7 [2560/15424 (17%)]	Batch Neg ELBO: 734.594910	Batch Neg IWELBO: 734.9585
# 2019-05-23 16:41:18,611 root         INFO     Train Epoch: 7 [3840/15424 (25%)]	Batch Neg ELBO: 739.502686	Batch Neg IWELBO: 735.8149
# 2019-05-23 16:41:19,124 root         INFO     Train Epoch: 7 [5120/15424 (33%)]	Batch Neg ELBO: 735.083069	Batch Neg IWELBO: 735.3460
# 2019-05-23 16:41:19,636 root         INFO     Train Epoch: 7 [6400/15424 (41%)]	Batch Neg ELBO: 736.089417	Batch Neg IWELBO: 735.8658
# 2019-05-23 16:41:20,147 root         INFO     Train Epoch: 7 [7680/15424 (50%)]	Batch Neg ELBO: 735.627686	Batch Neg IWELBO: 735.6490
# 2019-05-23 16:41:20,659 root         INFO     Train Epoch: 7 [8960/15424 (58%)]	Batch Neg ELBO: 736.765930	Batch Neg IWELBO: 736.3001
# 2019-05-23 16:41:21,173 root         INFO     Train Epoch: 7 [10240/15424 (66%)]	Batch Neg ELBO: 736.991272	Batch Neg IWELBO: 735.6373
# 2019-05-23 16:41:21,684 root         INFO     Train Epoch: 7 [11520/15424 (75%)]	Batch Neg ELBO: 735.005737	Batch Neg IWELBO: 735.7370
# 2019-05-23 16:41:22,196 root         INFO     Train Epoch: 7 [12800/15424 (83%)]	Batch Neg ELBO: 736.229736	Batch Neg IWELBO: 736.8621
# 2019-05-23 16:41:22,708 root         INFO     Train Epoch: 7 [14080/15424 (91%)]	Batch Neg ELBO: 735.680664	Batch Neg IWELBO: 736.7968
# 2019-05-23 16:41:23,219 root         INFO     Train Epoch: 7 [15360/15424 (99%)]	Batch Neg ELBO: 733.605164	Batch Neg IWELBO: 735.3289
# 2019-05-23 16:41:23,269 root         INFO     ====> Epoch: 7 Average Neg ELBO: 735.7774Average Neg IWELBO: 735.6789
# 2019-05-23 16:41:23,360 root         INFO     Val Epoch: 7 [0/3856 (0%)]	Batch Neg ELBO: 736.283691	Batch Neg IWELBO: 736.9585
# 2019-05-23 16:41:26,875 root         INFO     Val Epoch: 7 [1280/3856 (33%)]	Batch Neg ELBO: 734.412231	Batch Neg IWELBO: 738.0712
# 2019-05-23 16:41:30,389 root         INFO     Val Epoch: 7 [2560/3856 (66%)]	Batch Neg ELBO: 735.969543	Batch Neg IWELBO: 736.2778
# 2019-05-23 16:41:33,899 root         INFO     Val Epoch: 7 [3072/3856 (99%)]	Batch Neg ELBO: 738.042847	Batch Neg IWELBO: 735.2917
# 2019-05-23 16:41:33,926 root         INFO     ====> Val Epoch: 7 Average Negative ELBO: 735.5469Average IWAE: 735.5778
# 2019-05-23 16:41:33,978 root         INFO     Train Epoch: 8 [0/15424 (0%)]	Batch Neg ELBO: 734.960449	Batch Neg IWELBO: 735.1831
# 2019-05-23 16:41:34,506 root         INFO     Train Epoch: 8 [1280/15424 (8%)]	Batch Neg ELBO: 735.068665	Batch Neg IWELBO: 733.5664
# 2019-05-23 16:41:35,039 root         INFO     Train Epoch: 8 [2560/15424 (17%)]	Batch Neg ELBO: 734.757446	Batch Neg IWELBO: 734.8664
# 2019-05-23 16:41:35,552 root         INFO     Train Epoch: 8 [3840/15424 (25%)]	Batch Neg ELBO: 734.501038	Batch Neg IWELBO: 734.8131
# 2019-05-23 16:41:36,064 root         INFO     Train Epoch: 8 [5120/15424 (33%)]	Batch Neg ELBO: 734.768311	Batch Neg IWELBO: 735.9945
# 2019-05-23 16:41:36,576 root         INFO     Train Epoch: 8 [6400/15424 (41%)]	Batch Neg ELBO: 736.345764	Batch Neg IWELBO: 736.0466
# 2019-05-23 16:41:37,095 root         INFO     Train Epoch: 8 [7680/15424 (50%)]	Batch Neg ELBO: 737.297363	Batch Neg IWELBO: 738.2739
# 2019-05-23 16:41:37,608 root         INFO     Train Epoch: 8 [8960/15424 (58%)]	Batch Neg ELBO: 736.157410	Batch Neg IWELBO: 734.8620
# 2019-05-23 16:41:38,121 root         INFO     Train Epoch: 8 [10240/15424 (66%)]	Batch Neg ELBO: 736.109192	Batch Neg IWELBO: 736.7148
# 2019-05-23 16:41:38,634 root         INFO     Train Epoch: 8 [11520/15424 (75%)]	Batch Neg ELBO: 737.054688	Batch Neg IWELBO: 736.4547
# 2019-05-23 16:41:39,146 root         INFO     Train Epoch: 8 [12800/15424 (83%)]	Batch Neg ELBO: 735.289612	Batch Neg IWELBO: 737.0874
# 2019-05-23 16:41:39,657 root         INFO     Train Epoch: 8 [14080/15424 (91%)]	Batch Neg ELBO: 735.353333	Batch Neg IWELBO: 733.9990
# 2019-05-23 16:41:40,166 root         INFO     Train Epoch: 8 [15360/15424 (99%)]	Batch Neg ELBO: 736.614685	Batch Neg IWELBO: 736.6293
# 2019-05-23 16:41:40,215 root         INFO     ====> Epoch: 8 Average Neg ELBO: 735.7771Average Neg IWELBO: 735.6750
# 2019-05-23 16:41:40,306 root         INFO     Val Epoch: 8 [0/3856 (0%)]	Batch Neg ELBO: 734.333801	Batch Neg IWELBO: 738.9047
# 2019-05-23 16:41:43,818 root         INFO     Val Epoch: 8 [1280/3856 (33%)]	Batch Neg ELBO: 736.110352	Batch Neg IWELBO: 735.1769
# 2019-05-23 16:41:47,327 root         INFO     Val Epoch: 8 [2560/3856 (66%)]	Batch Neg ELBO: 737.768677	Batch Neg IWELBO: 737.3695
# 2019-05-23 16:41:50,830 root         INFO     Val Epoch: 8 [3072/3856 (99%)]	Batch Neg ELBO: 735.745117	Batch Neg IWELBO: 735.9674
# 2019-05-23 16:41:50,858 root         INFO     ====> Val Epoch: 8 Average Negative ELBO: 735.5643Average IWAE: 735.5564
# 2019-05-23 16:41:50,910 root         INFO     Train Epoch: 9 [0/15424 (0%)]	Batch Neg ELBO: 736.245605	Batch Neg IWELBO: 737.2766
# 2019-05-23 16:41:51,416 root         INFO     Train Epoch: 9 [1280/15424 (8%)]	Batch Neg ELBO: 734.202515	Batch Neg IWELBO: 735.4311
# 2019-05-23 16:41:51,925 root         INFO     Train Epoch: 9 [2560/15424 (17%)]	Batch Neg ELBO: 738.319702	Batch Neg IWELBO: 737.3909
# 2019-05-23 16:41:52,437 root         INFO     Train Epoch: 9 [3840/15424 (25%)]	Batch Neg ELBO: 735.443420	Batch Neg IWELBO: 735.1036
# 2019-05-23 16:41:52,949 root         INFO     Train Epoch: 9 [5120/15424 (33%)]	Batch Neg ELBO: 736.395874	Batch Neg IWELBO: 735.5626
# 2019-05-23 16:41:53,461 root         INFO     Train Epoch: 9 [6400/15424 (41%)]	Batch Neg ELBO: 735.198181	Batch Neg IWELBO: 735.1783
# 2019-05-23 16:41:53,973 root         INFO     Train Epoch: 9 [7680/15424 (50%)]	Batch Neg ELBO: 737.369080	Batch Neg IWELBO: 735.6784
# 2019-05-23 16:41:54,482 root         INFO     Train Epoch: 9 [8960/15424 (58%)]	Batch Neg ELBO: 737.311646	Batch Neg IWELBO: 735.7050
# 2019-05-23 16:41:54,992 root         INFO     Train Epoch: 9 [10240/15424 (66%)]	Batch Neg ELBO: 738.907532	Batch Neg IWELBO: 736.2408
# 2019-05-23 16:41:55,500 root         INFO     Train Epoch: 9 [11520/15424 (75%)]	Batch Neg ELBO: 736.463318	Batch Neg IWELBO: 735.3508
# 2019-05-23 16:41:56,009 root         INFO     Train Epoch: 9 [12800/15424 (83%)]	Batch Neg ELBO: 735.673035	Batch Neg IWELBO: 735.8786
# 2019-05-23 16:41:56,517 root         INFO     Train Epoch: 9 [14080/15424 (91%)]	Batch Neg ELBO: 734.484375	Batch Neg IWELBO: 735.2610
# 2019-05-23 16:41:57,026 root         INFO     Train Epoch: 9 [15360/15424 (99%)]	Batch Neg ELBO: 737.309753	Batch Neg IWELBO: 736.8487
# 2019-05-23 16:41:57,075 root         INFO     ====> Epoch: 9 Average Neg ELBO: 735.7316Average Neg IWELBO: 735.6713
# 2019-05-23 16:41:57,168 root         INFO     Val Epoch: 9 [0/3856 (0%)]	Batch Neg ELBO: 737.726990	Batch Neg IWELBO: 733.5905
# 2019-05-23 16:42:00,679 root         INFO     Val Epoch: 9 [1280/3856 (33%)]	Batch Neg ELBO: 734.589172	Batch Neg IWELBO: 737.4380
# 2019-05-23 16:42:04,192 root         INFO     Val Epoch: 9 [2560/3856 (66%)]	Batch Neg ELBO: 735.635315	Batch Neg IWELBO: 734.6559
# 2019-05-23 16:42:07,698 root         INFO     Val Epoch: 9 [3072/3856 (99%)]	Batch Neg ELBO: 735.776672	Batch Neg IWELBO: 735.6686
# 2019-05-23 16:42:07,725 root         INFO     ====> Val Epoch: 9 Average Negative ELBO: 735.6186Average IWAE: 735.4948
# 2019-05-23 16:42:07,778 root         INFO     Train Epoch: 10 [0/15424 (0%)]	Batch Neg ELBO: 734.954651	Batch Neg IWELBO: 735.7872
# 2019-05-23 16:42:08,288 root         INFO     Train Epoch: 10 [1280/15424 (8%)]	Batch Neg ELBO: 733.951416	Batch Neg IWELBO: 734.6386
# 2019-05-23 16:42:08,793 root         INFO     Train Epoch: 10 [2560/15424 (17%)]	Batch Neg ELBO: 735.578735	Batch Neg IWELBO: 735.6337
# 2019-05-23 16:42:09,296 root         INFO     Train Epoch: 10 [3840/15424 (25%)]	Batch Neg ELBO: 737.240356	Batch Neg IWELBO: 736.3393
# 2019-05-23 16:42:09,799 root         INFO     Train Epoch: 10 [5120/15424 (33%)]	Batch Neg ELBO: 738.261597	Batch Neg IWELBO: 737.9628
# 2019-05-23 16:42:10,302 root         INFO     Train Epoch: 10 [6400/15424 (41%)]	Batch Neg ELBO: 737.193420	Batch Neg IWELBO: 736.7089
# 2019-05-23 16:42:10,808 root         INFO     Train Epoch: 10 [7680/15424 (50%)]	Batch Neg ELBO: 734.322571	Batch Neg IWELBO: 735.8769
# 2019-05-23 16:42:11,322 root         INFO     Train Epoch: 10 [8960/15424 (58%)]	Batch Neg ELBO: 736.172546	Batch Neg IWELBO: 737.2272
# 2019-05-23 16:42:11,837 root         INFO     Train Epoch: 10 [10240/15424 (66%)]	Batch Neg ELBO: 736.312683	Batch Neg IWELBO: 735.1971
# 2019-05-23 16:42:12,354 root         INFO     Train Epoch: 10 [11520/15424 (75%)]	Batch Neg ELBO: 734.761719	Batch Neg IWELBO: 735.7710
# 2019-05-23 16:42:12,864 root         INFO     Train Epoch: 10 [12800/15424 (83%)]	Batch Neg ELBO: 733.372375	Batch Neg IWELBO: 734.0396
# 2019-05-23 16:42:13,376 root         INFO     Train Epoch: 10 [14080/15424 (91%)]	Batch Neg ELBO: 735.641968	Batch Neg IWELBO: 735.5612
# 2019-05-23 16:42:13,888 root         INFO     Train Epoch: 10 [15360/15424 (99%)]	Batch Neg ELBO: 732.051514	Batch Neg IWELBO: 734.1135
# 2019-05-23 16:42:13,937 root         INFO     ====> Epoch: 10 Average Neg ELBO: 735.7318Average Neg IWELBO: 735.6680
# 2019-05-23 16:42:14,029 root         INFO     Val Epoch: 10 [0/3856 (0%)]	Batch Neg ELBO: 735.095215	Batch Neg IWELBO: 731.9796
# 2019-05-23 16:42:17,545 root         INFO     Val Epoch: 10 [1280/3856 (33%)]	Batch Neg ELBO: 735.680481	Batch Neg IWELBO: 735.6225
# 2019-05-23 16:42:21,056 root         INFO     Val Epoch: 10 [2560/3856 (66%)]	Batch Neg ELBO: 734.314514	Batch Neg IWELBO: 735.1991
# 2019-05-23 16:42:24,562 root         INFO     Val Epoch: 10 [3072/3856 (99%)]	Batch Neg ELBO: 736.709290	Batch Neg IWELBO: 734.6428
# 2019-05-23 16:42:24,589 root         INFO     ====> Val Epoch: 10 Average Negative ELBO: 735.3971Average IWAE: 735.7107
# 2019-05-23 16:42:24,641 root         INFO     Train Epoch: 11 [0/15424 (0%)]	Batch Neg ELBO: 734.481323	Batch Neg IWELBO: 733.9470
# 2019-05-23 16:42:25,158 root         INFO     Train Epoch: 11 [1280/15424 (8%)]	Batch Neg ELBO: 737.847717	Batch Neg IWELBO: 735.9446
# 2019-05-23 16:42:25,674 root         INFO     Train Epoch: 11 [2560/15424 (17%)]	Batch Neg ELBO: 737.842102	Batch Neg IWELBO: 736.5027
# 2019-05-23 16:42:26,190 root         INFO     Train Epoch: 11 [3840/15424 (25%)]	Batch Neg ELBO: 735.164551	Batch Neg IWELBO: 734.5405
# 2019-05-23 16:42:26,704 root         INFO     Train Epoch: 11 [5120/15424 (33%)]	Batch Neg ELBO: 734.745361	Batch Neg IWELBO: 735.7615
# 2019-05-23 16:42:27,216 root         INFO     Train Epoch: 11 [6400/15424 (41%)]	Batch Neg ELBO: 735.058350	Batch Neg IWELBO: 734.7623
# 2019-05-23 16:42:27,735 root         INFO     Train Epoch: 11 [7680/15424 (50%)]	Batch Neg ELBO: 736.012146	Batch Neg IWELBO: 736.4041
# 2019-05-23 16:42:28,253 root         INFO     Train Epoch: 11 [8960/15424 (58%)]	Batch Neg ELBO: 736.554077	Batch Neg IWELBO: 735.7252
# 2019-05-23 16:42:28,773 root         INFO     Train Epoch: 11 [10240/15424 (66%)]	Batch Neg ELBO: 738.908691	Batch Neg IWELBO: 738.1642
# 2019-05-23 16:42:29,292 root         INFO     Train Epoch: 11 [11520/15424 (75%)]	Batch Neg ELBO: 735.877502	Batch Neg IWELBO: 735.9357
# 2019-05-23 16:42:29,809 root         INFO     Train Epoch: 11 [12800/15424 (83%)]	Batch Neg ELBO: 738.168274	Batch Neg IWELBO: 737.5646
# 2019-05-23 16:42:30,329 root         INFO     Train Epoch: 11 [14080/15424 (91%)]	Batch Neg ELBO: 737.572998	Batch Neg IWELBO: 737.1214
# 2019-05-23 16:42:30,848 root         INFO     Train Epoch: 11 [15360/15424 (99%)]	Batch Neg ELBO: 737.009216	Batch Neg IWELBO: 736.0815
# 2019-05-23 16:42:30,897 root         INFO     ====> Epoch: 11 Average Neg ELBO: 735.7818Average Neg IWELBO: 735.6647
# 2019-05-23 16:42:30,990 root         INFO     Val Epoch: 11 [0/3856 (0%)]	Batch Neg ELBO: 735.971313	Batch Neg IWELBO: 737.5768
# 2019-05-23 16:42:34,501 root         INFO     Val Epoch: 11 [1280/3856 (33%)]	Batch Neg ELBO: 733.914368	Batch Neg IWELBO: 735.3574
# 2019-05-23 16:42:38,013 root         INFO     Val Epoch: 11 [2560/3856 (66%)]	Batch Neg ELBO: 734.613403	Batch Neg IWELBO: 735.3204
# 2019-05-23 16:42:41,519 root         INFO     Val Epoch: 11 [3072/3856 (99%)]	Batch Neg ELBO: 736.792175	Batch Neg IWELBO: 737.5250
# 2019-05-23 16:42:41,546 root         INFO     ====> Val Epoch: 11 Average Negative ELBO: 735.5522Average IWAE: 735.5171
# 2019-05-23 16:42:41,599 root         INFO     Train Epoch: 12 [0/15424 (0%)]	Batch Neg ELBO: 739.265991	Batch Neg IWELBO: 736.5742
# 2019-05-23 16:42:42,116 root         INFO     Train Epoch: 12 [1280/15424 (8%)]	Batch Neg ELBO: 736.350525	Batch Neg IWELBO: 735.3466
# 2019-05-23 16:42:42,632 root         INFO     Train Epoch: 12 [2560/15424 (17%)]	Batch Neg ELBO: 737.253784	Batch Neg IWELBO: 736.2024
# 2019-05-23 16:42:43,143 root         INFO     Train Epoch: 12 [3840/15424 (25%)]	Batch Neg ELBO: 736.489258	Batch Neg IWELBO: 736.3229
# 2019-05-23 16:42:43,678 root         INFO     Train Epoch: 12 [5120/15424 (33%)]	Batch Neg ELBO: 736.735962	Batch Neg IWELBO: 736.0353
# 2019-05-23 16:42:44,218 root         INFO     Train Epoch: 12 [6400/15424 (41%)]	Batch Neg ELBO: 737.664246	Batch Neg IWELBO: 735.3273
# 2019-05-23 16:42:44,753 root         INFO     Train Epoch: 12 [7680/15424 (50%)]	Batch Neg ELBO: 733.327271	Batch Neg IWELBO: 735.1323
# 2019-05-23 16:42:45,273 root         INFO     Train Epoch: 12 [8960/15424 (58%)]	Batch Neg ELBO: 735.940125	Batch Neg IWELBO: 735.5067
# 2019-05-23 16:42:45,793 root         INFO     Train Epoch: 12 [10240/15424 (66%)]	Batch Neg ELBO: 736.057800	Batch Neg IWELBO: 735.3998
# 2019-05-23 16:42:46,310 root         INFO     Train Epoch: 12 [11520/15424 (75%)]	Batch Neg ELBO: 735.257812	Batch Neg IWELBO: 734.7806
# 2019-05-23 16:42:46,826 root         INFO     Train Epoch: 12 [12800/15424 (83%)]	Batch Neg ELBO: 734.177734	Batch Neg IWELBO: 735.0374
# 2019-05-23 16:42:47,340 root         INFO     Train Epoch: 12 [14080/15424 (91%)]	Batch Neg ELBO: 735.315430	Batch Neg IWELBO: 735.5135
# 2019-05-23 16:42:47,852 root         INFO     Train Epoch: 12 [15360/15424 (99%)]	Batch Neg ELBO: 735.127930	Batch Neg IWELBO: 735.3004
# 2019-05-23 16:42:47,902 root         INFO     ====> Epoch: 12 Average Neg ELBO: 735.7379Average Neg IWELBO: 735.6620
# 2019-05-23 16:42:47,994 root         INFO     Val Epoch: 12 [0/3856 (0%)]	Batch Neg ELBO: 736.311646	Batch Neg IWELBO: 736.5506
# 2019-05-23 16:42:51,507 root         INFO     Val Epoch: 12 [1280/3856 (33%)]	Batch Neg ELBO: 736.233093	Batch Neg IWELBO: 736.3011
# 2019-05-23 16:42:55,037 root         INFO     Val Epoch: 12 [2560/3856 (66%)]	Batch Neg ELBO: 738.900024	Batch Neg IWELBO: 735.9511
# 2019-05-23 16:42:58,543 root         INFO     Val Epoch: 12 [3072/3856 (99%)]	Batch Neg ELBO: 735.165222	Batch Neg IWELBO: 736.3953
# 2019-05-23 16:42:58,570 root         INFO     ====> Val Epoch: 12 Average Negative ELBO: 735.6613Average IWAE: 735.4178
# 2019-05-23 16:42:58,622 root         INFO     Train Epoch: 13 [0/15424 (0%)]	Batch Neg ELBO: 736.574646	Batch Neg IWELBO: 735.8815
# 2019-05-23 16:42:59,166 root         INFO     Train Epoch: 13 [1280/15424 (8%)]	Batch Neg ELBO: 736.143494	Batch Neg IWELBO: 737.3130
# 2019-05-23 16:42:59,684 root         INFO     Train Epoch: 13 [2560/15424 (17%)]	Batch Neg ELBO: 739.140747	Batch Neg IWELBO: 737.6829
# 2019-05-23 16:43:00,202 root         INFO     Train Epoch: 13 [3840/15424 (25%)]	Batch Neg ELBO: 737.004028	Batch Neg IWELBO: 736.2853
# 2019-05-23 16:43:00,723 root         INFO     Train Epoch: 13 [5120/15424 (33%)]	Batch Neg ELBO: 734.837952	Batch Neg IWELBO: 734.4901
# 2019-05-23 16:43:01,238 root         INFO     Train Epoch: 13 [6400/15424 (41%)]	Batch Neg ELBO: 736.192200	Batch Neg IWELBO: 736.1411
# 2019-05-23 16:43:01,761 root         INFO     Train Epoch: 13 [7680/15424 (50%)]	Batch Neg ELBO: 736.015259	Batch Neg IWELBO: 734.6003
# 2019-05-23 16:43:02,282 root         INFO     Train Epoch: 13 [8960/15424 (58%)]	Batch Neg ELBO: 734.418823	Batch Neg IWELBO: 735.6138
# 2019-05-23 16:43:02,802 root         INFO     Train Epoch: 13 [10240/15424 (66%)]	Batch Neg ELBO: 733.772095	Batch Neg IWELBO: 734.7919
# 2019-05-23 16:43:03,324 root         INFO     Train Epoch: 13 [11520/15424 (75%)]	Batch Neg ELBO: 737.199341	Batch Neg IWELBO: 735.6227
# 2019-05-23 16:43:03,845 root         INFO     Train Epoch: 13 [12800/15424 (83%)]	Batch Neg ELBO: 735.912415	Batch Neg IWELBO: 738.3535
# 2019-05-23 16:43:04,366 root         INFO     Train Epoch: 13 [14080/15424 (91%)]	Batch Neg ELBO: 734.793274	Batch Neg IWELBO: 735.3157
# 2019-05-23 16:43:04,887 root         INFO     Train Epoch: 13 [15360/15424 (99%)]	Batch Neg ELBO: 735.988770	Batch Neg IWELBO: 736.6765
# 2019-05-23 16:43:04,936 root         INFO     ====> Epoch: 13 Average Neg ELBO: 735.6689Average Neg IWELBO: 735.6608
# 2019-05-23 16:43:05,029 root         INFO     Val Epoch: 13 [0/3856 (0%)]	Batch Neg ELBO: 736.318237	Batch Neg IWELBO: 734.4616
# 2019-05-23 16:43:08,543 root         INFO     Val Epoch: 13 [1280/3856 (33%)]	Batch Neg ELBO: 737.153931	Batch Neg IWELBO: 736.8468
# 2019-05-23 16:43:12,055 root         INFO     Val Epoch: 13 [2560/3856 (66%)]	Batch Neg ELBO: 736.330688	Batch Neg IWELBO: 735.8009
# 2019-05-23 16:43:15,561 root         INFO     Val Epoch: 13 [3072/3856 (99%)]	Batch Neg ELBO: 734.829590	Batch Neg IWELBO: 735.4086
# 2019-05-23 16:43:15,587 root         INFO     ====> Val Epoch: 13 Average Negative ELBO: 735.5934Average IWAE: 735.4450
# 2019-05-23 16:43:15,643 root         INFO     Train Epoch: 14 [0/15424 (0%)]	Batch Neg ELBO: 734.594055	Batch Neg IWELBO: 734.6954
# 2019-05-23 16:43:16,179 root         INFO     Train Epoch: 14 [1280/15424 (8%)]	Batch Neg ELBO: 737.136536	Batch Neg IWELBO: 737.2539
# 2019-05-23 16:43:16,718 root         INFO     Train Epoch: 14 [2560/15424 (17%)]	Batch Neg ELBO: 737.836792	Batch Neg IWELBO: 735.3724
# 2019-05-23 16:43:17,244 root         INFO     Train Epoch: 14 [3840/15424 (25%)]	Batch Neg ELBO: 735.842834	Batch Neg IWELBO: 734.1771
# 2019-05-23 16:43:17,750 root         INFO     Train Epoch: 14 [5120/15424 (33%)]	Batch Neg ELBO: 740.452393	Batch Neg IWELBO: 737.4689
# 2019-05-23 16:43:18,256 root         INFO     Train Epoch: 14 [6400/15424 (41%)]	Batch Neg ELBO: 734.435974	Batch Neg IWELBO: 733.8989
# 2019-05-23 16:43:18,761 root         INFO     Train Epoch: 14 [7680/15424 (50%)]	Batch Neg ELBO: 733.563293	Batch Neg IWELBO: 734.5324
# 2019-05-23 16:43:19,265 root         INFO     Train Epoch: 14 [8960/15424 (58%)]	Batch Neg ELBO: 734.727112	Batch Neg IWELBO: 734.4446
# 2019-05-23 16:43:19,771 root         INFO     Train Epoch: 14 [10240/15424 (66%)]	Batch Neg ELBO: 734.847351	Batch Neg IWELBO: 736.8543
# 2019-05-23 16:43:20,283 root         INFO     Train Epoch: 14 [11520/15424 (75%)]	Batch Neg ELBO: 734.989197	Batch Neg IWELBO: 735.6371
# 2019-05-23 16:43:20,800 root         INFO     Train Epoch: 14 [12800/15424 (83%)]	Batch Neg ELBO: 732.352112	Batch Neg IWELBO: 733.1401
# 2019-05-23 16:43:21,314 root         INFO     Train Epoch: 14 [14080/15424 (91%)]	Batch Neg ELBO: 734.318359	Batch Neg IWELBO: 735.9716
# 2019-05-23 16:43:21,834 root         INFO     Train Epoch: 14 [15360/15424 (99%)]	Batch Neg ELBO: 736.679871	Batch Neg IWELBO: 735.2456
# 2019-05-23 16:43:21,882 root         INFO     ====> Epoch: 14 Average Neg ELBO: 735.6955Average Neg IWELBO: 735.6563
# 2019-05-23 16:43:21,975 root         INFO     Val Epoch: 14 [0/3856 (0%)]	Batch Neg ELBO: 738.560974	Batch Neg IWELBO: 735.1493
# 2019-05-23 16:43:25,486 root         INFO     Val Epoch: 14 [1280/3856 (33%)]	Batch Neg ELBO: 736.946289	Batch Neg IWELBO: 734.2834
# 2019-05-23 16:43:29,000 root         INFO     Val Epoch: 14 [2560/3856 (66%)]	Batch Neg ELBO: 736.263245	Batch Neg IWELBO: 734.0690
# 2019-05-23 16:43:32,506 root         INFO     Val Epoch: 14 [3072/3856 (99%)]	Batch Neg ELBO: 734.815552	Batch Neg IWELBO: 734.5372
# 2019-05-23 16:43:32,533 root         INFO     ====> Val Epoch: 14 Average Negative ELBO: 735.5620Average IWAE: 735.5213
# 2019-05-23 16:43:32,585 root         INFO     Train Epoch: 15 [0/15424 (0%)]	Batch Neg ELBO: 735.889526	Batch Neg IWELBO: 735.4931
# 2019-05-23 16:43:33,107 root         INFO     Train Epoch: 15 [1280/15424 (8%)]	Batch Neg ELBO: 734.953613	Batch Neg IWELBO: 734.5548
# 2019-05-23 16:43:33,641 root         INFO     Train Epoch: 15 [2560/15424 (17%)]	Batch Neg ELBO: 733.429321	Batch Neg IWELBO: 734.8737
# 2019-05-23 16:43:34,173 root         INFO     Train Epoch: 15 [3840/15424 (25%)]	Batch Neg ELBO: 735.259949	Batch Neg IWELBO: 734.8384
# 2019-05-23 16:43:34,702 root         INFO     Train Epoch: 15 [5120/15424 (33%)]	Batch Neg ELBO: 739.159119	Batch Neg IWELBO: 739.1262
# 2019-05-23 16:43:35,215 root         INFO     Train Epoch: 15 [6400/15424 (41%)]	Batch Neg ELBO: 735.576782	Batch Neg IWELBO: 734.3918
# 2019-05-23 16:43:35,731 root         INFO     Train Epoch: 15 [7680/15424 (50%)]	Batch Neg ELBO: 739.073792	Batch Neg IWELBO: 737.0607
# 2019-05-23 16:43:36,247 root         INFO     Train Epoch: 15 [8960/15424 (58%)]	Batch Neg ELBO: 733.189453	Batch Neg IWELBO: 734.7250
# 2019-05-23 16:43:36,778 root         INFO     Train Epoch: 15 [10240/15424 (66%)]	Batch Neg ELBO: 737.973572	Batch Neg IWELBO: 736.9993
# 2019-05-23 16:43:37,312 root         INFO     Train Epoch: 15 [11520/15424 (75%)]	Batch Neg ELBO: 737.869934	Batch Neg IWELBO: 736.8929
# 2019-05-23 16:43:37,843 root         INFO     Train Epoch: 15 [12800/15424 (83%)]	Batch Neg ELBO: 735.660217	Batch Neg IWELBO: 736.0809
# 2019-05-23 16:43:38,356 root         INFO     Train Epoch: 15 [14080/15424 (91%)]	Batch Neg ELBO: 735.233948	Batch Neg IWELBO: 735.3671
# 2019-05-23 16:43:38,869 root         INFO     Train Epoch: 15 [15360/15424 (99%)]	Batch Neg ELBO: 734.169495	Batch Neg IWELBO: 734.2646
# 2019-05-23 16:43:38,919 root         INFO     ====> Epoch: 15 Average Neg ELBO: 735.7453Average Neg IWELBO: 735.6551
# 2019-05-23 16:43:39,012 root         INFO     Val Epoch: 15 [0/3856 (0%)]	Batch Neg ELBO: 735.324951	Batch Neg IWELBO: 734.1406
# 2019-05-23 16:43:42,528 root         INFO     Val Epoch: 15 [1280/3856 (33%)]	Batch Neg ELBO: 734.345581	Batch Neg IWELBO: 736.5411
# 2019-05-23 16:43:46,044 root         INFO     Val Epoch: 15 [2560/3856 (66%)]	Batch Neg ELBO: 734.172302	Batch Neg IWELBO: 737.3922
# 2019-05-23 16:43:49,550 root         INFO     Val Epoch: 15 [3072/3856 (99%)]	Batch Neg ELBO: 734.623718	Batch Neg IWELBO: 738.7932
# 2019-05-23 16:43:49,578 root         INFO     ====> Val Epoch: 15 Average Negative ELBO: 735.5730Average IWAE: 735.5096
# 2019-05-23 16:43:49,631 root         INFO     Train Epoch: 16 [0/15424 (0%)]	Batch Neg ELBO: 736.364624	Batch Neg IWELBO: 735.7033
# 2019-05-23 16:43:50,187 root         INFO     Train Epoch: 16 [1280/15424 (8%)]	Batch Neg ELBO: 735.237793	Batch Neg IWELBO: 735.1912
# 2019-05-23 16:43:50,741 root         INFO     Train Epoch: 16 [2560/15424 (17%)]	Batch Neg ELBO: 735.939880	Batch Neg IWELBO: 736.3098
# 2019-05-23 16:43:51,297 root         INFO     Train Epoch: 16 [3840/15424 (25%)]	Batch Neg ELBO: 736.946838	Batch Neg IWELBO: 736.2139
# 2019-05-23 16:43:51,854 root         INFO     Train Epoch: 16 [5120/15424 (33%)]	Batch Neg ELBO: 735.972656	Batch Neg IWELBO: 736.7094
# 2019-05-23 16:43:52,408 root         INFO     Train Epoch: 16 [6400/15424 (41%)]	Batch Neg ELBO: 736.923462	Batch Neg IWELBO: 734.6933
# 2019-05-23 16:43:52,959 root         INFO     Train Epoch: 16 [7680/15424 (50%)]	Batch Neg ELBO: 736.353821	Batch Neg IWELBO: 735.6876
# 2019-05-23 16:43:53,510 root         INFO     Train Epoch: 16 [8960/15424 (58%)]	Batch Neg ELBO: 735.969360	Batch Neg IWELBO: 735.4107
# 2019-05-23 16:43:54,023 root         INFO     Train Epoch: 16 [10240/15424 (66%)]	Batch Neg ELBO: 734.146973	Batch Neg IWELBO: 734.0543
# 2019-05-23 16:43:54,534 root         INFO     Train Epoch: 16 [11520/15424 (75%)]	Batch Neg ELBO: 738.865051	Batch Neg IWELBO: 737.8200
# 2019-05-23 16:43:55,046 root         INFO     Train Epoch: 16 [12800/15424 (83%)]	Batch Neg ELBO: 737.422607	Batch Neg IWELBO: 735.8900
# 2019-05-23 16:43:55,569 root         INFO     Train Epoch: 16 [14080/15424 (91%)]	Batch Neg ELBO: 735.961487	Batch Neg IWELBO: 736.1586
# 2019-05-23 16:43:56,129 root         INFO     Train Epoch: 16 [15360/15424 (99%)]	Batch Neg ELBO: 737.027344	Batch Neg IWELBO: 734.9468
# 2019-05-23 16:43:56,179 root         INFO     ====> Epoch: 16 Average Neg ELBO: 735.7617Average Neg IWELBO: 735.6539
# 2019-05-23 16:43:56,271 root         INFO     Val Epoch: 16 [0/3856 (0%)]	Batch Neg ELBO: 735.689392	Batch Neg IWELBO: 734.6736
# 2019-05-23 16:43:59,786 root         INFO     Val Epoch: 16 [1280/3856 (33%)]	Batch Neg ELBO: 735.061401	Batch Neg IWELBO: 734.6251
# 2019-05-23 16:44:03,297 root         INFO     Val Epoch: 16 [2560/3856 (66%)]	Batch Neg ELBO: 734.860168	Batch Neg IWELBO: 736.7677
# 2019-05-23 16:44:06,801 root         INFO     Val Epoch: 16 [3072/3856 (99%)]	Batch Neg ELBO: 735.677612	Batch Neg IWELBO: 734.6139
# 2019-05-23 16:44:06,828 root         INFO     ====> Val Epoch: 16 Average Negative ELBO: 735.6172Average IWAE: 735.4382
# 2019-05-23 16:44:06,881 root         INFO     Train Epoch: 17 [0/15424 (0%)]	Batch Neg ELBO: 737.040771	Batch Neg IWELBO: 736.6003
# 2019-05-23 16:44:07,392 root         INFO     Train Epoch: 17 [1280/15424 (8%)]	Batch Neg ELBO: 734.962524	Batch Neg IWELBO: 734.9147
# 2019-05-23 16:44:07,904 root         INFO     Train Epoch: 17 [2560/15424 (17%)]	Batch Neg ELBO: 736.463440	Batch Neg IWELBO: 735.7716
# 2019-05-23 16:44:08,416 root         INFO     Train Epoch: 17 [3840/15424 (25%)]	Batch Neg ELBO: 736.652405	Batch Neg IWELBO: 735.0680
# 2019-05-23 16:44:08,927 root         INFO     Train Epoch: 17 [5120/15424 (33%)]	Batch Neg ELBO: 735.522217	Batch Neg IWELBO: 734.2462
# 2019-05-23 16:44:09,438 root         INFO     Train Epoch: 17 [6400/15424 (41%)]	Batch Neg ELBO: 735.312073	Batch Neg IWELBO: 734.4803
# 2019-05-23 16:44:09,948 root         INFO     Train Epoch: 17 [7680/15424 (50%)]	Batch Neg ELBO: 735.510803	Batch Neg IWELBO: 735.7224
# 2019-05-23 16:44:10,511 root         INFO     Train Epoch: 17 [8960/15424 (58%)]	Batch Neg ELBO: 736.412964	Batch Neg IWELBO: 735.5580
# 2019-05-23 16:44:11,074 root         INFO     Train Epoch: 17 [10240/15424 (66%)]	Batch Neg ELBO: 733.914673	Batch Neg IWELBO: 733.7437
# 2019-05-23 16:44:11,593 root         INFO     Train Epoch: 17 [11520/15424 (75%)]	Batch Neg ELBO: 734.354431	Batch Neg IWELBO: 736.0830
# 2019-05-23 16:44:12,121 root         INFO     Train Epoch: 17 [12800/15424 (83%)]	Batch Neg ELBO: 732.913757	Batch Neg IWELBO: 734.4904
# 2019-05-23 16:44:12,654 root         INFO     Train Epoch: 17 [14080/15424 (91%)]	Batch Neg ELBO: 736.704224	Batch Neg IWELBO: 736.0891
# 2019-05-23 16:44:13,184 root         INFO     Train Epoch: 17 [15360/15424 (99%)]	Batch Neg ELBO: 734.715515	Batch Neg IWELBO: 734.4158
# 2019-05-23 16:44:13,233 root         INFO     ====> Epoch: 17 Average Neg ELBO: 735.7355Average Neg IWELBO: 735.6521
# 2019-05-23 16:44:13,326 root         INFO     Val Epoch: 17 [0/3856 (0%)]	Batch Neg ELBO: 732.836121	Batch Neg IWELBO: 737.3185
# 2019-05-23 16:44:16,837 root         INFO     Val Epoch: 17 [1280/3856 (33%)]	Batch Neg ELBO: 734.817200	Batch Neg IWELBO: 735.5979
# 2019-05-23 16:44:20,349 root         INFO     Val Epoch: 17 [2560/3856 (66%)]	Batch Neg ELBO: 737.450867	Batch Neg IWELBO: 736.0166
# 2019-05-23 16:44:23,858 root         INFO     Val Epoch: 17 [3072/3856 (99%)]	Batch Neg ELBO: 735.197693	Batch Neg IWELBO: 735.9265
# 2019-05-23 16:44:23,885 root         INFO     ====> Val Epoch: 17 Average Negative ELBO: 735.4725Average IWAE: 735.5670
# 2019-05-23 16:44:23,938 root         INFO     Train Epoch: 18 [0/15424 (0%)]	Batch Neg ELBO: 733.893860	Batch Neg IWELBO: 735.0465
# 2019-05-23 16:44:24,449 root         INFO     Train Epoch: 18 [1280/15424 (8%)]	Batch Neg ELBO: 736.372437	Batch Neg IWELBO: 734.1567
# 2019-05-23 16:44:24,961 root         INFO     Train Epoch: 18 [2560/15424 (17%)]	Batch Neg ELBO: 734.223328	Batch Neg IWELBO: 734.9623
# 2019-05-23 16:44:25,468 root         INFO     Train Epoch: 18 [3840/15424 (25%)]	Batch Neg ELBO: 736.750061	Batch Neg IWELBO: 736.5461
# 2019-05-23 16:44:25,982 root         INFO     Train Epoch: 18 [5120/15424 (33%)]	Batch Neg ELBO: 737.078003	Batch Neg IWELBO: 738.2952
# 2019-05-23 16:44:26,505 root         INFO     Train Epoch: 18 [6400/15424 (41%)]	Batch Neg ELBO: 736.482239	Batch Neg IWELBO: 736.1913
# 2019-05-23 16:44:27,025 root         INFO     Train Epoch: 18 [7680/15424 (50%)]	Batch Neg ELBO: 740.567139	Batch Neg IWELBO: 736.7451
# 2019-05-23 16:44:27,544 root         INFO     Train Epoch: 18 [8960/15424 (58%)]	Batch Neg ELBO: 736.648682	Batch Neg IWELBO: 735.1701
# ...
# 2019-05-23 16:56:54,997 root         INFO     Train Epoch: 19 [10240/15424 (66%)]	Batch NEG IWELBO: 736.081787
# 2019-05-23 16:56:55,337 root         INFO     Train Epoch: 19 [11520/15424 (75%)]	Batch NEG IWELBO: 735.296509
# 2019-05-23 16:56:55,667 root         INFO     Train Epoch: 19 [12800/15424 (83%)]	Batch NEG IWELBO: 736.713318
# 2019-05-23 16:56:56,001 root         INFO     Train Epoch: 19 [14080/15424 (91%)]	Batch NEG IWELBO: 736.581787
# 2019-05-23 16:56:56,337 root         INFO     Train Epoch: 19 [15360/15424 (99%)]	Batch NEG IWELBO: 735.017212
# 2019-05-23 16:56:56,378 root         INFO     ====> Epoch: 19 Average NEG IWELBO: 735.6232
# 2019-05-23 16:56:56,471 root         INFO     Val Epoch: 19 [0/3856 (0%)]	Batch NEG IWELBO: 732.900024
# 2019-05-23 16:56:59,980 root         INFO     Val Epoch: 19 [1280/3856 (33%)]	Batch NEG IWELBO: 736.559753
# 2019-05-23 16:57:03,482 root         INFO     Val Epoch: 19 [2560/3856 (66%)]	Batch NEG IWELBO: 735.724121
# 2019-05-23 16:57:07,000 root         INFO     Val Epoch: 19 [3072/3856 (99%)]	Batch NEG IWELBO: 735.623291
# 2019-05-23 16:57:07,027 root         INFO     ====> Val Epoch: 19 Average NEG IWELBO: 735.5885
# 2019-05-23 16:57:07,077 root         INFO     Train Epoch: 20 [0/15424 (0%)]	Batch NEG IWELBO: 735.764343
# 2019-05-23 16:57:07,410 root         INFO     Train Epoch: 20 [1280/15424 (8%)]	Batch NEG IWELBO: 737.504333
# 2019-05-23 16:57:07,748 root         INFO     Train Epoch: 20 [2560/15424 (17%)]	Batch NEG IWELBO: 736.472961
# 2019-05-23 16:57:08,083 root         INFO     Train Epoch: 20 [3840/15424 (25%)]	Batch NEG IWELBO: 735.954285
# 2019-05-23 16:57:08,420 root         INFO     Train Epoch: 20 [5120/15424 (33%)]	Batch NEG IWELBO: 737.300781
# 2019-05-23 16:57:08,759 root         INFO     Train Epoch: 20 [6400/15424 (41%)]	Batch NEG IWELBO: 734.395874
# 2019-05-23 16:57:09,091 root         INFO     Train Epoch: 20 [7680/15424 (50%)]	Batch NEG IWELBO: 733.656128
# 2019-05-23 16:57:09,423 root         INFO     Train Epoch: 20 [8960/15424 (58%)]	Batch NEG IWELBO: 734.060974
# 2019-05-23 16:57:09,773 root         INFO     Train Epoch: 20 [10240/15424 (66%)]	Batch NEG IWELBO: 738.246277
# 2019-05-23 16:57:10,157 root         INFO     Train Epoch: 20 [11520/15424 (75%)]	Batch NEG IWELBO: 734.999695
# 2019-05-23 16:57:10,490 root         INFO     Train Epoch: 20 [12800/15424 (83%)]	Batch NEG IWELBO: 736.431152
# 2019-05-23 16:57:10,822 root         INFO     Train Epoch: 20 [14080/15424 (91%)]	Batch NEG IWELBO: 734.407898
# 2019-05-23 16:57:11,154 root         INFO     Train Epoch: 20 [15360/15424 (99%)]	Batch NEG IWELBO: 736.943848
# 2019-05-23 16:57:11,194 root         INFO     ====> Epoch: 20 Average NEG IWELBO: 735.6232
# 2019-05-23 16:57:11,288 root         INFO     Val Epoch: 20 [0/3856 (0%)]	Batch NEG IWELBO: 737.491516
# 2019-05-23 16:57:14,806 root         INFO     Val Epoch: 20 [1280/3856 (33%)]	Batch NEG IWELBO: 737.440613
# 2019-05-23 16:57:18,308 root         INFO     Val Epoch: 20 [2560/3856 (66%)]	Batch NEG IWELBO: 735.571838
# 2019-05-23 16:57:21,804 root         INFO     Val Epoch: 20 [3072/3856 (99%)]	Batch NEG IWELBO: 735.449402
# 2019-05-23 16:57:21,831 root         INFO     ====> Val Epoch: 20 Average NEG IWELBO: 735.5819
# 2019-05-23 16:57:21,880 root         INFO     Train Epoch: 21 [0/15424 (0%)]	Batch NEG IWELBO: 734.707825
# 2019-05-23 16:57:22,215 root         INFO     Train Epoch: 21 [1280/15424 (8%)]	Batch NEG IWELBO: 735.515320
# 2019-05-23 16:57:22,552 root         INFO     Train Epoch: 21 [2560/15424 (17%)]	Batch NEG IWELBO: 736.117493
# 2019-05-23 16:57:22,888 root         INFO     Train Epoch: 21 [3840/15424 (25%)]	Batch NEG IWELBO: 736.058716
# 2019-05-23 16:57:23,218 root         INFO     Train Epoch: 21 [5120/15424 (33%)]	Batch NEG IWELBO: 734.623840
# 2019-05-23 16:57:23,547 root         INFO     Train Epoch: 21 [6400/15424 (41%)]	Batch NEG IWELBO: 735.800598
# 2019-05-23 16:57:23,881 root         INFO     Train Epoch: 21 [7680/15424 (50%)]	Batch NEG IWELBO: 735.523621
# 2019-05-23 16:57:24,229 root         INFO     Train Epoch: 21 [8960/15424 (58%)]	Batch NEG IWELBO: 736.039429
# 2019-05-23 16:57:24,568 root         INFO     Train Epoch: 21 [10240/15424 (66%)]	Batch NEG IWELBO: 736.955078
# 2019-05-23 16:57:24,905 root         INFO     Train Epoch: 21 [11520/15424 (75%)]	Batch NEG IWELBO: 734.638184
# 2019-05-23 16:57:25,241 root         INFO     Train Epoch: 21 [12800/15424 (83%)]	Batch NEG IWELBO: 736.943176
# 2019-05-23 16:57:25,579 root         INFO     Train Epoch: 21 [14080/15424 (91%)]	Batch NEG IWELBO: 733.645081
# 2019-05-23 16:57:25,918 root         INFO     Train Epoch: 21 [15360/15424 (99%)]	Batch NEG IWELBO: 736.720398
# 2019-05-23 16:57:25,959 root         INFO     ====> Epoch: 21 Average NEG IWELBO: 735.6197
# 2019-05-23 16:57:26,052 root         INFO     Val Epoch: 21 [0/3856 (0%)]	Batch NEG IWELBO: 735.528992
# 2019-05-23 16:57:29,561 root         INFO     Val Epoch: 21 [1280/3856 (33%)]	Batch NEG IWELBO: 736.215027
# 2019-05-23 16:57:33,067 root         INFO     Val Epoch: 21 [2560/3856 (66%)]	Batch NEG IWELBO: 733.830261
# 2019-05-23 16:57:36,567 root         INFO     Val Epoch: 21 [3072/3856 (99%)]	Batch NEG IWELBO: 735.032837
# 2019-05-23 16:57:36,594 root         INFO     ====> Val Epoch: 21 Average NEG IWELBO: 735.5842
# 2019-05-23 16:57:36,643 root         INFO     Train Epoch: 22 [0/15424 (0%)]	Batch NEG IWELBO: 734.732361
# 2019-05-23 16:57:37,000 root         INFO     Train Epoch: 22 [1280/15424 (8%)]	Batch NEG IWELBO: 737.046997
# 2019-05-23 16:57:37,348 root         INFO     Train Epoch: 22 [2560/15424 (17%)]	Batch NEG IWELBO: 733.009949
# 2019-05-23 16:57:37,696 root         INFO     Train Epoch: 22 [3840/15424 (25%)]	Batch NEG IWELBO: 734.983398
# 2019-05-23 16:57:38,044 root         INFO     Train Epoch: 22 [5120/15424 (33%)]	Batch NEG IWELBO: 734.218140
# 2019-05-23 16:57:38,433 root         INFO     Train Epoch: 22 [6400/15424 (41%)]	Batch NEG IWELBO: 736.064514
# 2019-05-23 16:57:38,766 root         INFO     Train Epoch: 22 [7680/15424 (50%)]	Batch NEG IWELBO: 737.080322
# 2019-05-23 16:57:39,105 root         INFO     Train Epoch: 22 [8960/15424 (58%)]	Batch NEG IWELBO: 735.301392
# 2019-05-23 16:57:39,447 root         INFO     Train Epoch: 22 [10240/15424 (66%)]	Batch NEG IWELBO: 738.210144
# 2019-05-23 16:57:39,781 root         INFO     Train Epoch: 22 [11520/15424 (75%)]	Batch NEG IWELBO: 735.303589
# 2019-05-23 16:57:40,110 root         INFO     Train Epoch: 22 [12800/15424 (83%)]	Batch NEG IWELBO: 735.409912
# 2019-05-23 16:57:40,444 root         INFO     Train Epoch: 22 [14080/15424 (91%)]	Batch NEG IWELBO: 736.809753
# 2019-05-23 16:57:40,788 root         INFO     Train Epoch: 22 [15360/15424 (99%)]	Batch NEG IWELBO: 734.891846
# 2019-05-23 16:57:40,829 root         INFO     ====> Epoch: 22 Average NEG IWELBO: 735.6168
# 2019-05-23 16:57:40,922 root         INFO     Val Epoch: 22 [0/3856 (0%)]	Batch NEG IWELBO: 735.319214
# 2019-05-23 16:57:44,429 root         INFO     Val Epoch: 22 [1280/3856 (33%)]	Batch NEG IWELBO: 735.193542
# 2019-05-23 16:57:47,935 root         INFO     Val Epoch: 22 [2560/3856 (66%)]	Batch NEG IWELBO: 735.609436
# 2019-05-23 16:57:51,432 root         INFO     Val Epoch: 22 [3072/3856 (99%)]	Batch NEG IWELBO: 734.794983
# 2019-05-23 16:57:51,459 root         INFO     ====> Val Epoch: 22 Average NEG IWELBO: 735.5837
# 2019-05-23 16:57:51,509 root         INFO     Train Epoch: 23 [0/15424 (0%)]	Batch NEG IWELBO: 734.681152
# 2019-05-23 16:57:51,843 root         INFO     Train Epoch: 23 [1280/15424 (8%)]	Batch NEG IWELBO: 738.042297
# 2019-05-23 16:57:52,219 root         INFO     Train Epoch: 23 [2560/15424 (17%)]	Batch NEG IWELBO: 734.963745
# 2019-05-23 16:57:52,590 root         INFO     Train Epoch: 23 [3840/15424 (25%)]	Batch NEG IWELBO: 736.289795
# 2019-05-23 16:57:52,948 root         INFO     Train Epoch: 23 [5120/15424 (33%)]	Batch NEG IWELBO: 734.057678
# 2019-05-23 16:57:53,280 root         INFO     Train Epoch: 23 [6400/15424 (41%)]	Batch NEG IWELBO: 734.272766
# 2019-05-23 16:57:53,608 root         INFO     Train Epoch: 23 [7680/15424 (50%)]	Batch NEG IWELBO: 734.536377
# 2019-05-23 16:57:53,937 root         INFO     Train Epoch: 23 [8960/15424 (58%)]	Batch NEG IWELBO: 737.994446
# 2019-05-23 16:57:54,269 root         INFO     Train Epoch: 23 [10240/15424 (66%)]	Batch NEG IWELBO: 737.423645
# 2019-05-23 16:57:54,651 root         INFO     Train Epoch: 23 [11520/15424 (75%)]	Batch NEG IWELBO: 737.137329
# 2019-05-23 16:57:54,990 root         INFO     Train Epoch: 23 [12800/15424 (83%)]	Batch NEG IWELBO: 735.567017
# 2019-05-23 16:57:55,331 root         INFO     Train Epoch: 23 [14080/15424 (91%)]	Batch NEG IWELBO: 735.434753
# 2019-05-23 16:57:55,670 root         INFO     Train Epoch: 23 [15360/15424 (99%)]	Batch NEG IWELBO: 735.705750
# 2019-05-23 16:57:55,710 root         INFO     ====> Epoch: 23 Average NEG IWELBO: 735.6157
# 2019-05-23 16:57:55,804 root         INFO     Val Epoch: 23 [0/3856 (0%)]	Batch NEG IWELBO: 732.827759
# 2019-05-23 16:57:59,312 root         INFO     Val Epoch: 23 [1280/3856 (33%)]	Batch NEG IWELBO: 735.392578
# 2019-05-23 16:58:02,808 root         INFO     Val Epoch: 23 [2560/3856 (66%)]	Batch NEG IWELBO: 734.610046
# 2019-05-23 16:58:06,309 root         INFO     Val Epoch: 23 [3072/3856 (99%)]	Batch NEG IWELBO: 735.789978
# 2019-05-23 16:58:06,336 root         INFO     ====> Val Epoch: 23 Average NEG IWELBO: 735.5797
# 2019-05-23 16:58:06,386 root         INFO     Train Epoch: 24 [0/15424 (0%)]	Batch NEG IWELBO: 735.787842
# 2019-05-23 16:58:06,720 root         INFO     Train Epoch: 24 [1280/15424 (8%)]	Batch NEG IWELBO: 735.347351
# 2019-05-23 16:58:07,056 root         INFO     Train Epoch: 24 [2560/15424 (17%)]	Batch NEG IWELBO: 735.220398
# 2019-05-23 16:58:07,385 root         INFO     Train Epoch: 24 [3840/15424 (25%)]	Batch NEG IWELBO: 736.914368
# 2019-05-23 16:58:07,730 root         INFO     Train Epoch: 24 [5120/15424 (33%)]	Batch NEG IWELBO: 736.106018
# 2019-05-23 16:58:08,063 root         INFO     Train Epoch: 24 [6400/15424 (41%)]	Batch NEG IWELBO: 735.550354
# 2019-05-23 16:58:08,392 root         INFO     Train Epoch: 24 [7680/15424 (50%)]	Batch NEG IWELBO: 735.277771
# 2019-05-23 16:58:08,764 root         INFO     Train Epoch: 24 [8960/15424 (58%)]	Batch NEG IWELBO: 737.452515
# 2019-05-23 16:58:09,098 root         INFO     Train Epoch: 24 [10240/15424 (66%)]	Batch NEG IWELBO: 734.947754
# 2019-05-23 16:58:09,434 root         INFO     Train Epoch: 24 [11520/15424 (75%)]	Batch NEG IWELBO: 733.273499
# 2019-05-23 16:58:09,772 root         INFO     Train Epoch: 24 [12800/15424 (83%)]	Batch NEG IWELBO: 736.928650
# 2019-05-23 16:58:10,123 root         INFO     Train Epoch: 24 [14080/15424 (91%)]	Batch NEG IWELBO: 736.466736
# 2019-05-23 16:58:10,464 root         INFO     Train Epoch: 24 [15360/15424 (99%)]	Batch NEG IWELBO: 735.872070
# 2019-05-23 16:58:10,506 root         INFO     ====> Epoch: 24 Average NEG IWELBO: 735.6148
# 2019-05-23 16:58:10,599 root         INFO     Val Epoch: 24 [0/3856 (0%)]	Batch NEG IWELBO: 736.473328
# 2019-05-23 16:58:14,104 root         INFO     Val Epoch: 24 [1280/3856 (33%)]	Batch NEG IWELBO: 735.254089
# 2019-05-23 16:58:17,608 root         INFO     Val Epoch: 24 [2560/3856 (66%)]	Batch NEG IWELBO: 735.000977
# 2019-05-23 16:58:21,104 root         INFO     Val Epoch: 24 [3072/3856 (99%)]	Batch NEG IWELBO: 734.130493
# 2019-05-23 16:58:21,131 root         INFO     ====> Val Epoch: 24 Average NEG IWELBO: 735.5773
# 2019-05-23 16:58:21,144 luigi-interface INFO     [pid 4688] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=4688) done      TrainIWAE()
# 2019-05-23 16:58:21,144 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-23 16:58:21,145 luigi-interface INFO     Informed scheduler that task   TrainIWAE__99914b932b   has status   DONE
# 2019-05-23 16:58:21,145 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-23 16:58:21,145 luigi-interface DEBUG    Pending tasks: 2
# 2019-05-23 16:58:21,145 luigi-interface INFO     [pid 4688] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=4688) running   Report()
# 2019-05-23 16:58:21,148 luigi-interface INFO     [pid 4688] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=4688) done      Report()
# 2019-05-23 16:58:21,148 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-23 16:58:21,148 luigi-interface INFO     Informed scheduler that task   Report__99914b932b   has status   DONE
# 2019-05-23 16:58:21,148 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-23 16:58:21,149 luigi-interface DEBUG    Pending tasks: 1
# 2019-05-23 16:58:21,149 luigi-interface INFO     [pid 4688] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=4688) running   RunAll()
# 2019-05-23 16:58:21,149 luigi-interface INFO     [pid 4688] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=4688) done      RunAll()
# 2019-05-23 16:58:21,149 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-23 16:58:21,149 luigi-interface INFO     Informed scheduler that task   RunAll__99914b932b   has status   DONE
# 2019-05-23 16:58:21,150 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-23 16:58:21,150 luigi-interface DEBUG    Done
# 2019-05-23 16:58:21,150 luigi-interface DEBUG    There are no more tasks to run at this time
# 2019-05-23 16:58:21,150 luigi-interface INFO     Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=4688) was stopped. Shutting down Keep-Alive thread
# 2019-05-23 16:58:21,151 luigi-interface INFO
# ===== Luigi Execution Summary =====
#
# Scheduled 5 tasks of which:
# * 5 ran successfully:
#     - 1 Report()
#     - 1 RunAll()
#     - 1 TrainIWAE()
#     - 1 TrainVAE()
#     - 1 TrainVEM()
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
#
#
#
# -- Log file: logs2019-05-23 17:26:19.935086.txt
#
# 2019-05-23 17:26:19,935 root         INFO     start
# 2019-05-23 17:26:19,949 luigi        INFO     logging configured by default settings
# 2019-05-23 17:26:19,975 luigi-interface DEBUG    Checking if RunAll() is complete
# 2019-05-23 17:26:19,975 luigi-interface DEBUG    Checking if Report() is complete
# 2019-05-23 17:26:19,976 luigi-interface INFO     Informed scheduler that task   RunAll__99914b932b   has status   PENDING
# 2019-05-23 17:26:19,976 luigi-interface INFO     Informed scheduler that task   Report__99914b932b   has status   DONE
# 2019-05-23 17:26:19,976 luigi-interface INFO     Done scheduling tasks
# 2019-05-23 17:26:19,976 luigi-interface INFO     Running Worker with 1 processes
# 2019-05-23 17:26:19,976 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-23 17:26:19,977 luigi-interface DEBUG    Pending tasks: 1
# 2019-05-23 17:26:19,977 luigi-interface INFO     [pid 11005] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=11005) running   RunAll()
# 2019-05-23 17:26:19,977 luigi-interface INFO     [pid 11005] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=11005) done      RunAll()
# 2019-05-23 17:26:19,977 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-23 17:26:19,978 luigi-interface INFO     Informed scheduler that task   RunAll__99914b932b   has status   DONE
# 2019-05-23 17:26:19,978 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-23 17:26:19,978 luigi-interface DEBUG    Done
# 2019-05-23 17:26:19,978 luigi-interface DEBUG    There are no more tasks to run at this time
# 2019-05-23 17:26:19,978 luigi-interface INFO     Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=11005) was stopped. Shutting down Keep-Alive thread
# 2019-05-23 17:26:19,979 luigi-interface INFO
# ===== Luigi Execution Summary =====
#
# Scheduled 2 tasks of which:
# * 1 complete ones were encountered:
#     - 1 Report()
# * 1 ran successfully:
#     - 1 RunAll()
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
