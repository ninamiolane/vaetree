# %%
import glob
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import pickle
from scipy.stats import gaussian_kde
import seaborn as sns
import re

import importlib
import toylosses
importlib.reload(toylosses)
import toynn
importlib.reload(toynn)
import toyvis
importlib.reload(toyvis)

import torch
#sns.set()

import toypipeline
importlib.reload(toypipeline)

DEVICE = 'cuda'
OUTPUT = '/scratch/users/nmiolane/imoutput'

# %% [markdown]
# # Inspect Functions

# %%
def kl_posterior(w, phi, subdataset):
  
    sig2 = np.mean(subdataset ** 2, axis=0)
    
    kl_posterior_1 = - 1. / 2. * np.log(1 + w ** 2) 
    kl_posterior_2 = 1. /2. * (1 + w ** 2 ) 
    kl_posterior_3 = 1. / 2. * (w - phi - phi * w ** 2) ** 2 * sig2 / (1 + w ** 2) - 1. / 2.
    kl_posterior = kl_posterior_1 + kl_posterior_2 + kl_posterior_3
    return kl_posterior

# %%
algo_strings = {'vae': 'VAE', 'iwae': 'IWAE', 'vem': 'AVEM'}
crit_strings = {'neg_elbo': 'Neg ELBO', 'neg_iwelbo': 'Neg IWELBO', 'neg_loglikelihood': 'NLL'}
train_val_strings = {'train': 'Train', 'val': 'Valid'}

# %%
def plot_criterion(ax, algo_name='vae', crit_name='neg_elbo', mode='train', 
                   from_epoch=0, to_epoch=1000, color='blue', dashes=False):
    losses_path = glob.glob(f'{OUTPUT}/train_{algo_name}/{mode}_losses.pkl')[0]
    losses_all_epochs = pickle.load(open(losses_path, 'rb'))
    
    losses_total = [loss[crit_name] for loss in losses_all_epochs]
    
    n_epochs = len(losses_total)
    epochs = range(n_epochs)
    to_epoch = min(to_epoch, n_epochs)
    
    label = f'{algo_strings[algo_name]}: {train_val_strings[mode]} {crit_strings[crit_name]}'
   
    if not dashes:
        ax.plot(epochs[from_epoch:to_epoch], losses_total[from_epoch:to_epoch], 
                label=label, color=color)
    else:
        ax.plot(epochs[from_epoch:to_epoch], losses_total[from_epoch:to_epoch], 
                label=label, color=color, dashes=[2, 2, 2, 2])
    ax.set_xlabel('epochs')
    ax.legend()
    return ax

# %%
def plot_kl_posterior(ax, algo_name='vae', mode='train',
                      from_epoch=0, to_epoch=1000, color='blue', dashes=False):
    losses_path = glob.glob(f'{OUTPUT}/train_{algo_name}/train_losses.pkl')[0]
    losses_all_epochs = pickle.load(open(losses_path, 'rb'))
    
    weight_w = [loss['weight_w'] for loss in losses_all_epochs]
    weight_phi = [loss['weight_phi'] for loss in losses_all_epochs]
    
    # Take absolute value to avoid identifiability problem
    weight_w = np.abs(weight_w)
    weight_phi = np.abs(weight_phi)
    
    n_epochs = len(weight_w)
    epochs = range(n_epochs)
    to_epoch = min(to_epoch, n_epochs)
    
    dataset_path = glob.glob(f'{OUTPUT}/synthetic/dataset.npy')[0]
    dataset = np.load(dataset_path)
    if mode == 'train':
        subdataset = dataset[:N_TRAIN,]  
    if mode == 'val':
        subdataset = dataset[N_TRAIN:,]
        
    kl = kl_posterior(weight_w, weight_phi, subdataset)
    label = f'{algo_strings[algo_name]}: {train_val_strings[mode]} KL'
   
    if not dashes:
        ax.plot(epochs[from_epoch:to_epoch], kl[from_epoch:to_epoch], 
                label=label, color=color)
    else:
        ax.plot(epochs[from_epoch:to_epoch], kl[from_epoch:to_epoch], 
                label=label, color=color, dashes=[2, 2, 2, 2])
    ax.set_xlabel('epochs')
    return ax

# %% [markdown]
# # Comparison of Convergences

# %%
from_epoch = 2
to_epoch = 50

# %%
color_dict = {'neg_elbo': 'red', 'neg_iwelbo': 'orange'}

def plot_convergence(ax, algo_name, crit_name):
    ax = plot_criterion(ax, algo_name=algo_name, crit_name=crit_name, mode='train', 
                    from_epoch=from_epoch, to_epoch=to_epoch, color=color_dict[crit_name])
    ax = plot_criterion(ax, algo_name=algo_name, crit_name=crit_name, mode='val', 
                    from_epoch=from_epoch, to_epoch=to_epoch, color=color_dict[crit_name], dashes=True)
    ax.set_title(f'Convergence of {algo_strings[algo_name]}.')
    return ax

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(18, 4))

ax = axes[0]
ax = plot_convergence(ax, 'vae', 'neg_elbo')

ax = axes[1]
ax = plot_convergence(ax, 'iwae', 'neg_iwelbo')

ax = axes[2]
ax = plot_convergence(ax, 'vem', 'neg_elbo')
ax = axes[3]
ax = plot_convergence(ax, 'vem', 'neg_iwelbo')

# %%
algo_color_dict = {'vae': 'red', 'iwae': 'orange', 'vem': 'blue'}

def plot_nll(ax, algo_name):
    ax = plot_criterion(ax, algo_name=algo_name, crit_name='neg_loglikelihood', mode='train', 
                    from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name])
    ax = plot_criterion(ax, algo_name=algo_name, crit_name='neg_loglikelihood', mode='val', 
                    from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name], dashes=True)
    return ax

def plot_kl(ax, algo_name):
    ax = plot_kl_posterior(ax, algo_name=algo_name, mode='train',
                      from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name], dashes=False)
    ax = plot_kl_posterior(ax, algo_name=algo_name, mode='val',
                      from_epoch=from_epoch, to_epoch=to_epoch, color=algo_color_dict[algo_name], dashes=True)
    
    return ax

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

ax = axes[0]
ax = plot_nll(ax, 'vae')
ax = plot_nll(ax, 'iwae')
ax = plot_nll(ax, 'vem')
ax.set_title('NLL estimated (estimated)')

ax = axes[1]
ax = plot_kl(ax, 'vae')
ax = plot_kl(ax, 'iwae')
ax = plot_kl(ax, 'vem')
ax.set_title('KL to posterior (estimated)')
ax.legend(loc='lower right')
# Out:
# Text(0.5, 1.0, 'Convergence in parameters (Zoom)')

# %% [markdown]
# # Comparison of data distribution and posterior distributions

# %%
algo_name = 'iwae'

def plot_data_distribution(ax, algo_name='vae'):
    n_samples = 1000
    
    decoder_path = glob.glob(f'{OUTPUT}/train_{algo_name}/models/decoder.pth')[0]
    decoder = torch.load(decoder_path, map_location=DEVICE)
    
    generated_true_x = toynn.generate_from_decoder(decoder_true, n_samples)
    generated_x = toynn.generate_from_decoder(decoder, n_samples)

    toyvis.plot_data(generated_true_x, color='darkgreen', ax=ax)
    toyvis.plot_data(generated_x, color=algo_color_dict[algo_name], ax=ax)
    ax.set_title('Data distributions p(x)')
    ax.set_xlabel('x')
    return ax

def plot_posterior(ax, algo_name='vae'):
    n_to_sample = 10000
    w_true = 2
    x = 3
    
    encoder_path = glob.glob(f'{OUTPUT}/train_{algo_name}/models/encoder.pth')[0]
    encoder = torch.load(encoder_path, map_location=DEVICE)
    
    weight_phi = encoder.fc1.weight[[0]]    
    weight_phi = weight_phi.detach().cpu().numpy()
    weight_phi = np.abs(weight_phi)
    
    true_loc = w_true / (w_true ** 2 + 1) * x
    true_scale = 1/ np.sqrt((1 + w_true ** 2))
    z_true_posterior = np.random.normal(loc=true_loc, scale=true_scale, size=(n_to_sample, 1))
    z_opt_posterior = np.random.normal(loc=true_loc, scale=1, size=(n_to_sample, 1))
    z_encoder = np.random.normal(loc=weight_phi*x, scale=1, size=(n_to_sample, 1)) 
                        
    ax = toyvis.plot_data(z_true_posterior, color='darkgreen', ax=ax)
    # ax = toyvis.plot_data(z_opt_posterior, color='blue', ax=ax)
    ax = toyvis.plot_data(z_encoder, color=algo_color_dict[algo_name], ax=ax)
    ax.set_title('Posteriors z | x = 3')
    ax.set_xlabel('z')
    return ax

fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(18, 2))

ax = axes[0]
ax = plot_data_distribution(ax, 'vae')

ax = axes[1]
ax = plot_data_distribution(ax, 'iwae')

ax = axes[2]
ax = plot_data_distribution(ax, 'vem')

ax = axes[3]
ax = plot_posterior(ax, 'vae')

ax = axes[4]
ax = plot_posterior(ax, 'iwae')

ax = axes[5]
ax = plot_posterior(ax, 'vem')

# %% [markdown]
# # Comparison of times

# %%
def print_average_time(algo_name='vae'):
    losses_path = glob.glob(f'{OUTPUT}/train_{algo_name}/train_losses.pkl')[0]
    losses_all_epochs = pickle.load(open(losses_path, 'rb'))
    
    times = [loss['total_time'] for loss in losses_all_epochs]
    print(np.mean(times))
    
print_average_time('vae')
print_average_time('iwae')
print_average_time('vem')
# Out:
# 139.98291923999787
# 6.78458604812622
# 7.108811521530152

# %% [markdown]
# # Print pipeline logs

# %%
pattern = 'logs'
logs = []
for filename in os.listdir(OUTPUT):
    if re.search(pattern, filename):
        logs.append(filename)

print('Found %d log files.' % len(logs))
        
for filename in logs:
    path = os.path.join(OUTPUT, filename)
    print('\n-- Log file: %s\n' % filename)
    with open(path, 'r') as f:
        message = f.read()
    print(message)
# Out:
# Found 1 log files.
#
# -- Log file: logs2019-05-17 22:05:22.503695.txt
#
# 2019-05-17 22:05:22,503 root         INFO     start
# 2019-05-17 22:05:22,518 luigi        INFO     logging configured by default settings
# 2019-05-17 22:05:22,542 luigi-interface DEBUG    Checking if RunAll() is complete
# 2019-05-17 22:05:22,543 luigi-interface DEBUG    Checking if Report() is complete
# 2019-05-17 22:05:22,543 luigi-interface INFO     Informed scheduler that task   RunAll__99914b932b   has status   PENDING
# 2019-05-17 22:05:22,544 luigi-interface DEBUG    Checking if TrainVAE() is complete
# 2019-05-17 22:05:22,544 luigi-interface DEBUG    Checking if TrainIWAE() is complete
# 2019-05-17 22:05:22,545 luigi-interface DEBUG    Checking if TrainVEM() is complete
# 2019-05-17 22:05:22,545 luigi-interface INFO     Informed scheduler that task   Report__99914b932b   has status   PENDING
# 2019-05-17 22:05:22,546 luigi-interface DEBUG    Checking if MakeDataSet() is complete
# 2019-05-17 22:05:22,546 luigi-interface INFO     Informed scheduler that task   TrainVEM__99914b932b   has status   PENDING
# 2019-05-17 22:05:22,546 luigi-interface INFO     Informed scheduler that task   MakeDataSet__99914b932b   has status   PENDING
# 2019-05-17 22:05:22,546 luigi-interface INFO     Informed scheduler that task   TrainIWAE__99914b932b   has status   PENDING
# 2019-05-17 22:05:22,547 luigi-interface INFO     Informed scheduler that task   TrainVAE__99914b932b   has status   PENDING
# 2019-05-17 22:05:22,547 luigi-interface INFO     Done scheduling tasks
# 2019-05-17 22:05:22,547 luigi-interface INFO     Running Worker with 1 processes
# 2019-05-17 22:05:22,547 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-17 22:05:22,547 luigi-interface DEBUG    Pending tasks: 6
# 2019-05-17 22:05:22,547 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) running   MakeDataSet()
# 2019-05-17 22:05:22,548 root         INFO     Configuration:
# 2019-05-17 22:05:22,548 root         INFO     DATA_DIM = 1
# 2019-05-17 22:05:22,548 root         INFO     LATENT_DIM = 1
# 2019-05-17 22:05:22,548 root         INFO     N_DECODER_LAYERS = 1
# 2019-05-17 22:05:22,548 root         INFO     NONLINEARITY=False
# 2019-05-17 22:05:22,548 root         INFO     WITH_BIASX=False
# 2019-05-17 22:05:22,548 root         INFO     WITH_LOGVARX=False
# 2019-05-17 22:05:22,548 root         INFO     WITH_BIASZ=False
# 2019-05-17 22:05:22,548 root         INFO     WITH_LOGVARZ=False
# 2019-05-17 22:05:22,548 root         INFO     N_SAMPLES=10000
# 2019-05-17 22:05:22,548 root         INFO     W_TRUE:
# 2019-05-17 22:05:22,548 root         INFO     {0: [[2.0]]}
# 2019-05-17 22:05:22,548 root         INFO     B_TRUE:
# 2019-05-17 22:05:22,548 root         INFO     {}
# 2019-05-17 22:05:26,367 root         INFO     Values of true 'decoder' parameters:
# 2019-05-17 22:05:26,367 root         INFO     layers.0.weight
# 2019-05-17 22:05:26,367 root         INFO     tensor([[2.]], device='cuda:0')
# 2019-05-17 22:05:26,441 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) done      MakeDataSet()
# 2019-05-17 22:05:26,442 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-17 22:05:26,442 luigi-interface INFO     Informed scheduler that task   MakeDataSet__99914b932b   has status   DONE
# 2019-05-17 22:05:26,442 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-17 22:05:26,442 luigi-interface DEBUG    Pending tasks: 5
# 2019-05-17 22:05:26,442 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) running   TrainVAE()
# 2019-05-17 22:05:26,444 root         INFO     --Dataset tensor: (10000, 1)
# 2019-05-17 22:05:26,444 root         INFO     -- Train tensor: (8000, 1)
# 2019-05-17 22:05:26,444 root         INFO     -- Validation tensor: (2000, 1)
# 2019-05-17 22:05:26,445 root         INFO     Values of VAE's decoder parameters before training:
# 2019-05-17 22:05:26,445 root         INFO     layers.0.weight
# 2019-05-17 22:05:26,445 root         INFO     tensor([[0.9843]], device='cuda:0')
# 2019-05-17 22:05:26,505 root         INFO     Train Epoch: 0 [0/8000 (0%)]	Batch Neg ELBO: 7.947448
# Reconstruction: 7.170979, Regularization: 0.776469
# 2019-05-17 22:05:26,551 root         INFO     Train Epoch: 0 [512/8000 (6%)]	Batch Neg ELBO: 5.241745
# Reconstruction: 4.792336, Regularization: 0.449408
# 2019-05-17 22:05:26,596 root         INFO     Train Epoch: 0 [1024/8000 (13%)]	Batch Neg ELBO: 4.900143
# Reconstruction: 4.498724, Regularization: 0.401419
# 2019-05-17 22:05:26,641 root         INFO     Train Epoch: 0 [1536/8000 (19%)]	Batch Neg ELBO: 6.196386
# Reconstruction: 5.666515, Regularization: 0.529871
# 2019-05-17 22:05:26,686 root         INFO     Train Epoch: 0 [2048/8000 (26%)]	Batch Neg ELBO: 6.529162
# Reconstruction: 5.983389, Regularization: 0.545773
# 2019-05-17 22:05:26,731 root         INFO     Train Epoch: 0 [2560/8000 (32%)]	Batch Neg ELBO: 4.745511
# Reconstruction: 4.392980, Regularization: 0.352531
# 2019-05-17 22:05:26,776 root         INFO     Train Epoch: 0 [3072/8000 (38%)]	Batch Neg ELBO: 5.568696
# Reconstruction: 5.150579, Regularization: 0.418117
# 2019-05-17 22:05:26,821 root         INFO     Train Epoch: 0 [3584/8000 (45%)]	Batch Neg ELBO: 7.352244
# Reconstruction: 6.783929, Regularization: 0.568316
# 2019-05-17 22:05:26,866 root         INFO     Train Epoch: 0 [4096/8000 (51%)]	Batch Neg ELBO: 7.648108
# Reconstruction: 7.075304, Regularization: 0.572804
# 2019-05-17 22:05:26,911 root         INFO     Train Epoch: 0 [4608/8000 (58%)]	Batch Neg ELBO: 7.010714
# Reconstruction: 6.512498, Regularization: 0.498216
# 2019-05-17 22:05:26,957 root         INFO     Train Epoch: 0 [5120/8000 (64%)]	Batch Neg ELBO: 5.189764
# Reconstruction: 4.862162, Regularization: 0.327602
# 2019-05-17 22:05:27,002 root         INFO     Train Epoch: 0 [5632/8000 (70%)]	Batch Neg ELBO: 6.652480
# Reconstruction: 6.222576, Regularization: 0.429904
# 2019-05-17 22:05:27,045 root         INFO     Train Epoch: 0 [6144/8000 (77%)]	Batch Neg ELBO: 5.859538
# Reconstruction: 5.510880, Regularization: 0.348658
# 2019-05-17 22:05:27,088 root         INFO     Train Epoch: 0 [6656/8000 (83%)]	Batch Neg ELBO: 4.478884
# Reconstruction: 4.243633, Regularization: 0.235251
# 2019-05-17 22:05:27,132 root         INFO     Train Epoch: 0 [7168/8000 (90%)]	Batch Neg ELBO: 3.595692
# Reconstruction: 3.429257, Regularization: 0.166436
# 2019-05-17 22:05:27,175 root         INFO     Train Epoch: 0 [7680/8000 (96%)]	Batch Neg ELBO: 5.722009
# Reconstruction: 5.427976, Regularization: 0.294033
# 2019-05-17 22:05:27,248 root         INFO     ====> Epoch: 0 Average Neg ELBO: 5.7081
# 2019-05-17 22:05:27,270 root         INFO     Val Epoch: 0 [0/2000 (0%)]	Batch Neg ELBO: 5.326211
# Reconstruction: 5.067301, Regularization: 0.258910
# 2019-05-17 22:05:27,301 root         INFO     Val Epoch: 0 [512/2000 (25%)]	Batch Neg ELBO: 4.262020
# Reconstruction: 4.067668, Regularization: 0.194352
# 2019-05-17 22:05:27,331 root         INFO     Val Epoch: 0 [1024/2000 (51%)]	Batch Neg ELBO: 3.664350
# Reconstruction: 3.507394, Regularization: 0.156956
# 2019-05-17 22:05:27,361 root         INFO     Val Epoch: 0 [1536/2000 (76%)]	Batch Neg ELBO: 3.969464
# Reconstruction: 3.794604, Regularization: 0.174860
# 2019-05-17 22:05:27,411 root         INFO     ====> Val Epoch: 0 Average Neg ELBO: 4.9107
# 2019-05-17 22:05:27,435 root         INFO     Train Epoch: 1 [0/8000 (0%)]	Batch Neg ELBO: 5.112438
# Reconstruction: 4.865574, Regularization: 0.246863
# 2019-05-17 22:05:27,477 root         INFO     Train Epoch: 1 [512/8000 (6%)]	Batch Neg ELBO: 4.214150
# Reconstruction: 4.034644, Regularization: 0.179506
# 2019-05-17 22:05:27,519 root         INFO     Train Epoch: 1 [1024/8000 (13%)]	Batch Neg ELBO: 4.929201
# Reconstruction: 4.720559, Regularization: 0.208642
# 2019-05-17 22:05:27,561 root         INFO     Train Epoch: 1 [1536/8000 (19%)]	Batch Neg ELBO: 4.662582
# Reconstruction: 4.480053, Regularization: 0.182529
# 2019-05-17 22:05:27,603 root         INFO     Train Epoch: 1 [2048/8000 (26%)]	Batch Neg ELBO: 4.763369
# Reconstruction: 4.587946, Regularization: 0.175423
# 2019-05-17 22:05:27,645 root         INFO     Train Epoch: 1 [2560/8000 (32%)]	Batch Neg ELBO: 3.731434
# Reconstruction: 3.613673, Regularization: 0.117762
# 2019-05-17 22:05:27,687 root         INFO     Train Epoch: 1 [3072/8000 (38%)]	Batch Neg ELBO: 3.820236
# Reconstruction: 3.706487, Regularization: 0.113749
# 2019-05-17 22:05:27,728 root         INFO     Train Epoch: 1 [3584/8000 (45%)]	Batch Neg ELBO: 4.812312
# Reconstruction: 4.668816, Regularization: 0.143497
# 2019-05-17 22:05:27,770 root         INFO     Train Epoch: 1 [4096/8000 (51%)]	Batch Neg ELBO: 4.004340
# Reconstruction: 3.900182, Regularization: 0.104158
# 2019-05-17 22:05:27,812 root         INFO     Train Epoch: 1 [4608/8000 (58%)]	Batch Neg ELBO: 3.644486
# Reconstruction: 3.560544, Regularization: 0.083943
# 2019-05-17 22:05:27,853 root         INFO     Train Epoch: 1 [5120/8000 (64%)]	Batch Neg ELBO: 4.334696
# Reconstruction: 4.236482, Regularization: 0.098214
# 2019-05-17 22:05:27,895 root         INFO     Train Epoch: 1 [5632/8000 (70%)]	Batch Neg ELBO: 5.799967
# Reconstruction: 5.670135, Regularization: 0.129832
# 2019-05-17 22:05:27,937 root         INFO     Train Epoch: 1 [6144/8000 (77%)]	Batch Neg ELBO: 3.316387
# Reconstruction: 3.260296, Regularization: 0.056091
# 2019-05-17 22:05:27,978 root         INFO     Train Epoch: 1 [6656/8000 (83%)]	Batch Neg ELBO: 2.456054
# Reconstruction: 2.424408, Regularization: 0.031646
# 2019-05-17 22:05:28,019 root         INFO     Train Epoch: 1 [7168/8000 (90%)]	Batch Neg ELBO: 5.613795
# Reconstruction: 5.523171, Regularization: 0.090624
# 2019-05-17 22:05:28,059 root         INFO     Train Epoch: 1 [7680/8000 (96%)]	Batch Neg ELBO: 3.818813
# Reconstruction: 3.769204, Regularization: 0.049609
# 2019-05-17 22:05:28,120 root         INFO     ====> Epoch: 1 Average Neg ELBO: 4.2592
# 2019-05-17 22:05:28,143 root         INFO     Val Epoch: 1 [0/2000 (0%)]	Batch Neg ELBO: 5.350921
# Reconstruction: 5.279449, Regularization: 0.071472
# 2019-05-17 22:05:28,174 root         INFO     Val Epoch: 1 [512/2000 (25%)]	Batch Neg ELBO: 3.709836
# Reconstruction: 3.665575, Regularization: 0.044261
# 2019-05-17 22:05:28,204 root         INFO     Val Epoch: 1 [1024/2000 (51%)]	Batch Neg ELBO: 3.517647
# Reconstruction: 3.476347, Regularization: 0.041299
# 2019-05-17 22:05:28,235 root         INFO     Val Epoch: 1 [1536/2000 (76%)]	Batch Neg ELBO: 3.640096
# Reconstruction: 3.596849, Regularization: 0.043248
# 2019-05-17 22:05:28,285 root         INFO     ====> Val Epoch: 1 Average Neg ELBO: 3.9511
# 2019-05-17 22:05:28,309 root         INFO     Train Epoch: 2 [0/8000 (0%)]	Batch Neg ELBO: 2.855092
# Reconstruction: 2.824672, Regularization: 0.030420
# 2019-05-17 22:05:28,350 root         INFO     Train Epoch: 2 [512/8000 (6%)]	Batch Neg ELBO: 3.389369
# Reconstruction: 3.354923, Regularization: 0.034446
# 2019-05-17 22:05:28,392 root         INFO     Train Epoch: 2 [1024/8000 (13%)]	Batch Neg ELBO: 4.956698
# Reconstruction: 4.906493, Regularization: 0.050205
# 2019-05-17 22:05:28,434 root         INFO     Train Epoch: 2 [1536/8000 (19%)]	Batch Neg ELBO: 2.962371
# Reconstruction: 2.941180, Regularization: 0.021190
# 2019-05-17 22:05:28,475 root         INFO     Train Epoch: 2 [2048/8000 (26%)]	Batch Neg ELBO: 3.353900
# Reconstruction: 3.331816, Regularization: 0.022084
# 2019-05-17 22:05:28,517 root         INFO     Train Epoch: 2 [2560/8000 (32%)]	Batch Neg ELBO: 4.113163
# Reconstruction: 4.088181, Regularization: 0.024982
# 2019-05-17 22:05:28,558 root         INFO     Train Epoch: 2 [3072/8000 (38%)]	Batch Neg ELBO: 3.799641
# Reconstruction: 3.780596, Regularization: 0.019046
# 2019-05-17 22:05:28,599 root         INFO     Train Epoch: 2 [3584/8000 (45%)]	Batch Neg ELBO: 4.311207
# Reconstruction: 4.292649, Regularization: 0.018558
# 2019-05-17 22:05:28,640 root         INFO     Train Epoch: 2 [4096/8000 (51%)]	Batch Neg ELBO: 3.960128
# Reconstruction: 3.946825, Regularization: 0.013303
# 2019-05-17 22:05:28,681 root         INFO     Train Epoch: 2 [4608/8000 (58%)]	Batch Neg ELBO: 4.214798
# Reconstruction: 4.203547, Regularization: 0.011251
# 2019-05-17 22:05:28,723 root         INFO     Train Epoch: 2 [5120/8000 (64%)]	Batch Neg ELBO: 4.857858
# Reconstruction: 4.847237, Regularization: 0.010621
# 2019-05-17 22:05:28,763 root         INFO     Train Epoch: 2 [5632/8000 (70%)]	Batch Neg ELBO: 2.960917
# Reconstruction: 2.957004, Regularization: 0.003914
# 2019-05-17 22:05:28,804 root         INFO     Train Epoch: 2 [6144/8000 (77%)]	Batch Neg ELBO: 3.962027
# Reconstruction: 3.957824, Regularization: 0.004204
# 2019-05-17 22:05:28,844 root         INFO     Train Epoch: 2 [6656/8000 (83%)]	Batch Neg ELBO: 3.283387
# Reconstruction: 3.281346, Regularization: 0.002042
# 2019-05-17 22:05:28,885 root         INFO     Train Epoch: 2 [7168/8000 (90%)]	Batch Neg ELBO: 4.811800
# Reconstruction: 4.809718, Regularization: 0.002082
# 2019-05-17 22:05:28,925 root         INFO     Train Epoch: 2 [7680/8000 (96%)]	Batch Neg ELBO: 3.022651
# Reconstruction: 3.022101, Regularization: 0.000550
# 2019-05-17 22:05:28,987 root         INFO     ====> Epoch: 2 Average Neg ELBO: 3.6346
# 2019-05-17 22:05:29,010 root         INFO     Val Epoch: 2 [0/2000 (0%)]	Batch Neg ELBO: 3.235995
# Reconstruction: 3.235674, Regularization: 0.000321
# 2019-05-17 22:05:29,041 root         INFO     Val Epoch: 2 [512/2000 (25%)]	Batch Neg ELBO: 4.604024
# Reconstruction: 4.603505, Regularization: 0.000519
# 2019-05-17 22:05:29,071 root         INFO     Val Epoch: 2 [1024/2000 (51%)]	Batch Neg ELBO: 2.403959
# Reconstruction: 2.403758, Regularization: 0.000201
# 2019-05-17 22:05:29,102 root         INFO     Val Epoch: 2 [1536/2000 (76%)]	Batch Neg ELBO: 2.909844
# Reconstruction: 2.909570, Regularization: 0.000274
# 2019-05-17 22:05:29,153 root         INFO     ====> Val Epoch: 2 Average Neg ELBO: 3.5492
# 2019-05-17 22:05:29,176 root         INFO     Train Epoch: 3 [0/8000 (0%)]	Batch Neg ELBO: 4.436440
# Reconstruction: 4.435946, Regularization: 0.000494
# 2019-05-17 22:05:29,216 root         INFO     Train Epoch: 3 [512/8000 (6%)]	Batch Neg ELBO: 4.202589
# Reconstruction: 4.202508, Regularization: 0.000080
# 2019-05-17 22:05:29,257 root         INFO     Train Epoch: 3 [1024/8000 (13%)]	Batch Neg ELBO: 3.288825
# Reconstruction: 3.288812, Regularization: 0.000013
# 2019-05-17 22:05:29,297 root         INFO     Train Epoch: 3 [1536/8000 (19%)]	Batch Neg ELBO: 3.390529
# Reconstruction: 3.390332, Regularization: 0.000198
# 2019-05-17 22:05:29,336 root         INFO     Train Epoch: 3 [2048/8000 (26%)]	Batch Neg ELBO: 3.450894
# Reconstruction: 3.450299, Regularization: 0.000596
# 2019-05-17 22:05:29,377 root         INFO     Train Epoch: 3 [2560/8000 (32%)]	Batch Neg ELBO: 2.284264
# Reconstruction: 2.283649, Regularization: 0.000615
# 2019-05-17 22:05:29,417 root         INFO     Train Epoch: 3 [3072/8000 (38%)]	Batch Neg ELBO: 3.470154
# Reconstruction: 3.468295, Regularization: 0.001858
# 2019-05-17 22:05:29,457 root         INFO     Train Epoch: 3 [3584/8000 (45%)]	Batch Neg ELBO: 2.798746
# Reconstruction: 2.796651, Regularization: 0.002095
# 2019-05-17 22:05:29,497 root         INFO     Train Epoch: 3 [4096/8000 (51%)]	Batch Neg ELBO: 3.275526
# Reconstruction: 3.271807, Regularization: 0.003719
# 2019-05-17 22:05:29,536 root         INFO     Train Epoch: 3 [4608/8000 (58%)]	Batch Neg ELBO: 2.813358
# Reconstruction: 2.809440, Regularization: 0.003918
# 2019-05-17 22:05:29,576 root         INFO     Train Epoch: 3 [5120/8000 (64%)]	Batch Neg ELBO: 3.071784
# Reconstruction: 3.066044, Regularization: 0.005739
# 2019-05-17 22:05:29,616 root         INFO     Train Epoch: 3 [5632/8000 (70%)]	Batch Neg ELBO: 4.386046
# Reconstruction: 4.374293, Regularization: 0.011753
# 2019-05-17 22:05:29,656 root         INFO     Train Epoch: 3 [6144/8000 (77%)]	Batch Neg ELBO: 3.261981
# Reconstruction: 3.252126, Regularization: 0.009855
# 2019-05-17 22:05:29,696 root         INFO     Train Epoch: 3 [6656/8000 (83%)]	Batch Neg ELBO: 3.929018
# Reconstruction: 3.913572, Regularization: 0.015446
# 2019-05-17 22:05:29,736 root         INFO     Train Epoch: 3 [7168/8000 (90%)]	Batch Neg ELBO: 3.756496
# Reconstruction: 3.739492, Regularization: 0.017004
# 2019-05-17 22:05:29,776 root         INFO     Train Epoch: 3 [7680/8000 (96%)]	Batch Neg ELBO: 3.294086
# Reconstruction: 3.277649, Regularization: 0.016437
# 2019-05-17 22:05:29,849 root         INFO     ====> Epoch: 3 Average Neg ELBO: 3.3762
# 2019-05-17 22:05:29,872 root         INFO     Val Epoch: 3 [0/2000 (0%)]	Batch Neg ELBO: 3.976845
# Reconstruction: 3.953750, Regularization: 0.023094
# 2019-05-17 22:05:29,903 root         INFO     Val Epoch: 3 [512/2000 (25%)]	Batch Neg ELBO: 4.292473
# Reconstruction: 4.267012, Regularization: 0.025461
# 2019-05-17 22:05:29,933 root         INFO     Val Epoch: 3 [1024/2000 (51%)]	Batch Neg ELBO: 2.834562
# Reconstruction: 2.820320, Regularization: 0.014242
# 2019-05-17 22:05:29,964 root         INFO     Val Epoch: 3 [1536/2000 (76%)]	Batch Neg ELBO: 3.571336
# Reconstruction: 3.551418, Regularization: 0.019918
# 2019-05-17 22:05:30,015 root         INFO     ====> Val Epoch: 3 Average Neg ELBO: 3.3795
# 2019-05-17 22:05:30,039 root         INFO     Train Epoch: 4 [0/8000 (0%)]	Batch Neg ELBO: 3.105106
# Reconstruction: 3.088766, Regularization: 0.016340
# 2019-05-17 22:05:30,081 root         INFO     Train Epoch: 4 [512/8000 (6%)]	Batch Neg ELBO: 1.984907
# Reconstruction: 1.976213, Regularization: 0.008694
# 2019-05-17 22:05:30,124 root         INFO     Train Epoch: 4 [1024/8000 (13%)]	Batch Neg ELBO: 5.512827
# Reconstruction: 5.468687, Regularization: 0.044141
# 2019-05-17 22:05:30,166 root         INFO     Train Epoch: 4 [1536/8000 (19%)]	Batch Neg ELBO: 3.643988
# Reconstruction: 3.614746, Regularization: 0.029242
# 2019-05-17 22:05:30,209 root         INFO     Train Epoch: 4 [2048/8000 (26%)]	Batch Neg ELBO: 3.610089
# Reconstruction: 3.578045, Regularization: 0.032045
# 2019-05-17 22:05:30,251 root         INFO     Train Epoch: 4 [2560/8000 (32%)]	Batch Neg ELBO: 3.463511
# Reconstruction: 3.430291, Regularization: 0.033220
# 2019-05-17 22:05:30,293 root         INFO     Train Epoch: 4 [3072/8000 (38%)]	Batch Neg ELBO: 3.460468
# Reconstruction: 3.423515, Regularization: 0.036953
# 2019-05-17 22:05:30,335 root         INFO     Train Epoch: 4 [3584/8000 (45%)]	Batch Neg ELBO: 2.947888
# Reconstruction: 2.915876, Regularization: 0.032012
# 2019-05-17 22:05:30,377 root         INFO     Train Epoch: 4 [4096/8000 (51%)]	Batch Neg ELBO: 3.792082
# Reconstruction: 3.742304, Regularization: 0.049778
# 2019-05-17 22:05:30,419 root         INFO     Train Epoch: 4 [4608/8000 (58%)]	Batch Neg ELBO: 3.535094
# Reconstruction: 3.486064, Regularization: 0.049029
# 2019-05-17 22:05:30,462 root         INFO     Train Epoch: 4 [5120/8000 (64%)]	Batch Neg ELBO: 3.501637
# Reconstruction: 3.449224, Regularization: 0.052413
# 2019-05-17 22:05:30,504 root         INFO     Train Epoch: 4 [5632/8000 (70%)]	Batch Neg ELBO: 3.018656
# Reconstruction: 2.972797, Regularization: 0.045859
# 2019-05-17 22:05:30,546 root         INFO     Train Epoch: 4 [6144/8000 (77%)]	Batch Neg ELBO: 3.181180
# Reconstruction: 3.128424, Regularization: 0.052756
# 2019-05-17 22:05:30,588 root         INFO     Train Epoch: 4 [6656/8000 (83%)]	Batch Neg ELBO: 2.628218
# Reconstruction: 2.585785, Regularization: 0.042433
# 2019-05-17 22:05:30,630 root         INFO     Train Epoch: 4 [7168/8000 (90%)]	Batch Neg ELBO: 3.451466
# Reconstruction: 3.382886, Regularization: 0.068580
# 2019-05-17 22:05:30,673 root         INFO     Train Epoch: 4 [7680/8000 (96%)]	Batch Neg ELBO: 3.475857
# Reconstruction: 3.402112, Regularization: 0.073745
# 2019-05-17 22:05:30,735 root         INFO     ====> Epoch: 4 Average Neg ELBO: 3.2522
# 2019-05-17 22:05:30,757 root         INFO     Val Epoch: 4 [0/2000 (0%)]	Batch Neg ELBO: 2.799571
# Reconstruction: 2.743835, Regularization: 0.055736
# 2019-05-17 22:05:30,789 root         INFO     Val Epoch: 4 [512/2000 (25%)]	Batch Neg ELBO: 2.716408
# Reconstruction: 2.662944, Regularization: 0.053464
# 2019-05-17 22:05:30,819 root         INFO     Val Epoch: 4 [1024/2000 (51%)]	Batch Neg ELBO: 3.463685
# Reconstruction: 3.387070, Regularization: 0.076615
# 2019-05-17 22:05:30,849 root         INFO     Val Epoch: 4 [1536/2000 (76%)]	Batch Neg ELBO: 3.293028
# Reconstruction: 3.221830, Regularization: 0.071199
# 2019-05-17 22:05:30,900 root         INFO     ====> Val Epoch: 4 Average Neg ELBO: 3.2754
# 2019-05-17 22:05:30,923 root         INFO     Train Epoch: 5 [0/8000 (0%)]	Batch Neg ELBO: 4.261460
# Reconstruction: 4.160503, Regularization: 0.100957
# 2019-05-17 22:05:30,965 root         INFO     Train Epoch: 5 [512/8000 (6%)]	Batch Neg ELBO: 3.068877
# Reconstruction: 3.000642, Regularization: 0.068235
# 2019-05-17 22:05:31,007 root         INFO     Train Epoch: 5 [1024/8000 (13%)]	Batch Neg ELBO: 2.900853
# Reconstruction: 2.833328, Regularization: 0.067525
# 2019-05-17 22:05:31,048 root         INFO     Train Epoch: 5 [1536/8000 (19%)]	Batch Neg ELBO: 3.032261
# Reconstruction: 2.956043, Regularization: 0.076218
# 2019-05-17 22:05:31,090 root         INFO     Train Epoch: 5 [2048/8000 (26%)]	Batch Neg ELBO: 3.428013
# Reconstruction: 3.330550, Regularization: 0.097463
# 2019-05-17 22:05:31,132 root         INFO     Train Epoch: 5 [2560/8000 (32%)]	Batch Neg ELBO: 3.092832
# Reconstruction: 3.004601, Regularization: 0.088230
# 2019-05-17 22:05:31,173 root         INFO     Train Epoch: 5 [3072/8000 (38%)]	Batch Neg ELBO: 2.190794
# Reconstruction: 2.138143, Regularization: 0.052651
# 2019-05-17 22:05:31,214 root         INFO     Train Epoch: 5 [3584/8000 (45%)]	Batch Neg ELBO: 3.120146
# Reconstruction: 3.020448, Regularization: 0.099698
# 2019-05-17 22:05:31,256 root         INFO     Train Epoch: 5 [4096/8000 (51%)]	Batch Neg ELBO: 2.704013
# Reconstruction: 2.619778, Regularization: 0.084235
# 2019-05-17 22:05:31,298 root         INFO     Train Epoch: 5 [4608/8000 (58%)]	Batch Neg ELBO: 2.521882
# Reconstruction: 2.442147, Regularization: 0.079734
# 2019-05-17 22:05:31,339 root         INFO     Train Epoch: 5 [5120/8000 (64%)]	Batch Neg ELBO: 4.727044
# Reconstruction: 4.522500, Regularization: 0.204544
# 2019-05-17 22:05:31,380 root         INFO     Train Epoch: 5 [5632/8000 (70%)]	Batch Neg ELBO: 3.663026
# Reconstruction: 3.508101, Regularization: 0.154925
# 2019-05-17 22:05:31,422 root         INFO     Train Epoch: 5 [6144/8000 (77%)]	Batch Neg ELBO: 2.826626
# Reconstruction: 2.716025, Regularization: 0.110601
# 2019-05-17 22:05:31,464 root         INFO     Train Epoch: 5 [6656/8000 (83%)]	Batch Neg ELBO: 2.918636
# Reconstruction: 2.796130, Regularization: 0.122506
# 2019-05-17 22:05:31,505 root         INFO     Train Epoch: 5 [7168/8000 (90%)]	Batch Neg ELBO: 3.157683
# Reconstruction: 3.012702, Regularization: 0.144981
# 2019-05-17 22:05:31,547 root         INFO     Train Epoch: 5 [7680/8000 (96%)]	Batch Neg ELBO: 2.833816
# Reconstruction: 2.705787, Regularization: 0.128029
# 2019-05-17 22:05:31,609 root         INFO     ====> Epoch: 5 Average Neg ELBO: 3.1460
# 2019-05-17 22:05:31,631 root         INFO     Val Epoch: 5 [0/2000 (0%)]	Batch Neg ELBO: 3.113692
# Reconstruction: 2.960694, Regularization: 0.152999
# 2019-05-17 22:05:31,663 root         INFO     Val Epoch: 5 [512/2000 (25%)]	Batch Neg ELBO: 3.675771
# Reconstruction: 3.481765, Regularization: 0.194006
# 2019-05-17 22:05:31,693 root         INFO     Val Epoch: 5 [1024/2000 (51%)]	Batch Neg ELBO: 2.501817
# Reconstruction: 2.394056, Regularization: 0.107761
# 2019-05-17 22:05:31,724 root         INFO     Val Epoch: 5 [1536/2000 (76%)]	Batch Neg ELBO: 3.105588
# Reconstruction: 2.953912, Regularization: 0.151676
# 2019-05-17 22:05:31,775 root         INFO     ====> Val Epoch: 5 Average Neg ELBO: 3.1479
# 2019-05-17 22:05:31,799 root         INFO     Train Epoch: 6 [0/8000 (0%)]	Batch Neg ELBO: 3.552638
# Reconstruction: 3.368067, Regularization: 0.184571
# 2019-05-17 22:05:31,840 root         INFO     Train Epoch: 6 [512/8000 (6%)]	Batch Neg ELBO: 2.929844
# Reconstruction: 2.783075, Regularization: 0.146770
# 2019-05-17 22:05:31,882 root         INFO     Train Epoch: 6 [1024/8000 (13%)]	Batch Neg ELBO: 2.694228
# Reconstruction: 2.560209, Regularization: 0.134019
# 2019-05-17 22:05:31,924 root         INFO     Train Epoch: 6 [1536/8000 (19%)]	Batch Neg ELBO: 3.337674
# Reconstruction: 3.142875, Regularization: 0.194799
# 2019-05-17 22:05:31,965 root         INFO     Train Epoch: 6 [2048/8000 (26%)]	Batch Neg ELBO: 3.955197
# Reconstruction: 3.695306, Regularization: 0.259892
# 2019-05-17 22:05:32,007 root         INFO     Train Epoch: 6 [2560/8000 (32%)]	Batch Neg ELBO: 2.837810
# Reconstruction: 2.671760, Regularization: 0.166050
# 2019-05-17 22:05:32,048 root         INFO     Train Epoch: 6 [3072/8000 (38%)]	Batch Neg ELBO: 2.473874
# Reconstruction: 2.336508, Regularization: 0.137366
# 2019-05-17 22:05:32,090 root         INFO     Train Epoch: 6 [3584/8000 (45%)]	Batch Neg ELBO: 2.413774
# Reconstruction: 2.275033, Regularization: 0.138742
# 2019-05-17 22:05:32,131 root         INFO     Train Epoch: 6 [4096/8000 (51%)]	Batch Neg ELBO: 2.973969
# Reconstruction: 2.769147, Regularization: 0.204822
# 2019-05-17 22:05:32,172 root         INFO     Train Epoch: 6 [4608/8000 (58%)]	Batch Neg ELBO: 2.759503
# Reconstruction: 2.570010, Regularization: 0.189493
# 2019-05-17 22:05:32,214 root         INFO     Train Epoch: 6 [5120/8000 (64%)]	Batch Neg ELBO: 2.904052
# Reconstruction: 2.689502, Regularization: 0.214551
# 2019-05-17 22:05:32,255 root         INFO     Train Epoch: 6 [5632/8000 (70%)]	Batch Neg ELBO: 2.774646
# Reconstruction: 2.568417, Regularization: 0.206228
# 2019-05-17 22:05:32,296 root         INFO     Train Epoch: 6 [6144/8000 (77%)]	Batch Neg ELBO: 2.836430
# Reconstruction: 2.613157, Regularization: 0.223273
# 2019-05-17 22:05:32,338 root         INFO     Train Epoch: 6 [6656/8000 (83%)]	Batch Neg ELBO: 3.647528
# Reconstruction: 3.306934, Regularization: 0.340594
# 2019-05-17 22:05:32,379 root         INFO     Train Epoch: 6 [7168/8000 (90%)]	Batch Neg ELBO: 2.772349
# Reconstruction: 2.539468, Regularization: 0.232881
# 2019-05-17 22:05:32,421 root         INFO     Train Epoch: 6 [7680/8000 (96%)]	Batch Neg ELBO: 3.301512
# Reconstruction: 2.985315, Regularization: 0.316197
# 2019-05-17 22:05:32,483 root         INFO     ====> Epoch: 6 Average Neg ELBO: 3.0040
# 2019-05-17 22:05:32,506 root         INFO     Val Epoch: 6 [0/2000 (0%)]	Batch Neg ELBO: 2.374292
# Reconstruction: 2.188592, Regularization: 0.185700
# 2019-05-17 22:05:32,537 root         INFO     Val Epoch: 6 [512/2000 (25%)]	Batch Neg ELBO: 3.312437
# Reconstruction: 2.983117, Regularization: 0.329320
# 2019-05-17 22:05:32,568 root         INFO     Val Epoch: 6 [1024/2000 (51%)]	Batch Neg ELBO: 2.798753
# Reconstruction: 2.545729, Regularization: 0.253024
# 2019-05-17 22:05:32,598 root         INFO     Val Epoch: 6 [1536/2000 (76%)]	Batch Neg ELBO: 3.270305
# Reconstruction: 2.948878, Regularization: 0.321428
# 2019-05-17 22:05:32,650 root         INFO     ====> Val Epoch: 6 Average Neg ELBO: 2.9837
# 2019-05-17 22:05:32,673 root         INFO     Train Epoch: 7 [0/8000 (0%)]	Batch Neg ELBO: 3.438834
# Reconstruction: 3.091970, Regularization: 0.346864
# 2019-05-17 22:05:32,715 root         INFO     Train Epoch: 7 [512/8000 (6%)]	Batch Neg ELBO: 3.351572
# Reconstruction: 2.999988, Regularization: 0.351584
# 2019-05-17 22:05:32,757 root         INFO     Train Epoch: 7 [1024/8000 (13%)]	Batch Neg ELBO: 2.775320
# Reconstruction: 2.507105, Regularization: 0.268215
# 2019-05-17 22:05:32,799 root         INFO     Train Epoch: 7 [1536/8000 (19%)]	Batch Neg ELBO: 3.252937
# Reconstruction: 2.891431, Regularization: 0.361506
# 2019-05-17 22:05:32,840 root         INFO     Train Epoch: 7 [2048/8000 (26%)]	Batch Neg ELBO: 2.965668
# Reconstruction: 2.640267, Regularization: 0.325401
# 2019-05-17 22:05:32,882 root         INFO     Train Epoch: 7 [2560/8000 (32%)]	Batch Neg ELBO: 3.452939
# Reconstruction: 3.027526, Regularization: 0.425413
# 2019-05-17 22:05:32,923 root         INFO     Train Epoch: 7 [3072/8000 (38%)]	Batch Neg ELBO: 2.503716
# Reconstruction: 2.245327, Regularization: 0.258389
# 2019-05-17 22:05:32,965 root         INFO     Train Epoch: 7 [3584/8000 (45%)]	Batch Neg ELBO: 2.951952
# Reconstruction: 2.593867, Regularization: 0.358084
# 2019-05-17 22:05:33,006 root         INFO     Train Epoch: 7 [4096/8000 (51%)]	Batch Neg ELBO: 3.752434
# Reconstruction: 3.217011, Regularization: 0.535423
# 2019-05-17 22:05:33,047 root         INFO     Train Epoch: 7 [4608/8000 (58%)]	Batch Neg ELBO: 3.330730
# Reconstruction: 2.873444, Regularization: 0.457286
# 2019-05-17 22:05:33,088 root         INFO     Train Epoch: 7 [5120/8000 (64%)]	Batch Neg ELBO: 2.830854
# Reconstruction: 2.466193, Regularization: 0.364661
# 2019-05-17 22:05:33,128 root         INFO     Train Epoch: 7 [5632/8000 (70%)]	Batch Neg ELBO: 2.796225
# Reconstruction: 2.428026, Regularization: 0.368199
# 2019-05-17 22:05:33,168 root         INFO     Train Epoch: 7 [6144/8000 (77%)]	Batch Neg ELBO: 2.787998
# Reconstruction: 2.413719, Regularization: 0.374279
# 2019-05-17 22:05:33,208 root         INFO     Train Epoch: 7 [6656/8000 (83%)]	Batch Neg ELBO: 3.728246
# Reconstruction: 3.108191, Regularization: 0.620055
# 2019-05-17 22:05:33,249 root         INFO     Train Epoch: 7 [7168/8000 (90%)]	Batch Neg ELBO: 2.764188
# Reconstruction: 2.367624, Regularization: 0.396564
# 2019-05-17 22:05:33,288 root         INFO     Train Epoch: 7 [7680/8000 (96%)]	Batch Neg ELBO: 3.157984
# Reconstruction: 2.652242, Regularization: 0.505741
# 2019-05-17 22:05:33,348 root         INFO     ====> Epoch: 7 Average Neg ELBO: 2.8420
# 2019-05-17 22:05:33,371 root         INFO     Val Epoch: 7 [0/2000 (0%)]	Batch Neg ELBO: 2.347294
# Reconstruction: 2.045460, Regularization: 0.301834
# 2019-05-17 22:05:33,401 root         INFO     Val Epoch: 7 [512/2000 (25%)]	Batch Neg ELBO: 2.950083
# Reconstruction: 2.485012, Regularization: 0.465071
# 2019-05-17 22:05:33,431 root         INFO     Val Epoch: 7 [1024/2000 (51%)]	Batch Neg ELBO: 2.398016
# Reconstruction: 2.081310, Regularization: 0.316707
# 2019-05-17 22:05:33,461 root         INFO     Val Epoch: 7 [1536/2000 (76%)]	Batch Neg ELBO: 3.327847
# Reconstruction: 2.757372, Regularization: 0.570475
# 2019-05-17 22:05:33,512 root         INFO     ====> Val Epoch: 7 Average Neg ELBO: 2.8211
# 2019-05-17 22:05:33,535 root         INFO     Train Epoch: 8 [0/8000 (0%)]	Batch Neg ELBO: 2.822612
# Reconstruction: 2.393967, Regularization: 0.428644
# 2019-05-17 22:05:33,576 root         INFO     Train Epoch: 8 [512/8000 (6%)]	Batch Neg ELBO: 2.623930
# Reconstruction: 2.237701, Regularization: 0.386229
# 2019-05-17 22:05:33,618 root         INFO     Train Epoch: 8 [1024/8000 (13%)]	Batch Neg ELBO: 2.350746
# Reconstruction: 2.035488, Regularization: 0.315258
# 2019-05-17 22:05:33,659 root         INFO     Train Epoch: 8 [1536/8000 (19%)]	Batch Neg ELBO: 2.634017
# Reconstruction: 2.220752, Regularization: 0.413264
# 2019-05-17 22:05:33,701 root         INFO     Train Epoch: 8 [2048/8000 (26%)]	Batch Neg ELBO: 2.492364
# Reconstruction: 2.121936, Regularization: 0.370428
# 2019-05-17 22:05:33,742 root         INFO     Train Epoch: 8 [2560/8000 (32%)]	Batch Neg ELBO: 2.639621
# Reconstruction: 2.211075, Regularization: 0.428546
# 2019-05-17 22:05:33,784 root         INFO     Train Epoch: 8 [3072/8000 (38%)]	Batch Neg ELBO: 2.797396
# Reconstruction: 2.299052, Regularization: 0.498344
# 2019-05-17 22:05:33,825 root         INFO     Train Epoch: 8 [3584/8000 (45%)]	Batch Neg ELBO: 2.152795
# Reconstruction: 1.865205, Regularization: 0.287589
# 2019-05-17 22:05:33,866 root         INFO     Train Epoch: 8 [4096/8000 (51%)]	Batch Neg ELBO: 3.487419
# Reconstruction: 2.744462, Regularization: 0.742957
# 2019-05-17 22:05:33,907 root         INFO     Train Epoch: 8 [4608/8000 (58%)]	Batch Neg ELBO: 2.191663
# Reconstruction: 1.876465, Regularization: 0.315197
# 2019-05-17 22:05:33,948 root         INFO     Train Epoch: 8 [5120/8000 (64%)]	Batch Neg ELBO: 2.778254
# Reconstruction: 2.252866, Regularization: 0.525388
# 2019-05-17 22:05:33,990 root         INFO     Train Epoch: 8 [5632/8000 (70%)]	Batch Neg ELBO: 2.525769
# Reconstruction: 2.084575, Regularization: 0.441194
# 2019-05-17 22:05:34,031 root         INFO     Train Epoch: 8 [6144/8000 (77%)]	Batch Neg ELBO: 2.985882
# Reconstruction: 2.368764, Regularization: 0.617118
# 2019-05-17 22:05:34,072 root         INFO     Train Epoch: 8 [6656/8000 (83%)]	Batch Neg ELBO: 2.307406
# Reconstruction: 1.931530, Regularization: 0.375876
# 2019-05-17 22:05:34,113 root         INFO     Train Epoch: 8 [7168/8000 (90%)]	Batch Neg ELBO: 2.308984
# Reconstruction: 1.925193, Regularization: 0.383791
# 2019-05-17 22:05:34,154 root         INFO     Train Epoch: 8 [7680/8000 (96%)]	Batch Neg ELBO: 2.865990
# Reconstruction: 2.263425, Regularization: 0.602565
# 2019-05-17 22:05:34,229 root         INFO     ====> Epoch: 8 Average Neg ELBO: 2.7172
# 2019-05-17 22:05:34,251 root         INFO     Val Epoch: 8 [0/2000 (0%)]	Batch Neg ELBO: 2.470475
# Reconstruction: 2.018696, Regularization: 0.451779
# 2019-05-17 22:05:34,282 root         INFO     Val Epoch: 8 [512/2000 (25%)]	Batch Neg ELBO: 2.810166
# Reconstruction: 2.225041, Regularization: 0.585125
# 2019-05-17 22:05:34,313 root         INFO     Val Epoch: 8 [1024/2000 (51%)]	Batch Neg ELBO: 2.756769
# Reconstruction: 2.193404, Regularization: 0.563365
# 2019-05-17 22:05:34,343 root         INFO     Val Epoch: 8 [1536/2000 (76%)]	Batch Neg ELBO: 2.700241
# Reconstruction: 2.154751, Regularization: 0.545490
# 2019-05-17 22:05:34,395 root         INFO     ====> Val Epoch: 8 Average Neg ELBO: 2.7217
# 2019-05-17 22:05:34,419 root         INFO     Train Epoch: 9 [0/8000 (0%)]	Batch Neg ELBO: 2.806373
# Reconstruction: 2.222008, Regularization: 0.584365
# 2019-05-17 22:05:34,459 root         INFO     Train Epoch: 9 [512/8000 (6%)]	Batch Neg ELBO: 2.727967
# Reconstruction: 2.162506, Regularization: 0.565461
# 2019-05-17 22:05:34,501 root         INFO     Train Epoch: 9 [1024/8000 (13%)]	Batch Neg ELBO: 2.553561
# Reconstruction: 2.062500, Regularization: 0.491062
# 2019-05-17 22:05:34,541 root         INFO     Train Epoch: 9 [1536/8000 (19%)]	Batch Neg ELBO: 3.213621
# Reconstruction: 2.434943, Regularization: 0.778677
# 2019-05-17 22:05:34,582 root         INFO     Train Epoch: 9 [2048/8000 (26%)]	Batch Neg ELBO: 3.086472
# Reconstruction: 2.356075, Regularization: 0.730396
# 2019-05-17 22:05:34,624 root         INFO     Train Epoch: 9 [2560/8000 (32%)]	Batch Neg ELBO: 2.520789
# Reconstruction: 2.029739, Regularization: 0.491050
# 2019-05-17 22:05:34,665 root         INFO     Train Epoch: 9 [3072/8000 (38%)]	Batch Neg ELBO: 2.642849
# Reconstruction: 2.093469, Regularization: 0.549379
# 2019-05-17 22:05:34,707 root         INFO     Train Epoch: 9 [3584/8000 (45%)]	Batch Neg ELBO: 3.123188
# Reconstruction: 2.352332, Regularization: 0.770856
# 2019-05-17 22:05:34,748 root         INFO     Train Epoch: 9 [4096/8000 (51%)]	Batch Neg ELBO: 2.868055
# Reconstruction: 2.206790, Regularization: 0.661265
# 2019-05-17 22:05:34,789 root         INFO     Train Epoch: 9 [4608/8000 (58%)]	Batch Neg ELBO: 2.564099
# Reconstruction: 2.029901, Regularization: 0.534198
# 2019-05-17 22:05:34,831 root         INFO     Train Epoch: 9 [5120/8000 (64%)]	Batch Neg ELBO: 2.568577
# Reconstruction: 2.024359, Regularization: 0.544218
# 2019-05-17 22:05:34,873 root         INFO     Train Epoch: 9 [5632/8000 (70%)]	Batch Neg ELBO: 2.272097
# Reconstruction: 1.868545, Regularization: 0.403552
# 2019-05-17 22:05:34,914 root         INFO     Train Epoch: 9 [6144/8000 (77%)]	Batch Neg ELBO: 2.930826
# Reconstruction: 2.217328, Regularization: 0.713498
# 2019-05-17 22:05:34,956 root         INFO     Train Epoch: 9 [6656/8000 (83%)]	Batch Neg ELBO: 2.811943
# Reconstruction: 2.144559, Regularization: 0.667384
# 2019-05-17 22:05:34,998 root         INFO     Train Epoch: 9 [7168/8000 (90%)]	Batch Neg ELBO: 2.453598
# Reconstruction: 1.956982, Regularization: 0.496615
# 2019-05-17 22:05:35,040 root         INFO     Train Epoch: 9 [7680/8000 (96%)]	Batch Neg ELBO: 2.718245
# Reconstruction: 2.085166, Regularization: 0.633079
# 2019-05-17 22:05:35,103 root         INFO     ====> Epoch: 9 Average Neg ELBO: 2.6589
# 2019-05-17 22:05:35,127 root         INFO     Val Epoch: 9 [0/2000 (0%)]	Batch Neg ELBO: 2.576859
# Reconstruction: 2.017792, Regularization: 0.559067
# 2019-05-17 22:05:35,158 root         INFO     Val Epoch: 9 [512/2000 (25%)]	Batch Neg ELBO: 2.994664
# Reconstruction: 2.240410, Regularization: 0.754254
# 2019-05-17 22:05:35,189 root         INFO     Val Epoch: 9 [1024/2000 (51%)]	Batch Neg ELBO: 2.902635
# Reconstruction: 2.182701, Regularization: 0.719934
# 2019-05-17 22:05:35,219 root         INFO     Val Epoch: 9 [1536/2000 (76%)]	Batch Neg ELBO: 3.261741
# Reconstruction: 2.376711, Regularization: 0.885030
# 2019-05-17 22:05:35,271 root         INFO     ====> Val Epoch: 9 Average Neg ELBO: 2.6852
# 2019-05-17 22:05:35,294 root         INFO     Train Epoch: 10 [0/8000 (0%)]	Batch Neg ELBO: 2.806526
# Reconstruction: 2.140713, Regularization: 0.665813
# 2019-05-17 22:05:35,335 root         INFO     Train Epoch: 10 [512/8000 (6%)]	Batch Neg ELBO: 3.294516
# Reconstruction: 2.381353, Regularization: 0.913163
# 2019-05-17 22:05:35,375 root         INFO     Train Epoch: 10 [1024/8000 (13%)]	Batch Neg ELBO: 2.704654
# Reconstruction: 2.077271, Regularization: 0.627383
# 2019-05-17 22:05:35,416 root         INFO     Train Epoch: 10 [1536/8000 (19%)]	Batch Neg ELBO: 2.369365
# Reconstruction: 1.907875, Regularization: 0.461490
# 2019-05-17 22:05:35,458 root         INFO     Train Epoch: 10 [2048/8000 (26%)]	Batch Neg ELBO: 2.566041
# Reconstruction: 2.007700, Regularization: 0.558341
# 2019-05-17 22:05:35,500 root         INFO     Train Epoch: 10 [2560/8000 (32%)]	Batch Neg ELBO: 2.679834
# Reconstruction: 2.049377, Regularization: 0.630457
# 2019-05-17 22:05:35,541 root         INFO     Train Epoch: 10 [3072/8000 (38%)]	Batch Neg ELBO: 2.832070
# Reconstruction: 2.135422, Regularization: 0.696648
# 2019-05-17 22:05:35,583 root         INFO     Train Epoch: 10 [3584/8000 (45%)]	Batch Neg ELBO: 2.639813
# Reconstruction: 2.046956, Regularization: 0.592857
# 2019-05-17 22:05:35,625 root         INFO     Train Epoch: 10 [4096/8000 (51%)]	Batch Neg ELBO: 3.061099
# Reconstruction: 2.231794, Regularization: 0.829305
# 2019-05-17 22:05:35,666 root         INFO     Train Epoch: 10 [4608/8000 (58%)]	Batch Neg ELBO: 2.403655
# Reconstruction: 1.916797, Regularization: 0.486858
# 2019-05-17 22:05:35,708 root         INFO     Train Epoch: 10 [5120/8000 (64%)]	Batch Neg ELBO: 3.115854
# Reconstruction: 2.270492, Regularization: 0.845362
# 2019-05-17 22:05:35,749 root         INFO     Train Epoch: 10 [5632/8000 (70%)]	Batch Neg ELBO: 2.550607
# Reconstruction: 1.986180, Regularization: 0.564427
# 2019-05-17 22:05:35,791 root         INFO     Train Epoch: 10 [6144/8000 (77%)]	Batch Neg ELBO: 2.835021
# Reconstruction: 2.114208, Regularization: 0.720813
# 2019-05-17 22:05:35,832 root         INFO     Train Epoch: 10 [6656/8000 (83%)]	Batch Neg ELBO: 2.164444
# Reconstruction: 1.805921, Regularization: 0.358523
# 2019-05-17 22:05:35,874 root         INFO     Train Epoch: 10 [7168/8000 (90%)]	Batch Neg ELBO: 2.706787
# Reconstruction: 2.062989, Regularization: 0.643799
# 2019-05-17 22:05:35,915 root         INFO     Train Epoch: 10 [7680/8000 (96%)]	Batch Neg ELBO: 2.689945
# Reconstruction: 2.042987, Regularization: 0.646957
# 2019-05-17 22:05:35,977 root         INFO     ====> Epoch: 10 Average Neg ELBO: 2.6396
# 2019-05-17 22:05:36,000 root         INFO     Val Epoch: 10 [0/2000 (0%)]	Batch Neg ELBO: 2.358875
# Reconstruction: 1.892310, Regularization: 0.466565
# 2019-05-17 22:05:36,031 root         INFO     Val Epoch: 10 [512/2000 (25%)]	Batch Neg ELBO: 2.901759
# Reconstruction: 2.151867, Regularization: 0.749892
# 2019-05-17 22:05:36,062 root         INFO     Val Epoch: 10 [1024/2000 (51%)]	Batch Neg ELBO: 2.733991
# Reconstruction: 2.066234, Regularization: 0.667757
# 2019-05-17 22:05:36,093 root         INFO     Val Epoch: 10 [1536/2000 (76%)]	Batch Neg ELBO: 3.120015
# Reconstruction: 2.258678, Regularization: 0.861337
# 2019-05-17 22:05:36,144 root         INFO     ====> Val Epoch: 10 Average Neg ELBO: 2.6729
# 2019-05-17 22:05:36,168 root         INFO     Train Epoch: 11 [0/8000 (0%)]	Batch Neg ELBO: 2.294411
# Reconstruction: 1.864918, Regularization: 0.429493
# 2019-05-17 22:05:36,210 root         INFO     Train Epoch: 11 [512/8000 (6%)]	Batch Neg ELBO: 2.932019
# Reconstruction: 2.181435, Regularization: 0.750583
# 2019-05-17 22:05:36,251 root         INFO     Train Epoch: 11 [1024/8000 (13%)]	Batch Neg ELBO: 3.057301
# Reconstruction: 2.223681, Regularization: 0.833620
# 2019-05-17 22:05:36,293 root         INFO     Train Epoch: 11 [1536/8000 (19%)]	Batch Neg ELBO: 2.959882
# Reconstruction: 2.178311, Regularization: 0.781571
# 2019-05-17 22:05:36,335 root         INFO     Train Epoch: 11 [2048/8000 (26%)]	Batch Neg ELBO: 3.071035
# Reconstruction: 2.227588, Regularization: 0.843447
# 2019-05-17 22:05:36,376 root         INFO     Train Epoch: 11 [2560/8000 (32%)]	Batch Neg ELBO: 2.603355
# Reconstruction: 2.022846, Regularization: 0.580509
# 2019-05-17 22:05:36,418 root         INFO     Train Epoch: 11 [3072/8000 (38%)]	Batch Neg ELBO: 2.518533
# Reconstruction: 1.973553, Regularization: 0.544980
# 2019-05-17 22:05:36,459 root         INFO     Train Epoch: 11 [3584/8000 (45%)]	Batch Neg ELBO: 2.337272
# Reconstruction: 1.880538, Regularization: 0.456735
# 2019-05-17 22:05:36,501 root         INFO     Train Epoch: 11 [4096/8000 (51%)]	Batch Neg ELBO: 2.492982
# Reconstruction: 1.962503, Regularization: 0.530480
# 2019-05-17 22:05:36,542 root         INFO     Train Epoch: 11 [4608/8000 (58%)]	Batch Neg ELBO: 2.415233
# Reconstruction: 1.929401, Regularization: 0.485832
# 2019-05-17 22:05:36,583 root         INFO     Train Epoch: 11 [5120/8000 (64%)]	Batch Neg ELBO: 2.609326
# Reconstruction: 2.007884, Regularization: 0.601442
# 2019-05-17 22:05:36,624 root         INFO     Train Epoch: 11 [5632/8000 (70%)]	Batch Neg ELBO: 2.863447
# Reconstruction: 2.137816, Regularization: 0.725631
# 2019-05-17 22:05:36,665 root         INFO     Train Epoch: 11 [6144/8000 (77%)]	Batch Neg ELBO: 2.823682
# Reconstruction: 2.114082, Regularization: 0.709600
# 2019-05-17 22:05:36,706 root         INFO     Train Epoch: 11 [6656/8000 (83%)]	Batch Neg ELBO: 2.755613
# Reconstruction: 2.074916, Regularization: 0.680697
# 2019-05-17 22:05:36,747 root         INFO     Train Epoch: 11 [7168/8000 (90%)]	Batch Neg ELBO: 2.666779
# Reconstruction: 2.043630, Regularization: 0.623149
# 2019-05-17 22:05:36,788 root         INFO     Train Epoch: 11 [7680/8000 (96%)]	Batch Neg ELBO: 2.742100
# Reconstruction: 2.071696, Regularization: 0.670404
# 2019-05-17 22:05:36,849 root         INFO     ====> Epoch: 11 Average Neg ELBO: 2.6350
# 2019-05-17 22:05:36,872 root         INFO     Val Epoch: 11 [0/2000 (0%)]	Batch Neg ELBO: 2.615180
# Reconstruction: 2.015854, Regularization: 0.599326
# 2019-05-17 22:05:36,903 root         INFO     Val Epoch: 11 [512/2000 (25%)]	Batch Neg ELBO: 2.910410
# Reconstruction: 2.159137, Regularization: 0.751273
# 2019-05-17 22:05:36,933 root         INFO     Val Epoch: 11 [1024/2000 (51%)]	Batch Neg ELBO: 2.220908
# Reconstruction: 1.831857, Regularization: 0.389051
# 2019-05-17 22:05:36,963 root         INFO     Val Epoch: 11 [1536/2000 (76%)]	Batch Neg ELBO: 3.006220
# Reconstruction: 2.195333, Regularization: 0.810887
# 2019-05-17 22:05:37,013 root         INFO     ====> Val Epoch: 11 Average Neg ELBO: 2.6712
# 2019-05-17 22:05:37,037 root         INFO     Train Epoch: 12 [0/8000 (0%)]	Batch Neg ELBO: 2.626295
# Reconstruction: 2.021336, Regularization: 0.604959
# 2019-05-17 22:05:37,079 root         INFO     Train Epoch: 12 [512/8000 (6%)]	Batch Neg ELBO: 2.620390
# Reconstruction: 2.018215, Regularization: 0.602176
# 2019-05-17 22:05:37,120 root         INFO     Train Epoch: 12 [1024/8000 (13%)]	Batch Neg ELBO: 2.626894
# Reconstruction: 2.018261, Regularization: 0.608632
# 2019-05-17 22:05:37,162 root         INFO     Train Epoch: 12 [1536/8000 (19%)]	Batch Neg ELBO: 2.727325
# Reconstruction: 2.068622, Regularization: 0.658703
# 2019-05-17 22:05:37,203 root         INFO     Train Epoch: 12 [2048/8000 (26%)]	Batch Neg ELBO: 2.201092
# Reconstruction: 1.827637, Regularization: 0.373454
# 2019-05-17 22:05:37,244 root         INFO     Train Epoch: 12 [2560/8000 (32%)]	Batch Neg ELBO: 2.303985
# Reconstruction: 1.874997, Regularization: 0.428988
# 2019-05-17 22:05:37,284 root         INFO     Train Epoch: 12 [3072/8000 (38%)]	Batch Neg ELBO: 2.333932
# Reconstruction: 1.885493, Regularization: 0.448439
# 2019-05-17 22:05:37,325 root         INFO     Train Epoch: 12 [3584/8000 (45%)]	Batch Neg ELBO: 3.334816
# Reconstruction: 2.353042, Regularization: 0.981774
# 2019-05-17 22:05:37,366 root         INFO     Train Epoch: 12 [4096/8000 (51%)]	Batch Neg ELBO: 2.849113
# Reconstruction: 2.128918, Regularization: 0.720194
# 2019-05-17 22:05:37,406 root         INFO     Train Epoch: 12 [4608/8000 (58%)]	Batch Neg ELBO: 2.515728
# Reconstruction: 1.965143, Regularization: 0.550585
# 2019-05-17 22:05:37,447 root         INFO     Train Epoch: 12 [5120/8000 (64%)]	Batch Neg ELBO: 2.238943
# Reconstruction: 1.844476, Regularization: 0.394466
# 2019-05-17 22:05:37,487 root         INFO     Train Epoch: 12 [5632/8000 (70%)]	Batch Neg ELBO: 2.601445
# Reconstruction: 2.008854, Regularization: 0.592591
# 2019-05-17 22:05:37,528 root         INFO     Train Epoch: 12 [6144/8000 (77%)]	Batch Neg ELBO: 2.770708
# Reconstruction: 2.080817, Regularization: 0.689891
# 2019-05-17 22:05:37,569 root         INFO     Train Epoch: 12 [6656/8000 (83%)]	Batch Neg ELBO: 3.037910
# Reconstruction: 2.200436, Regularization: 0.837473
# 2019-05-17 22:05:37,609 root         INFO     Train Epoch: 12 [7168/8000 (90%)]	Batch Neg ELBO: 2.918738
# Reconstruction: 2.147893, Regularization: 0.770845
# 2019-05-17 22:05:37,650 root         INFO     Train Epoch: 12 [7680/8000 (96%)]	Batch Neg ELBO: 2.430912
# Reconstruction: 1.921307, Regularization: 0.509605
# 2019-05-17 22:05:37,711 root         INFO     ====> Epoch: 12 Average Neg ELBO: 2.6327
# 2019-05-17 22:05:37,734 root         INFO     Val Epoch: 12 [0/2000 (0%)]	Batch Neg ELBO: 2.320353
# Reconstruction: 1.872512, Regularization: 0.447841
# 2019-05-17 22:05:37,765 root         INFO     Val Epoch: 12 [512/2000 (25%)]	Batch Neg ELBO: 2.425924
# Reconstruction: 1.933756, Regularization: 0.492168
# 2019-05-17 22:05:37,796 root         INFO     Val Epoch: 12 [1024/2000 (51%)]	Batch Neg ELBO: 2.379723
# Reconstruction: 1.907897, Regularization: 0.471826
# 2019-05-17 22:05:37,826 root         INFO     Val Epoch: 12 [1536/2000 (76%)]	Batch Neg ELBO: 2.467607
# Reconstruction: 1.954975, Regularization: 0.512632
# 2019-05-17 22:05:37,878 root         INFO     ====> Val Epoch: 12 Average Neg ELBO: 2.6692
# 2019-05-17 22:05:37,902 root         INFO     Train Epoch: 13 [0/8000 (0%)]	Batch Neg ELBO: 2.489319
# Reconstruction: 1.971753, Regularization: 0.517567
# 2019-05-17 22:05:37,943 root         INFO     Train Epoch: 13 [512/8000 (6%)]	Batch Neg ELBO: 2.296049
# Reconstruction: 1.872630, Regularization: 0.423419
# 2019-05-17 22:05:37,985 root         INFO     Train Epoch: 13 [1024/8000 (13%)]	Batch Neg ELBO: 2.285047
# Reconstruction: 1.875780, Regularization: 0.409267
# 2019-05-17 22:05:38,027 root         INFO     Train Epoch: 13 [1536/8000 (19%)]	Batch Neg ELBO: 2.341075
# Reconstruction: 1.901008, Regularization: 0.440067
# 2019-05-17 22:05:38,068 root         INFO     Train Epoch: 13 [2048/8000 (26%)]	Batch Neg ELBO: 2.524630
# Reconstruction: 1.965952, Regularization: 0.558678
# 2019-05-17 22:05:38,110 root         INFO     Train Epoch: 13 [2560/8000 (32%)]	Batch Neg ELBO: 2.719972
# Reconstruction: 2.055986, Regularization: 0.663986
# 2019-05-17 22:05:38,151 root         INFO     Train Epoch: 13 [3072/8000 (38%)]	Batch Neg ELBO: 2.334175
# Reconstruction: 1.894490, Regularization: 0.439685
# 2019-05-17 22:05:38,193 root         INFO     Train Epoch: 13 [3584/8000 (45%)]	Batch Neg ELBO: 2.925529
# Reconstruction: 2.143907, Regularization: 0.781621
# 2019-05-17 22:05:38,235 root         INFO     Train Epoch: 13 [4096/8000 (51%)]	Batch Neg ELBO: 2.689969
# Reconstruction: 2.054704, Regularization: 0.635265
# ...
# 2019-05-17 22:09:05,650 root         INFO     Train Epoch: 74 [1536/8000 (19%)]	Batch NEG IWELBO: 2.309441
# 2019-05-17 22:09:05,694 root         INFO     Train Epoch: 74 [2048/8000 (26%)]	Batch NEG IWELBO: 2.393672
# 2019-05-17 22:09:05,737 root         INFO     Train Epoch: 74 [2560/8000 (32%)]	Batch NEG IWELBO: 2.425096
# 2019-05-17 22:09:05,780 root         INFO     Train Epoch: 74 [3072/8000 (38%)]	Batch NEG IWELBO: 2.387037
# 2019-05-17 22:09:05,824 root         INFO     Train Epoch: 74 [3584/8000 (45%)]	Batch NEG IWELBO: 2.183267
# 2019-05-17 22:09:05,867 root         INFO     Train Epoch: 74 [4096/8000 (51%)]	Batch NEG IWELBO: 2.321276
# 2019-05-17 22:09:05,910 root         INFO     Train Epoch: 74 [4608/8000 (58%)]	Batch NEG IWELBO: 2.412561
# 2019-05-17 22:09:05,954 root         INFO     Train Epoch: 74 [5120/8000 (64%)]	Batch NEG IWELBO: 2.207223
# 2019-05-17 22:09:05,997 root         INFO     Train Epoch: 74 [5632/8000 (70%)]	Batch NEG IWELBO: 2.137163
# 2019-05-17 22:09:06,040 root         INFO     Train Epoch: 74 [6144/8000 (77%)]	Batch NEG IWELBO: 2.111495
# 2019-05-17 22:09:06,084 root         INFO     Train Epoch: 74 [6656/8000 (83%)]	Batch NEG IWELBO: 2.148158
# 2019-05-17 22:09:06,127 root         INFO     Train Epoch: 74 [7168/8000 (90%)]	Batch NEG IWELBO: 2.233521
# 2019-05-17 22:09:06,170 root         INFO     Train Epoch: 74 [7680/8000 (96%)]	Batch NEG IWELBO: 2.060010
# 2019-05-17 22:09:06,232 root         INFO     ====> Epoch: 74 Average NEG IWELBO: 2.2141
# 2019-05-17 22:09:06,255 root         INFO     Val Epoch: 74 [0/2000 (0%)]	Batch NEG IWELBO: 2.484182
# 2019-05-17 22:09:06,286 root         INFO     Val Epoch: 74 [512/2000 (25%)]	Batch NEG IWELBO: 2.023984
# 2019-05-17 22:09:06,316 root         INFO     Val Epoch: 74 [1024/2000 (51%)]	Batch NEG IWELBO: 2.158433
# 2019-05-17 22:09:06,346 root         INFO     Val Epoch: 74 [1536/2000 (76%)]	Batch NEG IWELBO: 2.486200
# 2019-05-17 22:09:06,397 root         INFO     ====> Val Epoch: 74 Average NEG IWELBO: 2.2306
# 2019-05-17 22:09:06,421 root         INFO     Train Epoch: 75 [0/8000 (0%)]	Batch NEG IWELBO: 1.937733
# 2019-05-17 22:09:06,465 root         INFO     Train Epoch: 75 [512/8000 (6%)]	Batch NEG IWELBO: 2.502493
# 2019-05-17 22:09:06,509 root         INFO     Train Epoch: 75 [1024/8000 (13%)]	Batch NEG IWELBO: 2.410914
# 2019-05-17 22:09:06,553 root         INFO     Train Epoch: 75 [1536/8000 (19%)]	Batch NEG IWELBO: 2.248706
# 2019-05-17 22:09:06,596 root         INFO     Train Epoch: 75 [2048/8000 (26%)]	Batch NEG IWELBO: 2.361497
# 2019-05-17 22:09:06,640 root         INFO     Train Epoch: 75 [2560/8000 (32%)]	Batch NEG IWELBO: 2.100186
# 2019-05-17 22:09:06,683 root         INFO     Train Epoch: 75 [3072/8000 (38%)]	Batch NEG IWELBO: 1.979722
# 2019-05-17 22:09:06,727 root         INFO     Train Epoch: 75 [3584/8000 (45%)]	Batch NEG IWELBO: 2.213856
# 2019-05-17 22:09:06,770 root         INFO     Train Epoch: 75 [4096/8000 (51%)]	Batch NEG IWELBO: 2.147107
# 2019-05-17 22:09:06,813 root         INFO     Train Epoch: 75 [4608/8000 (58%)]	Batch NEG IWELBO: 2.052153
# 2019-05-17 22:09:06,855 root         INFO     Train Epoch: 75 [5120/8000 (64%)]	Batch NEG IWELBO: 2.393702
# 2019-05-17 22:09:06,897 root         INFO     Train Epoch: 75 [5632/8000 (70%)]	Batch NEG IWELBO: 2.344895
# 2019-05-17 22:09:06,940 root         INFO     Train Epoch: 75 [6144/8000 (77%)]	Batch NEG IWELBO: 2.221060
# 2019-05-17 22:09:06,982 root         INFO     Train Epoch: 75 [6656/8000 (83%)]	Batch NEG IWELBO: 2.195199
# 2019-05-17 22:09:07,025 root         INFO     Train Epoch: 75 [7168/8000 (90%)]	Batch NEG IWELBO: 2.111726
# 2019-05-17 22:09:07,067 root         INFO     Train Epoch: 75 [7680/8000 (96%)]	Batch NEG IWELBO: 2.123744
# 2019-05-17 22:09:07,129 root         INFO     ====> Epoch: 75 Average NEG IWELBO: 2.2145
# 2019-05-17 22:09:07,152 root         INFO     Val Epoch: 75 [0/2000 (0%)]	Batch NEG IWELBO: 2.298248
# 2019-05-17 22:09:07,183 root         INFO     Val Epoch: 75 [512/2000 (25%)]	Batch NEG IWELBO: 2.256324
# 2019-05-17 22:09:07,213 root         INFO     Val Epoch: 75 [1024/2000 (51%)]	Batch NEG IWELBO: 2.273923
# 2019-05-17 22:09:07,244 root         INFO     Val Epoch: 75 [1536/2000 (76%)]	Batch NEG IWELBO: 1.991561
# 2019-05-17 22:09:07,294 root         INFO     ====> Val Epoch: 75 Average NEG IWELBO: 2.2316
# 2019-05-17 22:09:07,319 root         INFO     Train Epoch: 76 [0/8000 (0%)]	Batch NEG IWELBO: 2.324075
# 2019-05-17 22:09:07,361 root         INFO     Train Epoch: 76 [512/8000 (6%)]	Batch NEG IWELBO: 2.038733
# 2019-05-17 22:09:07,403 root         INFO     Train Epoch: 76 [1024/8000 (13%)]	Batch NEG IWELBO: 2.260085
# 2019-05-17 22:09:07,445 root         INFO     Train Epoch: 76 [1536/8000 (19%)]	Batch NEG IWELBO: 2.072561
# 2019-05-17 22:09:07,488 root         INFO     Train Epoch: 76 [2048/8000 (26%)]	Batch NEG IWELBO: 2.112573
# 2019-05-17 22:09:07,530 root         INFO     Train Epoch: 76 [2560/8000 (32%)]	Batch NEG IWELBO: 2.196225
# 2019-05-17 22:09:07,573 root         INFO     Train Epoch: 76 [3072/8000 (38%)]	Batch NEG IWELBO: 2.218758
# 2019-05-17 22:09:07,615 root         INFO     Train Epoch: 76 [3584/8000 (45%)]	Batch NEG IWELBO: 2.242703
# 2019-05-17 22:09:07,659 root         INFO     Train Epoch: 76 [4096/8000 (51%)]	Batch NEG IWELBO: 2.173760
# 2019-05-17 22:09:07,702 root         INFO     Train Epoch: 76 [4608/8000 (58%)]	Batch NEG IWELBO: 2.207609
# 2019-05-17 22:09:07,745 root         INFO     Train Epoch: 76 [5120/8000 (64%)]	Batch NEG IWELBO: 2.366414
# 2019-05-17 22:09:07,787 root         INFO     Train Epoch: 76 [5632/8000 (70%)]	Batch NEG IWELBO: 2.373537
# 2019-05-17 22:09:07,829 root         INFO     Train Epoch: 76 [6144/8000 (77%)]	Batch NEG IWELBO: 2.296622
# 2019-05-17 22:09:07,872 root         INFO     Train Epoch: 76 [6656/8000 (83%)]	Batch NEG IWELBO: 2.156825
# 2019-05-17 22:09:07,915 root         INFO     Train Epoch: 76 [7168/8000 (90%)]	Batch NEG IWELBO: 2.185455
# 2019-05-17 22:09:07,957 root         INFO     Train Epoch: 76 [7680/8000 (96%)]	Batch NEG IWELBO: 2.350173
# 2019-05-17 22:09:08,018 root         INFO     ====> Epoch: 76 Average NEG IWELBO: 2.2142
# 2019-05-17 22:09:08,041 root         INFO     Val Epoch: 76 [0/2000 (0%)]	Batch NEG IWELBO: 2.155348
# 2019-05-17 22:09:08,071 root         INFO     Val Epoch: 76 [512/2000 (25%)]	Batch NEG IWELBO: 2.299059
# 2019-05-17 22:09:08,100 root         INFO     Val Epoch: 76 [1024/2000 (51%)]	Batch NEG IWELBO: 2.098445
# 2019-05-17 22:09:08,130 root         INFO     Val Epoch: 76 [1536/2000 (76%)]	Batch NEG IWELBO: 2.362784
# 2019-05-17 22:09:08,180 root         INFO     ====> Val Epoch: 76 Average NEG IWELBO: 2.2318
# 2019-05-17 22:09:08,203 root         INFO     Train Epoch: 77 [0/8000 (0%)]	Batch NEG IWELBO: 2.350997
# 2019-05-17 22:09:08,247 root         INFO     Train Epoch: 77 [512/8000 (6%)]	Batch NEG IWELBO: 2.207616
# 2019-05-17 22:09:08,290 root         INFO     Train Epoch: 77 [1024/8000 (13%)]	Batch NEG IWELBO: 2.153716
# 2019-05-17 22:09:08,333 root         INFO     Train Epoch: 77 [1536/8000 (19%)]	Batch NEG IWELBO: 2.168917
# 2019-05-17 22:09:08,376 root         INFO     Train Epoch: 77 [2048/8000 (26%)]	Batch NEG IWELBO: 2.098519
# 2019-05-17 22:09:08,419 root         INFO     Train Epoch: 77 [2560/8000 (32%)]	Batch NEG IWELBO: 2.291590
# 2019-05-17 22:09:08,462 root         INFO     Train Epoch: 77 [3072/8000 (38%)]	Batch NEG IWELBO: 2.543273
# 2019-05-17 22:09:08,506 root         INFO     Train Epoch: 77 [3584/8000 (45%)]	Batch NEG IWELBO: 2.277503
# 2019-05-17 22:09:08,549 root         INFO     Train Epoch: 77 [4096/8000 (51%)]	Batch NEG IWELBO: 2.084196
# 2019-05-17 22:09:08,591 root         INFO     Train Epoch: 77 [4608/8000 (58%)]	Batch NEG IWELBO: 2.164396
# 2019-05-17 22:09:08,633 root         INFO     Train Epoch: 77 [5120/8000 (64%)]	Batch NEG IWELBO: 2.146135
# 2019-05-17 22:09:08,675 root         INFO     Train Epoch: 77 [5632/8000 (70%)]	Batch NEG IWELBO: 2.090865
# 2019-05-17 22:09:08,717 root         INFO     Train Epoch: 77 [6144/8000 (77%)]	Batch NEG IWELBO: 2.136592
# 2019-05-17 22:09:08,760 root         INFO     Train Epoch: 77 [6656/8000 (83%)]	Batch NEG IWELBO: 2.577949
# 2019-05-17 22:09:08,802 root         INFO     Train Epoch: 77 [7168/8000 (90%)]	Batch NEG IWELBO: 2.125589
# 2019-05-17 22:09:08,844 root         INFO     Train Epoch: 77 [7680/8000 (96%)]	Batch NEG IWELBO: 2.152934
# 2019-05-17 22:09:08,907 root         INFO     ====> Epoch: 77 Average NEG IWELBO: 2.2150
# 2019-05-17 22:09:08,930 root         INFO     Val Epoch: 77 [0/2000 (0%)]	Batch NEG IWELBO: 2.291683
# 2019-05-17 22:09:08,961 root         INFO     Val Epoch: 77 [512/2000 (25%)]	Batch NEG IWELBO: 2.251106
# 2019-05-17 22:09:08,991 root         INFO     Val Epoch: 77 [1024/2000 (51%)]	Batch NEG IWELBO: 2.127356
# 2019-05-17 22:09:09,021 root         INFO     Val Epoch: 77 [1536/2000 (76%)]	Batch NEG IWELBO: 2.184667
# 2019-05-17 22:09:09,071 root         INFO     ====> Val Epoch: 77 Average NEG IWELBO: 2.2314
# 2019-05-17 22:09:09,095 root         INFO     Train Epoch: 78 [0/8000 (0%)]	Batch NEG IWELBO: 2.177320
# 2019-05-17 22:09:09,138 root         INFO     Train Epoch: 78 [512/8000 (6%)]	Batch NEG IWELBO: 2.110419
# 2019-05-17 22:09:09,181 root         INFO     Train Epoch: 78 [1024/8000 (13%)]	Batch NEG IWELBO: 2.115807
# 2019-05-17 22:09:09,223 root         INFO     Train Epoch: 78 [1536/8000 (19%)]	Batch NEG IWELBO: 2.192445
# 2019-05-17 22:09:09,266 root         INFO     Train Epoch: 78 [2048/8000 (26%)]	Batch NEG IWELBO: 2.199204
# 2019-05-17 22:09:09,309 root         INFO     Train Epoch: 78 [2560/8000 (32%)]	Batch NEG IWELBO: 2.131749
# 2019-05-17 22:09:09,352 root         INFO     Train Epoch: 78 [3072/8000 (38%)]	Batch NEG IWELBO: 2.128982
# 2019-05-17 22:09:09,395 root         INFO     Train Epoch: 78 [3584/8000 (45%)]	Batch NEG IWELBO: 2.062464
# 2019-05-17 22:09:09,438 root         INFO     Train Epoch: 78 [4096/8000 (51%)]	Batch NEG IWELBO: 2.109828
# 2019-05-17 22:09:09,482 root         INFO     Train Epoch: 78 [4608/8000 (58%)]	Batch NEG IWELBO: 2.041592
# 2019-05-17 22:09:09,525 root         INFO     Train Epoch: 78 [5120/8000 (64%)]	Batch NEG IWELBO: 2.284706
# 2019-05-17 22:09:09,568 root         INFO     Train Epoch: 78 [5632/8000 (70%)]	Batch NEG IWELBO: 2.466856
# 2019-05-17 22:09:09,611 root         INFO     Train Epoch: 78 [6144/8000 (77%)]	Batch NEG IWELBO: 2.338176
# 2019-05-17 22:09:09,654 root         INFO     Train Epoch: 78 [6656/8000 (83%)]	Batch NEG IWELBO: 2.217081
# 2019-05-17 22:09:09,698 root         INFO     Train Epoch: 78 [7168/8000 (90%)]	Batch NEG IWELBO: 2.175984
# 2019-05-17 22:09:09,741 root         INFO     Train Epoch: 78 [7680/8000 (96%)]	Batch NEG IWELBO: 2.391269
# 2019-05-17 22:09:09,817 root         INFO     ====> Epoch: 78 Average NEG IWELBO: 2.2145
# 2019-05-17 22:09:09,840 root         INFO     Val Epoch: 78 [0/2000 (0%)]	Batch NEG IWELBO: 2.375392
# 2019-05-17 22:09:09,871 root         INFO     Val Epoch: 78 [512/2000 (25%)]	Batch NEG IWELBO: 2.490708
# 2019-05-17 22:09:09,901 root         INFO     Val Epoch: 78 [1024/2000 (51%)]	Batch NEG IWELBO: 2.326151
# 2019-05-17 22:09:09,930 root         INFO     Val Epoch: 78 [1536/2000 (76%)]	Batch NEG IWELBO: 2.106025
# 2019-05-17 22:09:09,981 root         INFO     ====> Val Epoch: 78 Average NEG IWELBO: 2.2310
# 2019-05-17 22:09:10,005 root         INFO     Train Epoch: 79 [0/8000 (0%)]	Batch NEG IWELBO: 2.188702
# 2019-05-17 22:09:10,048 root         INFO     Train Epoch: 79 [512/8000 (6%)]	Batch NEG IWELBO: 2.122108
# 2019-05-17 22:09:10,089 root         INFO     Train Epoch: 79 [1024/8000 (13%)]	Batch NEG IWELBO: 2.116210
# 2019-05-17 22:09:10,131 root         INFO     Train Epoch: 79 [1536/8000 (19%)]	Batch NEG IWELBO: 2.219081
# 2019-05-17 22:09:10,173 root         INFO     Train Epoch: 79 [2048/8000 (26%)]	Batch NEG IWELBO: 2.075276
# 2019-05-17 22:09:10,215 root         INFO     Train Epoch: 79 [2560/8000 (32%)]	Batch NEG IWELBO: 2.113773
# 2019-05-17 22:09:10,256 root         INFO     Train Epoch: 79 [3072/8000 (38%)]	Batch NEG IWELBO: 2.290863
# 2019-05-17 22:09:10,298 root         INFO     Train Epoch: 79 [3584/8000 (45%)]	Batch NEG IWELBO: 2.233485
# 2019-05-17 22:09:10,340 root         INFO     Train Epoch: 79 [4096/8000 (51%)]	Batch NEG IWELBO: 2.362356
# 2019-05-17 22:09:10,382 root         INFO     Train Epoch: 79 [4608/8000 (58%)]	Batch NEG IWELBO: 2.336227
# 2019-05-17 22:09:10,423 root         INFO     Train Epoch: 79 [5120/8000 (64%)]	Batch NEG IWELBO: 1.978143
# 2019-05-17 22:09:10,465 root         INFO     Train Epoch: 79 [5632/8000 (70%)]	Batch NEG IWELBO: 2.338382
# 2019-05-17 22:09:10,507 root         INFO     Train Epoch: 79 [6144/8000 (77%)]	Batch NEG IWELBO: 2.173258
# 2019-05-17 22:09:10,549 root         INFO     Train Epoch: 79 [6656/8000 (83%)]	Batch NEG IWELBO: 2.089756
# 2019-05-17 22:09:10,591 root         INFO     Train Epoch: 79 [7168/8000 (90%)]	Batch NEG IWELBO: 2.297956
# 2019-05-17 22:09:10,633 root         INFO     Train Epoch: 79 [7680/8000 (96%)]	Batch NEG IWELBO: 2.545868
# 2019-05-17 22:09:10,696 root         INFO     ====> Epoch: 79 Average NEG IWELBO: 2.2144
# 2019-05-17 22:09:10,719 root         INFO     Val Epoch: 79 [0/2000 (0%)]	Batch NEG IWELBO: 2.057184
# 2019-05-17 22:09:10,749 root         INFO     Val Epoch: 79 [512/2000 (25%)]	Batch NEG IWELBO: 2.302283
# 2019-05-17 22:09:10,779 root         INFO     Val Epoch: 79 [1024/2000 (51%)]	Batch NEG IWELBO: 2.289575
# 2019-05-17 22:09:10,810 root         INFO     Val Epoch: 79 [1536/2000 (76%)]	Batch NEG IWELBO: 2.261017
# 2019-05-17 22:09:10,861 root         INFO     ====> Val Epoch: 79 Average NEG IWELBO: 2.2322
# 2019-05-17 22:09:10,884 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) done      TrainIWAE()
# 2019-05-17 22:09:10,885 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-17 22:09:10,885 luigi-interface INFO     Informed scheduler that task   TrainIWAE__99914b932b   has status   DONE
# 2019-05-17 22:09:10,885 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-17 22:09:10,885 luigi-interface DEBUG    Pending tasks: 2
# 2019-05-17 22:09:10,886 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) running   Report()
# 2019-05-17 22:09:10,888 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) done      Report()
# 2019-05-17 22:09:10,888 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-17 22:09:10,889 luigi-interface INFO     Informed scheduler that task   Report__99914b932b   has status   DONE
# 2019-05-17 22:09:10,889 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-17 22:09:10,889 luigi-interface DEBUG    Pending tasks: 1
# 2019-05-17 22:09:10,889 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) running   RunAll()
# 2019-05-17 22:09:10,890 luigi-interface INFO     [pid 28039] Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) done      RunAll()
# 2019-05-17 22:09:10,890 luigi-interface DEBUG    1 running tasks, waiting for next task to finish
# 2019-05-17 22:09:10,890 luigi-interface INFO     Informed scheduler that task   RunAll__99914b932b   has status   DONE
# 2019-05-17 22:09:10,890 luigi-interface DEBUG    Asking scheduler for work...
# 2019-05-17 22:09:10,890 luigi-interface DEBUG    Done
# 2019-05-17 22:09:10,890 luigi-interface DEBUG    There are no more tasks to run at this time
# 2019-05-17 22:09:10,890 luigi-interface INFO     Worker Worker(salt=447342177, workers=1, host=gne, username=nina, pid=28039) was stopped. Shutting down Keep-Alive thread
# 2019-05-17 22:09:10,891 luigi-interface INFO
# ===== Luigi Execution Summary =====
#
# Scheduled 6 tasks of which:
# * 6 ran successfully:
#     - 1 MakeDataSet()
#     - 1 Report()
#     - 1 RunAll()
#     - 1 TrainIWAE()
#     - 1 TrainVAE()
#     ...
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
