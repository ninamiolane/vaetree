# %%
"""Data inspection."""
# Out:
# 'Data inspection.'

# %%
import csv
import glob
import matplotlib
# %matplotlib inline
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib import animation
import nibabel
import os
import sklearn
import shutil

import torch
import numpy as np
import pickle
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider, FloatSlider
import ipywidgets as widgets

import importlib
import analyze
importlib.reload(analyze)
import datasets
importlib.reload(datasets)
import vis
importlib.reload(vis)

NEURO_DIR = '/neuro/'
TRAIN_VAL_DIR = os.path.join(NEURO_DIR, 'train_val_datasets')
OUTPUT = '/scratch/users/nmiolane/output_fmri'
DEVICE='cuda'

IMG_SHAPE = (96, 96)
SHAPE_STR = datasets.get_shape_string(IMG_SHAPE)
TRAIN_IMG_PATH = os.path.join(TRAIN_VAL_DIR, 'train_fmri_%s.npy' % SHAPE_STR)

# %%
boldscans3 = '/neuro/boldscans3/'
dir_4d = os.path.join(boldscans3, 'processed_4d')
i = 0
for filename in os.listdir(dir_4d):
    if i > 2:
        break
    test = os.path.join(dir_4d, filename)
    nii = nibabel.load(test)
    array = nii.get_fdata()
    array = np.nan_to_num(array)
    print(array.shape)
    
    plt.figure()
    plt.imshow(array[:, :, 26, 10], cmap='viridis')  
    i += 1
# Out:
# (128, 128, 52, 448)
# (128, 128, 52, 448)
# (128, 128, 52, 448)

# %%
boldscans2 = '/neuro/boldscans2/'
test = os.path.join(boldscans2, 'ses-002/func/sub-01_ses-002_task-rest_run-001_bold_space-T1w_preproc.nii.gz')
nii = nibabel.load(test)
array = nii.get_fdata()
array = np.nan_to_num(array)
print(array.shape)
# Out:
# (91, 113, 113, 448)

# %%
plt.figure()
plt.imshow(array[45, :, :, 10], cmap='viridis')

# %%
test2 = os.path.join(boldscans2, 'ses-002/func/sub-01_ses-002_task-rest_run-001_bold_space-MNI152NLin2009cAsym_preproc.nii.gz')
nii = nibabel.load(test2)
array2 = nii.get_fdata()
array2 = np.nan_to_num(array2)
print(array2.shape)
# Out:
# (97, 115, 98, 448)

# %%
plt.figure()
plt.imshow(array2[:, 60, :, 0], cmap='viridis')

# %%
test3 = os.path.join(boldscans2, 'ses-002/func/sub-01_ses-002_task-rest_run-001_bold_space-T1w_brainmask.nii.gz')
nii = nibabel.load(test3)
array3 = nii.get_fdata()
array3 = np.nan_to_num(array3)
print(array3.shape)
# Out:
# (91, 113, 113)

# %%
plt.figure()
plt.imshow(array3[:, :, 50, 0], cmap='viridis')
# Out:
# ------------------------------
# IndexErrorTraceback (most recent call last)
# <ipython-input-30-d957ba800bc4> in <module>
#       1 plt.figure()
# ----> 2 plt.imshow(array3[:, :, 50, 0], cmap='viridis')
#
# IndexError: too many indices for array

# %%
test4 = os.path.join(boldscans2, 'ses-002/func/sub-01_ses-002_task-rest_run-001_bold_space-MNI152NLin2009cAsym_brainmask.nii.gz')
nii = nibabel.load(test4)
array4 = nii.get_fdata()
array4 = np.nan_to_num(array4)
print(array4.shape)
# Out:
# (97, 115, 98)

# %%
plt.figure()
plt.imshow(array4[:, :, 50, 0], cmap='viridis')
task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-085/sub-01_ses-085_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-085_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-086/sub-01_ses-086_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-086_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-087/sub-01_ses-087_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-087_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-088/sub-01_ses-088_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-088_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-089/sub-01_ses-089_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-089_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-091/sub-01_ses-091_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-091_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-092/sub-01_ses-092_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-092_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-093/sub-01_ses-093_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-093_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-094/sub-01_ses-094_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-094_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-095/sub-01_ses-095_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-095_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-096/sub-01_ses-096_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-096_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-097/sub-01_ses-097_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-097_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-098/sub-01_ses-098_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-098_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-099/sub-01_ses-099_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-099_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-100/sub-01_ses-100_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-100_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-101/sub-01_ses-101_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-101_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-102/sub-01_ses-102_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-102_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-103/sub-01_ses-103_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-103_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-104/sub-01_ses-104_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-104_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-005_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-005_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-002_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-002_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-001_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-001_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-010_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-010_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-003_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-003_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-008_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-008_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-009_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-009_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-004_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-004_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-006_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-006_bold.nii.gz
# moving from /neuro/boldscans/processed/ses-105/sub-01_ses-105_task-rest_run-007_bold.nii.gz to /neuro/boldscans/processed/sub-01_ses-105_task-rest_run-007_bold.nii.gz

# %%
nii = nibabel.load('/neuro/boldscans/processed/ses-003/sub-01_ses-003_task-rest_run-001_bold.nii.gz')
array = nii.get_fdata()
array = np.nan_to_num(array)
print(array.shape)
print(nii.header)
# Out:
# (128, 128, 52, 448)
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 57
# dim             : [  4 128 128  52 448   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.     2.     2.     1.998  1.2    1.     1.     1.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.003436106
# quatern_c       : -0.99477684
# quatern_d       : -0.10193608
# qoffset_x       : 132.09444
# qoffset_y       : -121.61805
# qoffset_z       : -59.15113
# srow_x          : [-1.9998877e+00 -1.2027766e-02  1.7435595e-02  1.3209444e+02]
# srow_y          : [-1.5317504e-02  1.9583889e+00 -4.0515357e-01 -1.2161805e+02]
# srow_z          : [ 1.4650944e-02  4.0567005e-01  1.9564127e+00 -5.9151131e+01]
# intent_name     : b''
# magic           : b'n+1'

# %%
plt.figure()
plt.imshow(array[:, :, 26, 447], cmap='viridis')

# %%
mat = array
print(mat[0].shape)
slice = 26
def quick_play(dT = 50):
    fig, ax = plt.subplots()
    im = ax.imshow(mat[:, :, slice, 0], cmap = 'viridis')

    def init():
        im.set_data(mat[:, :, slice, 0])
        return im,

    def animate(i):
        im.set_data(mat[:, :, slice, i])
        return im,

    anima = animation.FuncAnimation(
        fig, animate, frames = array.shape[3]-1, init_func = init, interval = dT, blit = True)
    return anima
    #plt.show()

anima = quick_play()
HTML(anima.to_html5_video())
# Out:
# (128, 52, 448)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-740400cb96de> in <module>
#      20
#      21 anima = quick_play()
# ---> 22 HTML(anima.to_html5_video())
#
# NameError: name 'HTML' is not defined

# %% [markdown]
# ### Inspect MakeDataset

# %%
vis.show_data(TRAIN_IMG_PATH, cmap='viridis')
# Out:
# Loading /neuro/train_val_datasets/train_fmri_96x96.npy
# Dataset shape: (12437, 96, 96)

# %%
epoch_id=19
vis.plot_img_and_recon(OUTPUT, epoch_id=epoch_id, cmap='viridis')
# Out:
# Shape of img data:
# (20, 1, 96, 96)
# Shape of recon:
# (20, 1, 96, 96)

# %% [markdown]
# ### Inspect training

# %%
epoch_id = 19
vis.plot_losses(OUTPUT, epoch_id=epoch_id)

# %% [markdown]
# # 2. Inspect the latent space

# %% [markdown]
# ## Standard PCA on the means of the approximation of the posterior

# %% [markdown]
# ### Load test set and compute latent codes

# %%
def get_session(test_csv, ses_id):
    test_paths = []
    tasks = []
    times = []

    with open(test_csv, 'r') as csv_file:
        reader = csv.reader(csv_file)
        for row in reader:
            path, ses, task, run, time = row
            if path == 'path':
                continue
            if task != 'rest':
                continue
            if int(run) != 1:
                # Only take one run per session
                continue
            if int(ses) != ses_id:
                # Only take the session id
                continue
            test_paths.append(path)
            tasks.append(task)
            times.append(int(time))
        
    subset = [np.load(path) for path in test_paths]
    subset = np.array(subset)
    subset = np.expand_dims(subset, axis=1)
    N_PCA_COMPONENTS = 2

    # Note: the test dataset needs to be unshuffled here
    mus = analyze.latent_projection(OUTPUT, subset)
    projected_mus = analyze.pca_projection(mus, N_PCA_COMPONENTS)

    return projected_mus, tasks, times

# %% [markdown]
# ## Gaussian Kernel Density Estimation

# %%
TIME_MAX = 600

TASK_TO_MARKER = {
    'rest': 'o',
    'breathhold': 'x',
    'dotstop': 'triangle_down',
    'eyesopen': 'star',
    'languagewm': 'tri_down',
    'nback': 'triangle_left',
    'objects': 'hexagon1',
    'retinotopy': 'plus',
    'spatialwm': 'diamond'
}

SES_TO_MARKER = {
    2: 'o',
    3: 'x',
    4: 'v',
    5: 'D',
    10: 'P',
    11: 'p',
    12: 's',
    13: '*'
}

colormap = cm.get_cmap('viridis')
COLORS = colormap(np.linspace(start=0., stop=1., num=TIME_MAX))

def plot_session(ax, test_csv, ses_id, label=''):
    projected_mus, tasks, times = get_session(test_csv, ses_id)

    ax.plot(projected_mus[:, 0], projected_mus[:, 1], label=label)
    for mu, task, time in zip(projected_mus, tasks, times):
        c = np.array([COLORS[time-1]])[0]
        im = ax.plot(mu[0], mu[1], marker=SES_TO_MARKER[ses_id], c=c)
    return im, ax

# %%
train_csv_path = '/neuro/train_val_datasets/train_fmri_128x128_labels.csv'

nrows = 4
ncols = 2
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, 36))


for i_ses, ses_id in enumerate([2, 3, 4, 5, 10, 11, 12, 13]):
    print(ses_id)
    ax = axes[int(i_ses // ncols), int(i_ses % ncols)]
    plot_session(ax, train_csv_path, ses_id, label='Session %d' % ses_id)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.legend()
# Out:
# 2
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 3
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 4
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 5
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 10
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 11
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 12
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 13
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth

# %%
train_csv_path = '/neuro/train_val_datasets/train_fmri_128x128_labels.csv'

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 16))

for ses_id in [2, 3, 4, 5, 10, 11, 12, 13]:
    print(ses_id)
    im, ax = plot_session(ax, train_csv_path, ses_id, label='Session %d' % ses_id)

ax.legend()
    
#cb = fig.colorbar(im[0], ax=ax, orientation='horizontal')
#focus = cb.set_label('Time')
#yticklabels = cb.ax.set_xticklabels([])
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Out:
# 2
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 3
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 4
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 5
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 10
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 11
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 12
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 13
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth

# %%
train_csv_path = '/neuro/train_val_datasets/train_fmri_128x128_labels.csv'

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 16))

for ses_id in [5, 10]:
    print(ses_id)
    im, ax = plot_session(ax, train_csv_path, ses_id, label='Session %d' % ses_id)

ax.legend()

#cb = fig.colorbar(im, ax=ax, orientation='horizontal')
#focus = cb.set_label('Time')
#yticklabels = cb.ax.set_xticklabels([])
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Out:
# 5
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth
# 10
# Last checkpoint:  /scratch/users/nmiolane/output_fmri/training/models/epoch_19_encoder_train_loss_5893.4182_val_loss_11365.7494.pth

# %% [markdown]
# ## Fit a Gaussian Mixture

# %% [markdown]
# INFO:root:Found 106 sessions of rfMRIs: Divide in 75 train, 21 val and 10 test sessions

# %%
from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

# Clustering
X = projected_mus
n_components = 13

#X = StandardScaler().fit_transform(X)
gmm = mixture.GaussianMixture(
    n_components=n_components, covariance_type='full')
algorithm = gmm
name = 'GaussianMixture'
    
algorithm.fit(X)

if hasattr(algorithm, 'labels_'):
    print('test')
    y_pred = algorithm.labels_.astype(np.int)
else:
    y_pred = algorithm.predict(X)

fig, ax = plt.subplots(1, 1)
ax.set_title(name, size=18)

colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                     '#f781bf', '#a65628', '#984ea3',
                                      '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
# add black color for outliers (if any)
colors = np.append(colors, ["#000000"])
ax.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

#ax.xlim(-4, 4)
#ax.ylim(-5, 5)
#ax.xticks(())
#ax.yticks(())

plt.show()

# %% [markdown]
# ### Interactive exploration of PCA in each cluster

# %%
print(torch.__version__)
# Out:
# 1.1.0

# %%
epoch_id = 19

stds = np.zeros(N_COMPONENTS)
for i in range(N_COMPONENTS):
    stds[i] = np.std(projected_mus[:,i])
    
decoder = vis.load_module(OUTPUT, 'decoder', epoch_id)


projected = {}
pcas = {}
for i in range(n_components):
    print('Cluster: %d' % i)
    cluster = mus[y_pred==i]
    pca = PCA(n_components=N_COMPONENTS)
    pca.fit(cluster)
    projected[i] = pca.transform(cluster)
    pcas[i] = pca

    @interact(
        c1=FloatSlider(min=-3,max=3,step=0.1,value=0), 
        c2=FloatSlider(min=-3,max=3,step=0.1,value=0),
        c3=FloatSlider(min=-3,max=3,step=0.1,value=0),
        c4=FloatSlider(min=-3,max=3,step=0.1,value=0),
        c5=FloatSlider(min=-3,max=3,step=0.1,value=0))
    def display_image(c1, c2, c3, c4, c5):
        z = (c1 * pca.components_[0]
             + c2 * pca.components_[1]
             + c3 * pca.components_[2]
             + c4 * pca.components_[3]
             + c5 * pca.components_[4])
        z = torch.Tensor(z).cuda()
        recon, _ = decoder(z)
        recon = recon.squeeze()
        plt.imshow(recon.detach().cpu(), cmap='gray')
# Out:
# Loading: /scratch/users/nmiolane/output/training/models/epoch_19_decoder_train_loss_5893.4182_val_loss_11365.7494.pth
# Cluster: 0
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 1
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 2
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 3
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 4
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 5
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 6
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 7
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 8
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 9
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 10
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 11
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…
# Cluster: 12
# interactive(children=(FloatSlider(value=0.0, description='c1', max=3.0, min=-3.0), FloatSlider(value=0.0, desc…

# %% [markdown]
# ### PCA in each cluster

# %%
fig = plt.figure(figsize=(20, 50))
plt.tight_layout()
r = 4
n_cols = 2 * r + 1 

projected = {}
pcas = {}
cmaps = ['Blues', 'Purples', 'Greens', 'Oranges', 'Reds']
for i in range(n_clusters):
    cluster = mus[y_pred==i]
    pca = PCA(n_components=N_COMPONENTS)
    pca.fit(cluster)
    projected[i] = pca.transform(cluster)
    pcas[i] = pca

    for id in range(N_COMPONENTS):
        for slider in range(-r, r+1, 1):
            plt.subplot(n_clusters*N_COMPONENTS, n_cols, i * N_COMPONENTS * n_cols + id * n_cols + slider + r + 1)
            z = slider * pca.components_[id]
            z = torch.Tensor(z).cuda()
            recon, _ = decoder(z)
            recon = recon.squeeze()
            plt.imshow(recon.detach().cpu(), cmap=cmaps[i])
# Out:
# --------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-34-757cd742a250> in <module>
#       7 pcas = {}
#       8 cmaps = ['Blues', 'Purples', 'Greens', 'Oranges', 'Reds']
# ----> 9 for i in range(n_clusters):
#      10     cluster = mus[y_pred==i]
#      11     pca = PCA(n_components=N_COMPONENTS)
#
# NameError: name 'n_clusters' is not defined

# %% [markdown]
# # 3. Inspect report created by pipeline

# %%
import os
import pylab

report_dir = '/scratch/users/nmiolane/output/report'
losses_path = os.path.join(report_dir, 'losses.png')
images_path = os.path.join(report_dir, 'images.png')
report_path = os.path.join(report_dir, 'report.html')

plt.figure()
img = pylab.imread(losses_path)
plt.imshow(img, aspect='auto')
plt.axis('off')

plt.figure(figsize=(30, 60))
img = pylab.imread(images_path)
plt.imshow(img)
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-1b7bd06265d0> in <module>
#       8
#       9 plt.figure()
# ---> 10 img = pylab.imread(losses_path)
#      11 plt.imshow(img, aspect='auto')
#      12 plt.axis('off')
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in imread(fname, format)
#    2150 @docstring.copy_dedent(matplotlib.image.imread)
#    2151 def imread(fname, format=None):
# -> 2152     return matplotlib.image.imread(fname, format)
#    2153
#    2154
#
# ~/miniconda/envs/py36/lib/python3.6/site-packages/matplotlib/image.py in imread(fname, format)
#    1364             return handler(fd)
#    1365         else:
# -> 1366             with open(fname, 'rb') as fd:
#    1367                 return handler(fd)
#    1368     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch/users/nmiolane/output/report/losses.png'

# %%
import nibabel
path = '/tmp/_oyiw_36_defBrainExtractionBrain.nii.gz'
img = nibabel.load(path)
array = img.get_fdata()
array = np.nan_to_num(array)
plt.imshow(array[:,:,120], cmap='gray')
