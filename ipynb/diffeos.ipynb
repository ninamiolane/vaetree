# %%
"""Data inspection."""
# Out:
# 'Data inspection.'

# %%
import glob
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import nibabel
import os
import sklearn

import torch
import numpy as np
import pickle
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider, FloatSlider
import ipywidgets as widgets

PATH = '/scratch/users/nmiolane/diffeos'
DEVICE='cuda'

# %% [markdown]
# ### Diffeo MNIST

# %% [markdown]
# ### Diffeo Brains

# %%
directory = '/neuro/train_test_datasets'
train = np.load(f'{directory}/train_img_128x128.npy')
train_seg = np.load(f'{directory}/train_segmentation_128x128.npy')

print(train.shape)
print(train_seg.shape)

moving_image = train[11]
target_image = train[12]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
ax = axes[0]
ax.imshow(moving_image[0], cmap='gray')
ax = axes[1]
ax.imshow(target_image[0], cmap='gray')
# Out:
# (76, 1, 128, 128)
# (76, 1, 128, 128)
